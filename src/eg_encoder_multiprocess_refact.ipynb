# %%
import time, threading, queue, sys, gc
from typing import Tuple

import numpy as np
import pyqtgraph as pg
from PyQt6 import QtCore
from collections import deque

import logging, logging.handlers

import h5py, pathlib
from datetime import datetime

# %% [markdown]
# | **速度目標 [rps]** | **1秒当たり [pulses / s]** | **1iterあたり [pulses]** | **カウント** | **再構成速度 (UP / DOWN) \[rps]** | **偏差 \[%]** |
# | ----------------- | -------------------------- | --------------------------- | ----------------------- | ------------------------------- | -------------------------- |
# | 0.1               | 204.8                      | 25.6                        | 26<br>25                | 0.102<br>0.09765625             | +1.56<br>−2.34             |
# | 0.2               | 409.6                      | 51.2                        | 52<br>51                | 0.203<br>0.19921875             | +1.56<br>−0.39             |
# | 0.3               | 614.4                      | 76.8                        | 77<br>76                | 0.301<br>0.296875               | +0.26<br>−1.04             |
# | 0.4               | 819.2                      | 102.4                       | 103<br>102              | 0.402<br>0.3984375              | +0.59<br>−0.39             |
# | 0.5               | 1 024.0                    | 128.0                       | 128<br>128              | 0.500<br>0.500                  | 0.00<br>0.00               |
# | 0.6               | 1 228.8                    | 153.6                       | 154<br>153              | 0.602<br>0.59765625             | +0.26<br>−0.39             |
# | 0.7               | 1 433.6                    | 179.2                       | 180<br>179              | 0.703<br>0.69921875             | +0.45<br>−0.11             |
# | 0.8               | 1 638.4                    | 204.8                       | 205<br>204              | 0.801<br>0.796875               | +0.10<br>−0.39             |
# | 0.9               | 1 843.2                    | 230.4                       | 231<br>230              | 0.902<br>0.8984375              | +0.26<br>−0.17             |
# | 1.0               | 2 048.0                    | 256.0                       | 256<br>256              | 1.000<br>1.000                  | 0.00<br>0.00               |

# %%
# Please change as you need
t_DC = 10 # [s]
pps = 0 # pulses at initialization
step = 100 # [pps]
rst = 1  # [s] reset time
target_freq = 1  # [rps]
RUN_SEC = 100_000



# ------------------------------------------------------------  parameters
DEBUG = True  # set True for jitter log
SAMPLE_RATE = 100_000  # Hz
GEN_CHUNK_SEC = 0.1 # corresponds to PROC_INTERVAL up to 0.05
PROC_INTERVAL = 0.125          # process rate

CHUNK_SEC     = GEN_CHUNK_SEC
N_SAMPLES_GEN = int(SAMPLE_RATE * GEN_CHUNK_SEC) # 100_000 * 0.05 = 5000
SAMPLES_PROC = int(PROC_INTERVAL * SAMPLE_RATE) # 0.125s * 100kHz = 12500
QUEUE_DEPTH = 40  # raw AB backlog
QUAD_DEPTH = 40  # processed backlog (same)
DISPLAY_SEC = RUN_SEC+600
PLOT_SEC = 0.15  # *** fixed x-axis window width (s) *** 1/(0.2*36) < 0.15, 1/(1*36) = 0.03 in 0.03 case pruning length might be too short
GUI_INTERVAL_MS = 50  # update interval (ms) e.g. 50ms = 20Hz

NUM_PULSES = 36000
STABLE_SEC = 7200

# encoder pulse parameters
PULSE_HEIGHT = 5.0  # amplitude
INPUT_VELOCITY = 0.2  # rps

PULSE_WIDTH = 1 / (INPUT_VELOCITY * 512)  # period  (s)
PULSE_DUTY = 0.5  # duty
PULSE_PHASE_A = 0.0  # phase offset (s)
PULSE_PHASE_B = -PULSE_WIDTH / 4  # phase offset (s)

QUADPULSE_WIDTH = 0.00025  # width (s) assuming 4x given 1 rps
THRESHOLD_DEFAULT = 2.5  # logic threshold (V)

IDEAL_CPS = INPUT_VELOCITY   # counts/s (constant ideal)

# power supply parameters
AMPLITUDE = 0.3  # V
OMEGA = 2*np.pi*36*INPUT_VELOCITY

# GUI buffer lengths
PRUNING = 100  # pruning length (s) for GUI
HISTORY = int(SAMPLE_RATE * PLOT_SEC / PRUNING) # = 15000
COUNT_HISTORY = int(8*10) # <-- 1/0.125 * 10 sec
VELO_HISTORY = COUNT_HISTORY
POW_HISTORY = COUNT_HISTORY

# ------------------------------------------------------------  logging
LOG_CHUNK = 1024       # flush log queue every LOG_CHUNK messages
LOG_DATA_NUM = 4  # number of data columns in log file (t, A, B, quad)



# ------------------------------------------------------------  queues & stop flag
buf_q = queue.Queue(maxsize=QUEUE_DEPTH)  # raw (t, A, B)
quad_q = queue.Queue(maxsize=QUAD_DEPTH)  # processed (t, A, B, quad)
stop_writer = threading.Event()

log_q = queue.Queue(maxsize=0)
queue_h = logging.handlers.QueueHandler(log_q)
logger = logging.getLogger("debug")
logger.setLevel(logging.INFO)
logger.addHandler(queue_h)

# %%
# ------------------------------------------------------------  queues & stop flag
buf_q = queue.Queue(maxsize=QUEUE_DEPTH)  # raw (t, A, B)
quad_q = queue.Queue(maxsize=QUAD_DEPTH)  # processed (t, com, vel, pow)
stop_writer = threading.Event()

log_q = queue.Queue(maxsize=0)
queue_h = logging.handlers.QueueHandler(log_q)
logger = logging.getLogger("debug")
logger.setLevel(logging.INFO)
logger.addHandler(queue_h)

run_dir = pathlib.Path("../runs")
run_dir.mkdir(exist_ok=True)
timestamp = datetime.now().strftime("%y%m%d%H%M%S")
h5path = f"{run_dir}/{timestamp}.h5"

h5f = h5py.File(h5path, "w")
dset = h5f.create_dataset(
    "log", shape=(0, LOG_DATA_NUM), maxshape=(None, LOG_DATA_NUM),
    dtype=np.float32, chunks=(LOG_CHUNK, LOG_DATA_NUM), compression="gzip"
)

print("dset shape  =", dset.shape)
print("dset maxshape =", dset.maxshape)
# Out:
# dset shape  = (0, 4)
# dset maxshape = (None, 4)

# %%
def gen_chunk_pulse(
    t: np.ndarray,
    *,
    height: float = PULSE_HEIGHT,
    width: float = PULSE_WIDTH,
    duty: float = PULSE_DUTY,
    phase: float = 0.0,
) -> np.ndarray:
    mod = (t + phase) % width
    return np.where(mod < duty * width, height, 0.0).astype(np.float32)

def gen_chunk_sin(
    time: np.ndarray,
    *,
    A: float = AMPLITUDE,  # amplitude
    omega: float = OMEGA,  # angular frequency
    phase: float = 0.0,  # phase offset in radians
) -> np.ndarray:
    """
    Generate a sine wave chunk.

    Parameters
    ----------
    time : ndarray[float32]
        Time axis for the sine wave.
    A : float
        Amplitude of the sine wave.
    omega : float
        Angular frequency of the sine wave.
    phase : float
        Phase offset in radians.

    Returns
    -------
    ndarray[float32]
        Sine wave values at the given time points.
    """
    n = np.random.randn(len(time))  # random noise
    return A*np.sin(omega*time + phase) + A*0.01*n


REL_AXIS_GEN = (
    np.arange(N_SAMPLES_GEN, dtype=np.float32) / SAMPLE_RATE
)  # 0 ... 0.2 s

# ------------------------------------------------------------  AB → direction → quad helpers


def gen_pulse_direction(
    dA: np.ndarray,
    dB: np.ndarray,
    *,
    threshold: float,
    prev_A: bool | None = None,
    prev_B: bool | None = None,
) -> tuple[np.ndarray, bool, bool]:
    """
    Detect direction for one block **with perfect edge coverage**.

    Parameters
    ----------
    dA, dB : ndarray[float32]
        Analog levels of phase-A / phase-B for the current block.
    threshold : float
        Logic threshold [V].
    prev_A, prev_B : bool | None
        Logical state of A/B *at the end of the PREVIOUS block*.
        • If None (first block), the function falls back to the
          “self-shift” method used before.

    Returns
    -------
    dir_log : ndarray[int8]
        +1 = CW edge, –1 = CCW edge, 0 = no edge.
    last_A, last_B : bool
        Logical state of A/B at the *end* of this block — feed these
        into the next call to avoid losing the boundary edge.
    """
    # --- current logic level ----------------------------------------
    A = dA > threshold
    B = dB > threshold

    # --- previous sample for XOR -----------------------------------
    if prev_A is None:  # first block → old behaviour
        A_prev = np.concatenate(([A[0]], A[:-1]))
        B_prev = np.concatenate(([B[0]], B[:-1]))
    else:               # use states carried over from last block
        A_prev = np.concatenate(([prev_A], A[:-1]))
        B_prev = np.concatenate(([prev_B], B[:-1]))

    dir_log = (B_prev ^ A).astype(int) - (A_prev ^ B).astype(int)

    return dir_log.astype(np.int8), bool(A[-1]), bool(B[-1])

def pulse_count(dir_log: np.ndarray) -> int:
    #return int(np.sum(dir_log))
    return np.sum(dir_log)


def gen_quad_pulse(
    t: np.ndarray, dir_log: np.ndarray, width: float, height: float, sampling_rate: int
) -> np.ndarray:
    samples = int(width * sampling_rate)
    if samples <= 0:
        return np.zeros_like(dir_log, dtype=np.float32)
    base = np.full(samples, height, dtype=np.float32)
    return np.convolve(dir_log, base, mode="full")[: len(t)]


# ------------------------------------------------------------  producer thread
def generator() -> None:
    """Generate AB rectangular-wave chunks at real-time cadence."""
    chunk_idx = 0
    next_t = time.perf_counter()
    while not stop_writer.is_set():
        base = chunk_idx * GEN_CHUNK_SEC
        t_axis = REL_AXIS_GEN + base
        pulse_A = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_A)
        pulse_B = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_B)

        # --- add sine wave for testing purposes ---
        Iu = gen_chunk_sin(t_axis, A=0.3, omega=OMEGA, phase=0.0)
        Iv = gen_chunk_sin(t_axis, A=0.3, omega=OMEGA, phase=2*np.pi/3)
        Iw = gen_chunk_sin(t_axis, A=0.3, omega=OMEGA, phase=4*np.pi/3)
        Vu = gen_chunk_sin(t_axis, A=1.0, omega=OMEGA, phase=np.pi/8)
        Vv = gen_chunk_sin(t_axis, A=1.0, omega=OMEGA, phase=2*np.pi/3 + np.pi/8)
        Vw = gen_chunk_sin(t_axis, A=1.0, omega=OMEGA, phase=4*np.pi/3 + np.pi/8)

        try:
            buf_q.put_nowait((t_axis, pulse_A, pulse_B, Iu, Iv, Iw, Vu, Vv, Vw))
        except queue.Full:
            pass

        chunk_idx += 1
        next_t += GEN_CHUNK_SEC
        sleep = next_t - time.perf_counter()
        if sleep > 0:
            time.sleep(sleep)
        else:
            next_t = time.perf_counter()


# ------------------------------------------------------------  consumer thread
def log_listener():
    handler = logging.StreamHandler(sys.stdout)
    listener = logging.handlers.QueueListener(log_q, handler)
    listener.start()
    stop_writer.wait()
    listener.stop()

def command_freq(t_DC, pps, step, rst, num_pulse, target_freq, t_stable, proc_interval):
    num_step = np.ceil((num_pulse-pps)*target_freq/step) #stableに到達するまでの段数
    time = np.arange(0, t_DC+num_step*rst+t_stable, proc_interval, dtype=np.float32)
    freq = np.zeros(int((t_DC+num_step*rst+t_stable)*(1/proc_interval)), dtype=np.float32)
    n_DC = int(np.round(t_DC/proc_interval))  #DCの速度指令値=0rps
    freq[:n_DC] = 0.0
    n_rst = int(np.round(rst/proc_interval))  #加速中の速度指令値
    freq[n_DC: int(n_DC+n_rst*num_step)] = [pps/num_pulse + target_freq/num_pulse*step*(i+1) for i in range(int(num_step)) for j in freq[int(n_DC+i*n_rst): int(n_DC+(i+1)*n_rst)]]
    #Stableの速度指令値
    freq[int(n_DC+n_rst*num_step):] = target_freq
    return time, freq



# schmitt trigger
def schmitt_trigger(upper, lower, current):
    y_schmitt = np.zeros_like(current)
    state = 0.0
    for i, sample in enumerate(current):
        if state == 0.0 and sample >= upper:
            state = 1.0
        elif state == 1.0 and sample <= lower:
            state = 0.0
        y_schmitt[i] = state
    
    d = np.diff(y_schmitt.astype(int))      # diff（+1 なら立ち上がり, −1 なら立ち下がり）
    rise_idx = np.where(d ==  1)[0] + 1     # 立ち上がり位置
    fall_idx = np.where(d == -1)[0] + 1     # 立ち下がり位置

    return rise_idx, fall_idx

# make function to calculate power
def calc_power_refact(time, I_u, I_v, I_w, V_u, V_v, V_w, upper, lower):
    # schmitt_triggerを用いて電流の1周期につき1点を取ってくる
    rise_idx_I_u = schmitt_trigger(upper, lower, I_u)[0]
    #rise_idx_I_v = schmitt_trigger(upper, lower, I_v)[0]
    #rise_idx_I_w = schmitt_trigger(upper, lower, I_w)[0]

    # proc_intervalの中にI_uが2周期以上入るとき->初めの1周期を取り出してPを計算
    if len(rise_idx_I_u) >= 3:
        period = rise_idx_I_u[1] - rise_idx_I_u[0]
        P_u = np.mean(I_u[rise_idx_I_u[0] : rise_idx_I_u[0]+period] * V_u[rise_idx_I_u[0] : rise_idx_I_u[0]+period])
        P_v = np.mean(I_v[rise_idx_I_u[0]+int(period/3) : rise_idx_I_u[0]+int(4*period/3)] * V_v[rise_idx_I_u[0]+int(period/3) : rise_idx_I_u[0]+int(4*period/3)])
        P_w = np.mean(I_w[rise_idx_I_u[0]+int(2*period/3) : rise_idx_I_u[0]+int(5*period/3)] * V_w[rise_idx_I_u[0]+int(2*period/3) : rise_idx_I_u[0]+int(5*period/3)])
        P_tot = P_u + P_v + P_w

    # proc_intervalの中にI_uが2周期入らないとき->proc_interval全体でPを計算
    else:
        P_u = np.mean(I_u * V_u)
        P_v = np.mean(I_v * V_v)
        P_w = np.mean(I_w * V_w)
        P_tot = P_u + P_v + P_w
    
    # 中央の時間を計算
    time_p = time[0] + (time[-1] - time[0]) / 2

    return time_p,P_u,P_v,P_w,P_tot

class IdealVelocityProvider: # 0 sec からstepはいるので、想定時間よりも1rst分早くなるのが正常
    def __init__(self, t_DC, pps, step, rst, num_pulse, target_freq, t_stable, proc_interval) -> None:
        #num_points: int = int(duration / dt) + 1
        #self.time_axis: np.ndarray = np.linspace(0.0, duration, num_points, dtype=np.float32)
        #self.velocity:  np.ndarray = np.full(num_points, IDEAL_CPS, dtype=np.float32)
        self.t_DC = t_DC
        self.pps = pps
        self.step = step
        self.rst = rst
        self.num_pulse = num_pulse
        self.target_freq = target_freq
        self.t_stable = t_stable
        self.proc_interval = proc_interval
        self.time_axis, self.velocity = command_freq(t_DC, pps, step, rst, num_pulse, target_freq, t_stable, proc_interval)


    def slice(self, t_start: float, t_end: float) -> tuple[np.ndarray, np.ndarray]:
        """Return the time and velocity arrays that fall within [t_start, t_end]."""
        idx_start, idx_end = np.searchsorted(self.time_axis, [t_start, t_end])
        return self.time_axis[idx_start:idx_end], self.velocity[idx_start:idx_end]

ideal: IdealVelocityProvider | None = None  # initialised lazily in processor()


def processor() -> None:
    """
    dequeにしないとバグる
    """
    # ---------- one-time init ----------
    global ideal_provider
    if 'ideal_provider' not in globals() or ideal_provider is None:
        ideal_provider = IdealVelocityProvider(t_DC, pps, step, rst, NUM_PULSES, target_freq, STABLE_SEC, PROC_INTERVAL)

    # ---------- logging ----------
    buf = np.empty((LOG_CHUNK, LOG_DATA_NUM), dtype=np.float32)  # 内部バッファ
    buf_len = 0
    print("buf shape =", buf.shape)

    # --- Python deque リングバッファ ---
    ring_t: deque[np.float32] = deque()
    ring_a: deque[np.float32] = deque()
    ring_b: deque[np.float32] = deque()

    ring_Iu: deque[np.float32] = deque()
    ring_Iv: deque[np.float32] = deque()
    ring_Iw: deque[np.float32] = deque()
    ring_Vu: deque[np.float32] = deque()
    ring_Vv: deque[np.float32] = deque()
    ring_Vw: deque[np.float32] = deque()


    last_A = last_B = None

    next_proc = time.perf_counter()
    cum_count = 0
    last_ts   = next_proc

    while not stop_writer.is_set():
        # ---------- 非ブロッキングで出来るだけ取り込む ----------
        try:
            while True:
                t, pA, pB, Iu, Iv, Iw, Vu, Vv, Vw = buf_q.get_nowait()
                ring_t.extend(t); ring_a.extend(pA); ring_b.extend(pB)
                ring_Iu.extend(Iu); ring_Iv.extend(Iv); ring_Iw.extend(Iw)
                ring_Vu.extend(Vu); ring_Vv.extend(Vv); ring_Vw.extend(Vw)
                buf_q.task_done()
        except queue.Empty:
            pass

        # ---------- 次の処理時刻まで待機 ----------
        now = time.perf_counter()
        if now < next_proc:
            time.sleep(next_proc - now)
            continue
        next_proc += PROC_INTERVAL

        # ---------- サンプル不足ならスキップ ----------
        if len(ring_t) < SAMPLES_PROC:
            continue

        # ---------- deque → NumPy へコピー ----------
        t_blk = np.array([ring_t.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        a_blk = np.array([ring_a.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        b_blk = np.array([ring_b.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)

        Iu_blk = np.array([ring_Iu.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        Iv_blk = np.array([ring_Iv.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        Iw_blk = np.array([ring_Iw.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        Vu_blk = np.array([ring_Vu.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        Vv_blk = np.array([ring_Vv.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        Vw_blk = np.array([ring_Vw.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)

        # ---------- 信号処理 ----------
        dir_log, last_A, last_B = gen_pulse_direction(
            a_blk, b_blk,
            threshold=THRESHOLD_DEFAULT,
            prev_A=last_A, prev_B=last_B
        )
        quad_sig  = gen_quad_pulse(t_blk, dir_log, QUADPULSE_WIDTH, PULSE_HEIGHT, SAMPLE_RATE)
        delta_cnt = pulse_count(dir_log)
        cum_count += delta_cnt
        velocity  = delta_cnt / PROC_INTERVAL / 2048



        # Power calculation
        time_p, P_u, P_v, P_w, P_tot = calc_power_refact(
            t_blk, Iu_blk, Iv_blk, Iw_blk,
            Vu_blk, Vv_blk, Vw_blk, 0, -0.1
        )

        # ---------- 理想速度スライス ----------
        t_ref, v_ref = ideal_provider.slice(t_blk[0], t_blk[-1])

        # ---------- ログ ----------
        '''if DEBUG:
            now = time.perf_counter()
            jitter = (now - last_ts) * 1e3
            logger.info(
                "EPOCH = %f, wall = %6.2f ms, jitter = %6.2f ms  delta c=%+d, v=%6.3f, len(dir_log)=%d, buf_len=%d",
                now, jitter, (now - last_ts) * 1e3,
                delta_cnt, velocity, len(dir_log), buf_len
            )'''

        if DEBUG:
            now = time.perf_counter()
            jitter = (now - last_ts) * 1e3
            logger.info(
                "EPOCH = %f, wall = %6.2f ms, jitter = %6.2f ms  delta c=%+d, v=%6.3f, v_ref=%6.3f, time_p = %f, P_tot = %f",
                now, jitter, (now - last_ts) * 1e3,
                delta_cnt, velocity, v_ref, time_p, P_tot
            )
            last_ts = now

        # ---------- GUI へ送信 ----------
        try:
            quad_q.put_nowait(
                (t_blk, a_blk, b_blk, quad_sig,
                 t_blk[-1], cum_count, velocity,
                 t_ref, v_ref, time_p, P_tot, Iu_blk, Vu_blk)
            )
        except queue.Full:
            pass

         # ---- append to buffer ----
        buf[buf_len] = (t_blk[-1], (v_ref[-1] if v_ref.size else 0.0), velocity, P_tot)
        buf_len += 1
        if buf_len == buf.shape[0]:
            n = dset.shape[0]
            dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf
            buf_len = 0

     # ---- final flush ----
    if buf_len:
        n = dset.shape[0]
        dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf[:buf_len]
    h5f.close()


def start_gui() -> None:
    pg.setConfigOptions(useOpenGL=True, background="w", foreground="k")
    app = pg.mkQApp("Live plots")

    win = pg.GraphicsLayoutWidget(title="DEMO")

    layout = win.ci.layout                 # GraphicsLayout の中身
    layout.setColumnStretchFactor(0, 4)
    layout.setColumnStretchFactor(1, 5)
    #win_sig = pg.GraphicsLayoutWidget(show=True, title="Signal")
    #win_vel = pg.GraphicsLayoutWidget(show=True, title="Velocity")

    #win_sig.resize(800, 600)
    #win_vel.resize(800, 600)
    #win_sig.show()
    pruning = PRUNING
    if pruning < 1:
        pruning = 1 # 0以下の値は無効とし、1に設定


    win.resize(800, 600)
    win.show()

    # [0, 0] A/B -------------------------------------------------------
    plt_ab = win.addPlot(row=0, col=0, title="RAW A / B")
    curve_A = plt_ab.plot(pen=pg.mkPen("#ff4b00", width=3),stepMode="right")
    curve_B = plt_ab.plot(pen=pg.mkPen("#005aff", width=3),stepMode="right")
    plt_ab.setLabel("left", "Amplitude [V]")
    plt_ab.setLabel("bottom", "Time [s]")
    plt_ab.setYRange(-0.5, PULSE_HEIGHT + 0.5)

    # [1,0] Quad waveform --------------------------------------------
    #plt_q = win.addPlot(row=1, col=0, title="Quad pulse")
    #curve_Q = plt_q.plot(pen=pg.mkPen("m", width=3))
    #plt_q.setLabel("left", "Amplitude [V]")
    #plt_q.setLabel("bottom", "Time [s]")
    #plt_q.setYRange(-PULSE_HEIGHT - 0.5, PULSE_HEIGHT + 0.5)

    # [2,0] I/V waveform --------------------------------------------
    plt_IV = win.addPlot(row=2, col=0, title="PhaseU I / V")
    curve_I = plt_IV.plot(pen=pg.mkPen("r", width=3))
    curve_V = plt_IV.plot(pen=pg.mkPen("b", width=3))
    plt_IV.setLabel("left", "Amplitude [a.u.]")
    plt_IV.setLabel("bottom", "Time [s]")
    plt_IV.setYRange(-1.2, 1.2)

    # [0,1] count (fixed x-axis) -------------------------------------
    plt_cnt = win.addPlot(row=0, col=1, title="Velovity - Command")
    curve_cnt = plt_cnt.plot(pen=pg.mkPen("#03af7a", width=3))
    #plt_cnt.setXRange(0, RUN_SEC, padding=0)
    #plt_cnt.enableAutoRange("x", True)
    plt_cnt.setLabel("left", "Diff")
    plt_cnt.setLabel("bottom", "Time [s]")

    # [1,1] velocity
    plt_vel = win.addPlot(row=1, col=1, title="Velocity")
    curve_vel     = plt_vel.plot(pen=pg.mkPen("#00a0e9", width=3))   # measured
    curve_vel_ref = plt_vel.plot(pen=pg.mkPen("#a05aff", width=3), stepMode="right")   # ideal (new)
    #plt_vel.setXRange(0, RUN_SEC, padding=0)
    #plt_vel.enableAutoRange("x", True)
    plt_vel.setLabel("left", "Velocity [rps]")
    plt_vel.setLabel("bottom", "Time [s]")

    # [2,1] power ----------------------------------
    plt_pow = win.addPlot(row=2, col=1, title="Power")
    curve_pow     = plt_pow.plot(pen=pg.mkPen("#f6aa00", width=3))   # measured
    plt_pow.setLabel("left", "Power [W]")
    plt_pow.setLabel("bottom", "Time [s]")

    # buffers ---------------------------------------------------------
    xs = ya = yb = yq = np.empty(0, dtype=np.float32)
    xs_cnt = y_cnt = np.empty(0, dtype=np.float32)
    xs_vel = y_vel = np.empty(0, dtype=np.float32)
    xr = yr = np.empty(0, dtype=np.float32)       # ideal velocity buffers (new)
    y_Iu = y_Vu = np.empty(0, dtype=np.float32)  # I/V buffers (new)
    xs_time_p = y_P_tot = np.empty(0, dtype=np.float32)  # time and power buffers (new)

    def refresh():
        nonlocal xs, ya, yb, yq, xs_cnt, y_cnt, xs_vel, y_vel, xr, yr, xs_time_p, y_P_tot, y_Iu, y_Vu
        try:
            while True:
                # receive processed data
                t_ax, pA, pB, qsig, t_end, cum_cnt, vel, t_ref, v_ref, time_p, P_tot, Iu_blk, Vu_blk = quad_q.get_nowait()

                xs = np.concatenate((xs, t_ax[::pruning]))[-HISTORY:]
                ya = np.concatenate((ya, pA[::pruning]))[-HISTORY:]
                yb = np.concatenate((yb, pB[::pruning]))[-HISTORY:]
                #yq = np.concatenate((yq, qsig))[-HISTORY:]

                xs_cnt = np.append(xs_cnt, t_end)[-COUNT_HISTORY:]
                y_cnt  = np.append(y_cnt, vel-v_ref)[-COUNT_HISTORY:]

                xs_vel = np.append(xs_vel, t_end)[-VELO_HISTORY:]
                y_vel  = np.append(y_vel, vel)[-VELO_HISTORY:]

                xr = np.concatenate((xr, t_ref))[-VELO_HISTORY:]
                yr = np.concatenate((yr, v_ref))[-VELO_HISTORY:]

                y_Iu = np.concatenate((y_Iu, Iu_blk[::pruning]))[-HISTORY:]
                y_Vu = np.concatenate((y_Vu, Vu_blk[::pruning]))[-HISTORY:]

                xs_time_p = np.append(xs_time_p, time_p)[-POW_HISTORY:]
                y_P_tot = np.append(y_P_tot, P_tot)[-POW_HISTORY:]

                quad_q.task_done()
        except queue.Empty:
            pass

        # scrolling window for waveforms only
        if xs.size:
            start = xs[-1] - PLOT_SEC
            plt_ab.setXRange(start, xs[-1], padding=0)
            plt_IV.setXRange(start, xs[-1], padding=0)

        # --- auto-range for count/velocity ---
        if xs_cnt.size:
            plt_cnt.setXRange(xs_cnt[-1]-10, xs_cnt[-1], padding=0)

        if xs_vel.size:
            plt_vel.setXRange(xs_vel[-1]-10, xs_vel[-1], padding=0)

        if xs_time_p.size:
            plt_pow.setXRange(xs_time_p[-1]-10, xs_time_p[-1], padding=0)

        # --- push data to curves ---
        curve_A.setData(xs, ya)
        curve_B.setData(xs, yb)
        curve_I.setData(xs, y_Iu)
        curve_V.setData(xs, y_Vu)
        curve_cnt.setData(xs_cnt, y_cnt)
        curve_vel.setData(xs_vel, y_vel)
        curve_vel_ref.setData(xr, yr)
        curve_pow.setData(xs_time_p, y_P_tot)

    timer = QtCore.QTimer()
    timer.timeout.connect(refresh)
    timer.start(GUI_INTERVAL_MS)

    # auto-stop after RUN_SEC
    QtCore.QTimer.singleShot(int(RUN_SEC * 1000), lambda: (stop_writer.set(), app.quit()))
    app.exec()

# %%
if __name__ == "__main__":
    threading.Thread(target=log_listener, daemon=True).start()  # start log listener

    gen_th  = threading.Thread(target=generator, daemon=True)
    proc_th = threading.Thread(target=processor, daemon=True)

    gen_th.start()
    proc_th.start()
    # con_th.start()

    start_gui()  # blocks until the user closes the window or timer expires

    # join threads and exit
    stop_writer.set()
    gen_th.join()
    proc_th.join()

    print("Graceful shutdown.")
# Out:
# buf shape = (1024, 4)
# EPOCH = 867431.668332, wall = 1357.35 ms, jitter = 1357.35 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 0.062495, P_tot = 0.415717
# EPOCH = 867431.765468, wall =  97.14 ms, jitter =  97.14 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 0.187495, P_tot = 0.415754
# EPOCH = 867431.869085, wall = 103.62 ms, jitter = 103.62 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 0.312495, P_tot = 0.415761
# EPOCH = 867432.042673, wall = 173.59 ms, jitter = 173.59 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 0.437495, P_tot = 0.415783
# EPOCH = 867432.123576, wall =  80.90 ms, jitter =  80.90 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 0.562495, P_tot = 0.415724
# EPOCH = 867432.272708, wall = 149.13 ms, jitter = 149.13 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 0.687495, P_tot = 0.415727
# EPOCH = 867432.385561, wall = 112.85 ms, jitter = 112.85 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 0.812495, P_tot = 0.415801
# EPOCH = 867432.506216, wall = 120.65 ms, jitter = 120.65 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 0.937495, P_tot = 0.415841
# EPOCH = 867432.634303, wall = 128.09 ms, jitter = 128.09 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 1.062495, P_tot = 0.415650
# EPOCH = 867432.782424, wall = 148.12 ms, jitter = 148.12 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 1.187495, P_tot = 0.415774
# EPOCH = 867432.881353, wall =  98.93 ms, jitter =  98.93 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 1.312495, P_tot = 0.415747
# EPOCH = 867433.018956, wall = 137.60 ms, jitter = 137.60 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 1.437495, P_tot = 0.415720
# EPOCH = 867433.136820, wall = 117.86 ms, jitter = 117.86 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 1.562495, P_tot = 0.415749
# EPOCH = 867433.268458, wall = 131.64 ms, jitter = 131.64 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 1.687495, P_tot = 0.415673
# EPOCH = 867433.395204, wall = 126.75 ms, jitter = 126.75 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 1.812495, P_tot = 0.415700
# EPOCH = 867433.516118, wall = 120.91 ms, jitter = 120.91 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 1.937495, P_tot = 0.415686
# EPOCH = 867433.652715, wall = 136.60 ms, jitter = 136.60 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 2.062495, P_tot = 0.415769
# EPOCH = 867433.790608, wall = 137.89 ms, jitter = 137.89 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 2.187495, P_tot = 0.415778
# EPOCH = 867433.874890, wall =  84.28 ms, jitter =  84.28 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 2.312495, P_tot = 0.415712
# EPOCH = 867434.017661, wall = 142.77 ms, jitter = 142.77 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 2.437495, P_tot = 0.415741
# EPOCH = 867434.133213, wall = 115.55 ms, jitter = 115.55 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 2.562495, P_tot = 0.415757
# EPOCH = 867434.255216, wall = 122.00 ms, jitter = 122.00 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 2.687495, P_tot = 0.415722
# EPOCH = 867434.404399, wall = 149.18 ms, jitter = 149.18 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 2.812495, P_tot = 0.415714
# EPOCH = 867434.518500, wall = 114.10 ms, jitter = 114.10 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 2.937495, P_tot = 0.415751
# EPOCH = 867434.754444, wall = 235.94 ms, jitter = 235.94 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 3.062495, P_tot = 0.415709
# EPOCH = 867434.904685, wall = 150.24 ms, jitter = 150.24 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 3.187495, P_tot = 0.415774
# EPOCH = 867435.005693, wall = 101.01 ms, jitter = 101.01 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 3.312495, P_tot = 0.415746
# EPOCH = 867435.142253, wall = 136.56 ms, jitter = 136.56 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 3.437495, P_tot = 0.415768
# EPOCH = 867435.257823, wall = 115.57 ms, jitter = 115.57 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 3.562495, P_tot = 0.415711
# EPOCH = 867435.406553, wall = 148.73 ms, jitter = 148.73 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 3.687495, P_tot = 0.415787
# EPOCH = 867435.508907, wall = 102.35 ms, jitter = 102.35 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 3.812495, P_tot = 0.415741
# EPOCH = 867435.638274, wall = 129.37 ms, jitter = 129.37 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 3.937495, P_tot = 0.415705
# EPOCH = 867435.759229, wall = 120.96 ms, jitter = 120.96 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 4.062495, P_tot = 0.415810
# EPOCH = 867435.909515, wall = 150.29 ms, jitter = 150.29 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 4.187495, P_tot = 0.415707
# EPOCH = 867436.041728, wall = 132.21 ms, jitter = 132.21 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 4.312495, P_tot = 0.415762
# EPOCH = 867436.131249, wall =  89.52 ms, jitter =  89.52 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 4.437495, P_tot = 0.415676
# EPOCH = 867436.259940, wall = 128.69 ms, jitter = 128.69 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 4.562495, P_tot = 0.415692
# EPOCH = 867436.391186, wall = 131.25 ms, jitter = 131.25 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 4.687495, P_tot = 0.415646
# EPOCH = 867436.533179, wall = 141.99 ms, jitter = 141.99 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 4.812495, P_tot = 0.415843
# EPOCH = 867436.669810, wall = 136.63 ms, jitter = 136.63 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 4.937495, P_tot = 0.415699
# EPOCH = 867436.801319, wall = 131.51 ms, jitter = 131.51 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 5.062495, P_tot = 0.415867
# EPOCH = 867436.914961, wall = 113.64 ms, jitter = 113.64 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 5.187495, P_tot = 0.415775
# EPOCH = 867437.022300, wall = 107.34 ms, jitter = 107.34 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 5.312495, P_tot = 0.415807
# EPOCH = 867437.163334, wall = 141.03 ms, jitter = 141.03 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 5.437495, P_tot = 0.415733
# EPOCH = 867437.365983, wall = 202.65 ms, jitter = 202.65 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 5.562495, P_tot = 0.415689
# EPOCH = 867437.502469, wall = 136.49 ms, jitter = 136.49 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 5.687495, P_tot = 0.415708
# EPOCH = 867437.611074, wall = 108.60 ms, jitter = 108.60 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 5.812495, P_tot = 0.415695
# EPOCH = 867437.792140, wall = 181.07 ms, jitter = 181.07 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 5.937495, P_tot = 0.415856
# EPOCH = 867437.900556, wall = 108.42 ms, jitter = 108.42 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 6.062495, P_tot = 0.415761
# EPOCH = 867438.014260, wall = 113.70 ms, jitter = 113.70 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 6.187495, P_tot = 0.415676
# EPOCH = 867438.127376, wall = 113.12 ms, jitter = 113.12 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 6.312495, P_tot = 0.415730
# EPOCH = 867438.289564, wall = 162.19 ms, jitter = 162.19 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 6.437495, P_tot = 0.415792
# EPOCH = 867438.367302, wall =  77.74 ms, jitter =  77.74 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 6.562495, P_tot = 0.415709
# EPOCH = 867438.525968, wall = 158.67 ms, jitter = 158.67 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 6.687495, P_tot = 0.415691
# EPOCH = 867438.667598, wall = 141.63 ms, jitter = 141.63 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 6.812495, P_tot = 0.415715
# EPOCH = 867438.793545, wall = 125.95 ms, jitter = 125.95 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 6.937495, P_tot = 0.415765
# EPOCH = 867438.860579, wall =  67.03 ms, jitter =  67.03 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 7.062495, P_tot = 0.415795
# EPOCH = 867439.005717, wall = 145.14 ms, jitter = 145.14 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 7.187495, P_tot = 0.415721
# EPOCH = 867439.127173, wall = 121.46 ms, jitter = 121.46 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 7.312495, P_tot = 0.415767
# EPOCH = 867439.230082, wall = 102.91 ms, jitter = 102.91 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 7.437495, P_tot = 0.415813
# EPOCH = 867439.361102, wall = 131.02 ms, jitter = 131.02 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 7.562495, P_tot = 0.415729
# EPOCH = 867439.515896, wall = 154.79 ms, jitter = 154.79 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 7.687495, P_tot = 0.415741
# EPOCH = 867439.629893, wall = 114.00 ms, jitter = 114.00 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 7.812495, P_tot = 0.415682
# EPOCH = 867439.759056, wall = 129.16 ms, jitter = 129.16 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 7.937495, P_tot = 0.415743
# EPOCH = 867439.908960, wall = 149.90 ms, jitter = 149.90 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 8.062495, P_tot = 0.415754
# EPOCH = 867440.022987, wall = 114.03 ms, jitter = 114.03 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 8.187495, P_tot = 0.415710
# EPOCH = 867440.143893, wall = 120.91 ms, jitter = 120.91 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 8.312495, P_tot = 0.415805
# EPOCH = 867440.243655, wall =  99.76 ms, jitter =  99.76 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 8.437495, P_tot = 0.415715
# EPOCH = 867440.383912, wall = 140.26 ms, jitter = 140.26 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 8.562495, P_tot = 0.415846
# EPOCH = 867440.513882, wall = 129.97 ms, jitter = 129.97 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 8.687495, P_tot = 0.415704
# EPOCH = 867440.653246, wall = 139.36 ms, jitter = 139.36 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 8.812495, P_tot = 0.415705
# EPOCH = 867440.782391, wall = 129.15 ms, jitter = 129.15 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 8.937495, P_tot = 0.415678
# EPOCH = 867440.869529, wall =  87.14 ms, jitter =  87.14 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 9.062495, P_tot = 0.415715
# EPOCH = 867441.004338, wall = 134.81 ms, jitter = 134.81 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 9.187495, P_tot = 0.415712
# EPOCH = 867441.130246, wall = 125.91 ms, jitter = 125.91 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 9.312495, P_tot = 0.415784
# EPOCH = 867441.262650, wall = 132.40 ms, jitter = 132.40 ms  delta c=+52, v= 0.203, v_ref= 0.000, time_p = 9.437495, P_tot = 0.415808
# EPOCH = 867441.394875, wall = 132.23 ms, jitter = 132.23 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 9.562495, P_tot = 0.415778
# EPOCH = 867441.511107, wall = 116.23 ms, jitter = 116.23 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 9.687495, P_tot = 0.415789
# EPOCH = 867441.627246, wall = 116.14 ms, jitter = 116.14 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 9.812495, P_tot = 0.415779
# EPOCH = 867441.740597, wall = 113.35 ms, jitter = 113.35 ms  delta c=+51, v= 0.199, v_ref= 0.000, time_p = 9.937495, P_tot = 0.415731
# EPOCH = 867441.876979, wall = 136.38 ms, jitter = 136.38 ms  delta c=+52, v= 0.203, v_ref= 0.003, time_p = 10.062495, P_tot = 0.415811
# EPOCH = 867442.002110, wall = 125.13 ms, jitter = 125.13 ms  delta c=+51, v= 0.199, v_ref= 0.003, time_p = 10.187495, P_tot = 0.415756
# EPOCH = 867442.111096, wall = 108.99 ms, jitter = 108.99 ms  delta c=+51, v= 0.199, v_ref= 0.003, time_p = 10.312495, P_tot = 0.415706
# EPOCH = 867442.245213, wall = 134.12 ms, jitter = 134.12 ms  delta c=+51, v= 0.199, v_ref= 0.003, time_p = 10.437495, P_tot = 0.415776
# EPOCH = 867442.415680, wall = 170.47 ms, jitter = 170.47 ms  delta c=+51, v= 0.199, v_ref= 0.003, time_p = 10.562495, P_tot = 0.415799
# EPOCH = 867442.529307, wall = 113.63 ms, jitter = 113.63 ms  delta c=+52, v= 0.203, v_ref= 0.003, time_p = 10.687495, P_tot = 0.415764
# EPOCH = 867442.629476, wall = 100.17 ms, jitter = 100.17 ms  delta c=+51, v= 0.199, v_ref= 0.003, time_p = 10.812495, P_tot = 0.415740
# EPOCH = 867442.773500, wall = 144.02 ms, jitter = 144.02 ms  delta c=+51, v= 0.199, v_ref= 0.003, time_p = 10.937495, P_tot = 0.415653
# EPOCH = 867442.891374, wall = 117.87 ms, jitter = 117.87 ms  delta c=+51, v= 0.199, v_ref= 0.006, time_p = 11.062495, P_tot = 0.415768
# EPOCH = 867443.033652, wall = 142.28 ms, jitter = 142.28 ms  delta c=+51, v= 0.199, v_ref= 0.006, time_p = 11.187495, P_tot = 0.415742
# EPOCH = 867443.129050, wall =  95.40 ms, jitter =  95.40 ms  delta c=+52, v= 0.203, v_ref= 0.006, time_p = 11.312495, P_tot = 0.415713
# EPOCH = 867443.277890, wall = 148.84 ms, jitter = 148.84 ms  delta c=+51, v= 0.199, v_ref= 0.006, time_p = 11.437495, P_tot = 0.415737
# EPOCH = 867443.387500, wall = 109.61 ms, jitter = 109.61 ms  delta c=+51, v= 0.199, v_ref= 0.006, time_p = 11.562495, P_tot = 0.415638
# EPOCH = 867443.512265, wall = 124.77 ms, jitter = 124.77 ms  delta c=+51, v= 0.199, v_ref= 0.006, time_p = 11.687495, P_tot = 0.415728
# EPOCH = 867443.618791, wall = 106.53 ms, jitter = 106.53 ms  delta c=+51, v= 0.199, v_ref= 0.006, time_p = 11.812495, P_tot = 0.415793
# EPOCH = 867443.754988, wall = 136.20 ms, jitter = 136.20 ms  delta c=+52, v= 0.203, v_ref= 0.006, time_p = 11.937495, P_tot = 0.415796
# EPOCH = 867443.894094, wall = 139.11 ms, jitter = 139.11 ms  delta c=+51, v= 0.199, v_ref= 0.008, time_p = 12.062495, P_tot = 0.415807
# EPOCH = 867444.033525, wall = 139.43 ms, jitter = 139.43 ms  delta c=+51, v= 0.199, v_ref= 0.008, time_p = 12.187495, P_tot = 0.415759
# EPOCH = 867444.141760, wall = 108.23 ms, jitter = 108.23 ms  delta c=+51, v= 0.199, v_ref= 0.008, time_p = 12.312495, P_tot = 0.415765
# EPOCH = 867444.258702, wall = 116.94 ms, jitter = 116.94 ms  delta c=+51, v= 0.199, v_ref= 0.008, time_p = 12.437495, P_tot = 0.415789
# EPOCH = 867444.387371, wall = 128.67 ms, jitter = 128.67 ms  delta c=+52, v= 0.203, v_ref= 0.008, time_p = 12.562495, P_tot = 0.415750
# EPOCH = 867444.512002, wall = 124.63 ms, jitter = 124.63 ms  delta c=+51, v= 0.199, v_ref= 0.008, time_p = 12.687495, P_tot = 0.415703
# EPOCH = 867444.627732, wall = 115.73 ms, jitter = 115.73 ms  delta c=+51, v= 0.199, v_ref= 0.008, time_p = 12.812495, P_tot = 0.415750
# EPOCH = 867444.770488, wall = 142.76 ms, jitter = 142.76 ms  delta c=+51, v= 0.199, v_ref= 0.008, time_p = 12.937495, P_tot = 0.415695
# EPOCH = 867444.888958, wall = 118.47 ms, jitter = 118.47 ms  delta c=+51, v= 0.199, v_ref= 0.011, time_p = 13.062495, P_tot = 0.415753
# EPOCH = 867445.015376, wall = 126.42 ms, jitter = 126.42 ms  delta c=+52, v= 0.203, v_ref= 0.011, time_p = 13.187495, P_tot = 0.415743
# EPOCH = 867445.128248, wall = 112.87 ms, jitter = 112.87 ms  delta c=+51, v= 0.199, v_ref= 0.011, time_p = 13.312495, P_tot = 0.415714
# EPOCH = 867445.273114, wall = 144.87 ms, jitter = 144.87 ms  delta c=+51, v= 0.199, v_ref= 0.011, time_p = 13.437495, P_tot = 0.415729
# EPOCH = 867445.398039, wall = 124.93 ms, jitter = 124.93 ms  delta c=+51, v= 0.199, v_ref= 0.011, time_p = 13.562495, P_tot = 0.415733
# EPOCH = 867445.503811, wall = 105.77 ms, jitter = 105.77 ms  delta c=+51, v= 0.199, v_ref= 0.011, time_p = 13.687495, P_tot = 0.415743
# EPOCH = 867445.631724, wall = 127.91 ms, jitter = 127.91 ms  delta c=+52, v= 0.203, v_ref= 0.011, time_p = 13.812495, P_tot = 0.415740
# EPOCH = 867445.759169, wall = 127.45 ms, jitter = 127.45 ms  delta c=+51, v= 0.199, v_ref= 0.011, time_p = 13.937495, P_tot = 0.415768
# EPOCH = 867445.885030, wall = 125.86 ms, jitter = 125.86 ms  delta c=+51, v= 0.199, v_ref= 0.014, time_p = 14.062495, P_tot = 0.415740
# EPOCH = 867446.010725, wall = 125.70 ms, jitter = 125.70 ms  delta c=+51, v= 0.199, v_ref= 0.014, time_p = 14.187495, P_tot = 0.415807
# EPOCH = 867446.128026, wall = 117.30 ms, jitter = 117.30 ms  delta c=+51, v= 0.199, v_ref= 0.014, time_p = 14.312495, P_tot = 0.415692
# EPOCH = 867446.250778, wall = 122.75 ms, jitter = 122.75 ms  delta c=+52, v= 0.203, v_ref= 0.014, time_p = 14.437495, P_tot = 0.415715
# EPOCH = 867446.396559, wall = 145.78 ms, jitter = 145.78 ms  delta c=+51, v= 0.199, v_ref= 0.014, time_p = 14.562495, P_tot = 0.415793
# EPOCH = 867446.497175, wall = 100.62 ms, jitter = 100.62 ms  delta c=+51, v= 0.199, v_ref= 0.014, time_p = 14.687495, P_tot = 0.415700
# EPOCH = 867446.609076, wall = 111.90 ms, jitter = 111.90 ms  delta c=+51, v= 0.199, v_ref= 0.014, time_p = 14.812495, P_tot = 0.415786
# EPOCH = 867446.759207, wall = 150.13 ms, jitter = 150.13 ms  delta c=+51, v= 0.199, v_ref= 0.014, time_p = 14.937495, P_tot = 0.415766
# EPOCH = 867446.902603, wall = 143.40 ms, jitter = 143.40 ms  delta c=+52, v= 0.203, v_ref= 0.017, time_p = 15.062495, P_tot = 0.415739
# EPOCH = 867447.033578, wall = 130.97 ms, jitter = 130.97 ms  delta c=+51, v= 0.199, v_ref= 0.017, time_p = 15.187495, P_tot = 0.415722
# EPOCH = 867447.122032, wall =  88.45 ms, jitter =  88.45 ms  delta c=+51, v= 0.199, v_ref= 0.017, time_p = 15.312495, P_tot = 0.415803
# EPOCH = 867447.286551, wall = 164.52 ms, jitter = 164.52 ms  delta c=+51, v= 0.199, v_ref= 0.017, time_p = 15.437495, P_tot = 0.415793
# EPOCH = 867447.516982, wall = 230.43 ms, jitter = 230.43 ms  delta c=+51, v= 0.199, v_ref= 0.017, time_p = 15.562495, P_tot = 0.415779
# EPOCH = 867447.649126, wall = 132.14 ms, jitter = 132.14 ms  delta c=+52, v= 0.203, v_ref= 0.017, time_p = 15.687495, P_tot = 0.415770
# EPOCH = 867447.758380, wall = 109.25 ms, jitter = 109.25 ms  delta c=+51, v= 0.199, v_ref= 0.017, time_p = 15.812495, P_tot = 0.415751
# EPOCH = 867447.865825, wall = 107.45 ms, jitter = 107.45 ms  delta c=+51, v= 0.199, v_ref= 0.017, time_p = 15.937495, P_tot = 0.415700
# EPOCH = 867448.013458, wall = 147.63 ms, jitter = 147.63 ms  delta c=+51, v= 0.199, v_ref= 0.019, time_p = 16.062495, P_tot = 0.415731
# EPOCH = 867448.126769, wall = 113.31 ms, jitter = 113.31 ms  delta c=+51, v= 0.199, v_ref= 0.019, time_p = 16.187495, P_tot = 0.415764
# EPOCH = 867448.261282, wall = 134.51 ms, jitter = 134.51 ms  delta c=+52, v= 0.203, v_ref= 0.019, time_p = 16.312495, P_tot = 0.415685
# EPOCH = 867448.383605, wall = 122.32 ms, jitter = 122.32 ms  delta c=+51, v= 0.199, v_ref= 0.019, time_p = 16.437495, P_tot = 0.415674
# EPOCH = 867448.506132, wall = 122.53 ms, jitter = 122.53 ms  delta c=+51, v= 0.199, v_ref= 0.019, time_p = 16.562495, P_tot = 0.415690
# EPOCH = 867448.614733, wall = 108.60 ms, jitter = 108.60 ms  delta c=+51, v= 0.199, v_ref= 0.019, time_p = 16.687495, P_tot = 0.415719
# EPOCH = 867448.750710, wall = 135.98 ms, jitter = 135.98 ms  delta c=+51, v= 0.199, v_ref= 0.019, time_p = 16.812495, P_tot = 0.415783
# EPOCH = 867448.907497, wall = 156.79 ms, jitter = 156.79 ms  delta c=+52, v= 0.203, v_ref= 0.019, time_p = 16.937495, P_tot = 0.415818
# EPOCH = 867448.994687, wall =  87.19 ms, jitter =  87.19 ms  delta c=+51, v= 0.199, v_ref= 0.022, time_p = 17.062495, P_tot = 0.415815
# EPOCH = 867449.126251, wall = 131.56 ms, jitter = 131.56 ms  delta c=+51, v= 0.199, v_ref= 0.022, time_p = 17.187495, P_tot = 0.415783
# EPOCH = 867449.258203, wall = 131.95 ms, jitter = 131.95 ms  delta c=+51, v= 0.199, v_ref= 0.022, time_p = 17.312495, P_tot = 0.415821
# EPOCH = 867449.395987, wall = 137.78 ms, jitter = 137.78 ms  delta c=+51, v= 0.199, v_ref= 0.022, time_p = 17.437495, P_tot = 0.415758
# EPOCH = 867449.535873, wall = 139.89 ms, jitter = 139.89 ms  delta c=+52, v= 0.203, v_ref= 0.022, time_p = 17.562495, P_tot = 0.415766
# EPOCH = 867449.613415, wall =  77.54 ms, jitter =  77.54 ms  delta c=+51, v= 0.199, v_ref= 0.022, time_p = 17.687495, P_tot = 0.415765
# EPOCH = 867449.766787, wall = 153.37 ms, jitter = 153.37 ms  delta c=+51, v= 0.199, v_ref= 0.022, time_p = 17.812495, P_tot = 0.415769
# EPOCH = 867449.903330, wall = 136.54 ms, jitter = 136.54 ms  delta c=+51, v= 0.199, v_ref= 0.022, time_p = 17.937495, P_tot = 0.415652
# EPOCH = 867450.026634, wall = 123.30 ms, jitter = 123.30 ms  delta c=+51, v= 0.199, v_ref= 0.025, time_p = 18.062495, P_tot = 0.415770
# EPOCH = 867450.156023, wall = 129.39 ms, jitter = 129.39 ms  delta c=+52, v= 0.203, v_ref= 0.025, time_p = 18.187495, P_tot = 0.415731
# EPOCH = 867450.262438, wall = 106.42 ms, jitter = 106.42 ms  delta c=+51, v= 0.199, v_ref= 0.025, time_p = 18.312495, P_tot = 0.415703
# EPOCH = 867450.383995, wall = 121.56 ms, jitter = 121.56 ms  delta c=+51, v= 0.199, v_ref= 0.025, time_p = 18.437495, P_tot = 0.415764
# EPOCH = 867450.506694, wall = 122.70 ms, jitter = 122.70 ms  delta c=+51, v= 0.199, v_ref= 0.025, time_p = 18.562495, P_tot = 0.415728
# EPOCH = 867450.624615, wall = 117.92 ms, jitter = 117.92 ms  delta c=+51, v= 0.199, v_ref= 0.025, time_p = 18.687495, P_tot = 0.415796
# EPOCH = 867450.756973, wall = 132.36 ms, jitter = 132.36 ms  delta c=+52, v= 0.203, v_ref= 0.025, time_p = 18.812495, P_tot = 0.415768
# EPOCH = 867450.883134, wall = 126.16 ms, jitter = 126.16 ms  delta c=+51, v= 0.199, v_ref= 0.025, time_p = 18.937495, P_tot = 0.415735
# EPOCH = 867451.002728, wall = 119.59 ms, jitter = 119.59 ms  delta c=+51, v= 0.199, v_ref= 0.028, time_p = 19.062495, P_tot = 0.415782
# EPOCH = 867451.147313, wall = 144.58 ms, jitter = 144.58 ms  delta c=+51, v= 0.199, v_ref= 0.028, time_p = 19.187495, P_tot = 0.415685
# EPOCH = 867451.250639, wall = 103.33 ms, jitter = 103.33 ms  delta c=+51, v= 0.199, v_ref= 0.028, time_p = 19.312495, P_tot = 0.415858
# EPOCH = 867451.391114, wall = 140.48 ms, jitter = 140.48 ms  delta c=+52, v= 0.203, v_ref= 0.028, time_p = 19.437495, P_tot = 0.415712
# EPOCH = 867451.503571, wall = 112.46 ms, jitter = 112.46 ms  delta c=+51, v= 0.199, v_ref= 0.028, time_p = 19.562495, P_tot = 0.415808
# EPOCH = 867451.612321, wall = 108.75 ms, jitter = 108.75 ms  delta c=+51, v= 0.199, v_ref= 0.028, time_p = 19.687495, P_tot = 0.415834
# EPOCH = 867451.775340, wall = 163.02 ms, jitter = 163.02 ms  delta c=+51, v= 0.199, v_ref= 0.028, time_p = 19.812495, P_tot = 0.415750
# EPOCH = 867451.862661, wall =  87.32 ms, jitter =  87.32 ms  delta c=+51, v= 0.199, v_ref= 0.028, time_p = 19.937495, P_tot = 0.415764
# EPOCH = 867452.015008, wall = 152.35 ms, jitter = 152.35 ms  delta c=+52, v= 0.203, v_ref= 0.031, time_p = 20.062495, P_tot = 0.415670
# EPOCH = 867452.160909, wall = 145.90 ms, jitter = 145.90 ms  delta c=+51, v= 0.199, v_ref= 0.031, time_p = 20.187495, P_tot = 0.415745
# EPOCH = 867452.295917, wall = 135.01 ms, jitter = 135.01 ms  delta c=+51, v= 0.199, v_ref= 0.031, time_p = 20.312495, P_tot = 0.415683
# EPOCH = 867452.495629, wall = 199.71 ms, jitter = 199.71 ms  delta c=+51, v= 0.199, v_ref= 0.031, time_p = 20.437495, P_tot = 0.415699
# EPOCH = 867452.662508, wall = 166.88 ms, jitter = 166.88 ms  delta c=+51, v= 0.199, v_ref= 0.031, time_p = 20.562495, P_tot = 0.415728
# EPOCH = 867452.773126, wall = 110.62 ms, jitter = 110.62 ms  delta c=+52, v= 0.203, v_ref= 0.031, time_p = 20.687495, P_tot = 0.415752
# EPOCH = 867452.861329, wall =  88.20 ms, jitter =  88.20 ms  delta c=+51, v= 0.199, v_ref= 0.031, time_p = 20.812495, P_tot = 0.415719
# EPOCH = 867453.003456, wall = 142.13 ms, jitter = 142.13 ms  delta c=+51, v= 0.199, v_ref= 0.031, time_p = 20.937495, P_tot = 0.415665
# EPOCH = 867453.140659, wall = 137.20 ms, jitter = 137.20 ms  delta c=+51, v= 0.199, v_ref= 0.033, time_p = 21.062495, P_tot = 0.415764
# EPOCH = 867453.261884, wall = 121.22 ms, jitter = 121.22 ms  delta c=+51, v= 0.199, v_ref= 0.033, time_p = 21.187495, P_tot = 0.415744
# EPOCH = 867453.405035, wall = 143.15 ms, jitter = 143.15 ms  delta c=+52, v= 0.203, v_ref= 0.033, time_p = 21.312495, P_tot = 0.415705
# EPOCH = 867453.498530, wall =  93.49 ms, jitter =  93.49 ms  delta c=+51, v= 0.199, v_ref= 0.033, time_p = 21.437495, P_tot = 0.415778
# EPOCH = 867453.648211, wall = 149.68 ms, jitter = 149.68 ms  delta c=+51, v= 0.199, v_ref= 0.033, time_p = 21.562495, P_tot = 0.415771
# EPOCH = 867453.738451, wall =  90.24 ms, jitter =  90.24 ms  delta c=+51, v= 0.199, v_ref= 0.033, time_p = 21.687495, P_tot = 0.415750
# EPOCH = 867453.881086, wall = 142.64 ms, jitter = 142.64 ms  delta c=+51, v= 0.199, v_ref= 0.033, time_p = 21.812495, P_tot = 0.415769
# EPOCH = 867454.019771, wall = 138.69 ms, jitter = 138.69 ms  delta c=+52, v= 0.203, v_ref= 0.033, time_p = 21.937495, P_tot = 0.415729
# EPOCH = 867454.151151, wall = 131.38 ms, jitter = 131.38 ms  delta c=+51, v= 0.199, v_ref= 0.036, time_p = 22.062495, P_tot = 0.415673
# EPOCH = 867454.262688, wall = 111.54 ms, jitter = 111.54 ms  delta c=+51, v= 0.199, v_ref= 0.036, time_p = 22.187495, P_tot = 0.415794
# EPOCH = 867454.383538, wall = 120.85 ms, jitter = 120.85 ms  delta c=+51, v= 0.199, v_ref= 0.036, time_p = 22.312495, P_tot = 0.415731
# EPOCH = 867454.506362, wall = 122.82 ms, jitter = 122.82 ms  delta c=+51, v= 0.199, v_ref= 0.036, time_p = 22.437495, P_tot = 0.415826
# EPOCH = 867454.625274, wall = 118.91 ms, jitter = 118.91 ms  delta c=+52, v= 0.203, v_ref= 0.036, time_p = 22.562495, P_tot = 0.415681
# EPOCH = 867454.748153, wall = 122.88 ms, jitter = 122.88 ms  delta c=+51, v= 0.199, v_ref= 0.036, time_p = 22.687495, P_tot = 0.415706
# EPOCH = 867454.879602, wall = 131.45 ms, jitter = 131.45 ms  delta c=+51, v= 0.199, v_ref= 0.036, time_p = 22.812495, P_tot = 0.415799
# EPOCH = 867455.001389, wall = 121.79 ms, jitter = 121.79 ms  delta c=+51, v= 0.199, v_ref= 0.036, time_p = 22.937495, P_tot = 0.415692
# EPOCH = 867455.132861, wall = 131.47 ms, jitter = 131.47 ms  delta c=+51, v= 0.199, v_ref= 0.039, time_p = 23.062495, P_tot = 0.415799
# EPOCH = 867455.265588, wall = 132.73 ms, jitter = 132.73 ms  delta c=+52, v= 0.203, v_ref= 0.039, time_p = 23.187495, P_tot = 0.415723
# EPOCH = 867455.370200, wall = 104.61 ms, jitter = 104.61 ms  delta c=+51, v= 0.199, v_ref= 0.039, time_p = 23.312495, P_tot = 0.415771
# EPOCH = 867455.500678, wall = 130.48 ms, jitter = 130.48 ms  delta c=+51, v= 0.199, v_ref= 0.039, time_p = 23.437495, P_tot = 0.415752
# EPOCH = 867455.651528, wall = 150.85 ms, jitter = 150.85 ms  delta c=+51, v= 0.199, v_ref= 0.039, time_p = 23.562495, P_tot = 0.415738
# EPOCH = 867455.762779, wall = 111.25 ms, jitter = 111.25 ms  delta c=+51, v= 0.199, v_ref= 0.039, time_p = 23.687495, P_tot = 0.415722
# EPOCH = 867455.884121, wall = 121.34 ms, jitter = 121.34 ms  delta c=+52, v= 0.203, v_ref= 0.039, time_p = 23.812495, P_tot = 0.415745
# EPOCH = 867456.008833, wall = 124.71 ms, jitter = 124.71 ms  delta c=+51, v= 0.199, v_ref= 0.039, time_p = 23.937495, P_tot = 0.415726
# EPOCH = 867456.168128, wall = 159.29 ms, jitter = 159.29 ms  delta c=+51, v= 0.199, v_ref= 0.042, time_p = 24.062495, P_tot = 0.415818
# EPOCH = 867456.278551, wall = 110.42 ms, jitter = 110.42 ms  delta c=+51, v= 0.199, v_ref= 0.042, time_p = 24.187495, P_tot = 0.415752
# EPOCH = 867456.405653, wall = 127.10 ms, jitter = 127.10 ms  delta c=+51, v= 0.199, v_ref= 0.042, time_p = 24.312495, P_tot = 0.415775
# EPOCH = 867456.513199, wall = 107.55 ms, jitter = 107.55 ms  delta c=+52, v= 0.203, v_ref= 0.042, time_p = 24.437495, P_tot = 0.415825
# EPOCH = 867456.644374, wall = 131.17 ms, jitter = 131.17 ms  delta c=+51, v= 0.199, v_ref= 0.042, time_p = 24.562495, P_tot = 0.415746
# EPOCH = 867456.812369, wall = 168.00 ms, jitter = 168.00 ms  delta c=+51, v= 0.199, v_ref= 0.042, time_p = 24.687495, P_tot = 0.415791
# EPOCH = 867457.012353, wall = 199.98 ms, jitter = 199.98 ms  delta c=+51, v= 0.199, v_ref= 0.042, time_p = 24.812495, P_tot = 0.415798
# EPOCH = 867457.150548, wall = 138.19 ms, jitter = 138.19 ms  delta c=+51, v= 0.199, v_ref= 0.042, time_p = 24.937495, P_tot = 0.415763
# EPOCH = 867457.260047, wall = 109.50 ms, jitter = 109.50 ms  delta c=+52, v= 0.203, v_ref= 0.044, time_p = 25.062495, P_tot = 0.415800
# EPOCH = 867457.422237, wall = 162.19 ms, jitter = 162.19 ms  delta c=+51, v= 0.199, v_ref= 0.044, time_p = 25.187495, P_tot = 0.415780
# EPOCH = 867457.520910, wall =  98.67 ms, jitter =  98.67 ms  delta c=+51, v= 0.199, v_ref= 0.044, time_p = 25.312495, P_tot = 0.415753
# EPOCH = 867457.634462, wall = 113.55 ms, jitter = 113.55 ms  delta c=+51, v= 0.199, v_ref= 0.044, time_p = 25.437495, P_tot = 0.415830
# EPOCH = 867457.763563, wall = 129.10 ms, jitter = 129.10 ms  delta c=+51, v= 0.199, v_ref= 0.044, time_p = 25.562495, P_tot = 0.415648
# EPOCH = 867457.878532, wall = 114.97 ms, jitter = 114.97 ms  delta c=+52, v= 0.203, v_ref= 0.044, time_p = 25.687495, P_tot = 0.415765
# EPOCH = 867458.020995, wall = 142.46 ms, jitter = 142.46 ms  delta c=+51, v= 0.199, v_ref= 0.044, time_p = 25.812495, P_tot = 0.415770
# EPOCH = 867458.112996, wall =  92.00 ms, jitter =  92.00 ms  delta c=+51, v= 0.199, v_ref= 0.044, time_p = 25.937495, P_tot = 0.415790
# EPOCH = 867458.274071, wall = 161.08 ms, jitter = 161.08 ms  delta c=+51, v= 0.199, v_ref= 0.047, time_p = 26.062495, P_tot = 0.415747
# EPOCH = 867458.390619, wall = 116.55 ms, jitter = 116.55 ms  delta c=+51, v= 0.199, v_ref= 0.047, time_p = 26.187495, P_tot = 0.415736
# EPOCH = 867458.538605, wall = 147.99 ms, jitter = 147.99 ms  delta c=+52, v= 0.203, v_ref= 0.047, time_p = 26.312495, P_tot = 0.415735
# EPOCH = 867458.631657, wall =  93.05 ms, jitter =  93.05 ms  delta c=+51, v= 0.199, v_ref= 0.047, time_p = 26.437495, P_tot = 0.415764
# EPOCH = 867458.764723, wall = 133.07 ms, jitter = 133.07 ms  delta c=+51, v= 0.199, v_ref= 0.047, time_p = 26.562495, P_tot = 0.415723
# EPOCH = 867458.889076, wall = 124.35 ms, jitter = 124.35 ms  delta c=+51, v= 0.199, v_ref= 0.047, time_p = 26.687495, P_tot = 0.415756
# EPOCH = 867459.003580, wall = 114.50 ms, jitter = 114.50 ms  delta c=+51, v= 0.199, v_ref= 0.047, time_p = 26.812495, P_tot = 0.415756
# EPOCH = 867459.145752, wall = 142.17 ms, jitter = 142.17 ms  delta c=+52, v= 0.203, v_ref= 0.047, time_p = 26.937495, P_tot = 0.415767
# EPOCH = 867459.299763, wall = 154.01 ms, jitter = 154.01 ms  delta c=+51, v= 0.199, v_ref= 0.050, time_p = 27.062495, P_tot = 0.415754
# EPOCH = 867459.368033, wall =  68.27 ms, jitter =  68.27 ms  delta c=+51, v= 0.199, v_ref= 0.050, time_p = 27.187495, P_tot = 0.415729
# EPOCH = 867459.574989, wall = 206.96 ms, jitter = 206.96 ms  delta c=+51, v= 0.199, v_ref= 0.050, time_p = 27.312495, P_tot = 0.415722
# EPOCH = 867459.650673, wall =  75.68 ms, jitter =  75.68 ms  delta c=+51, v= 0.199, v_ref= 0.050, time_p = 27.437495, P_tot = 0.415741
# EPOCH = 867459.918632, wall = 267.96 ms, jitter = 267.96 ms  delta c=+52, v= 0.203, v_ref= 0.050, time_p = 27.562495, P_tot = 0.415770
# EPOCH = 867460.015505, wall =  96.87 ms, jitter =  96.87 ms  delta c=+51, v= 0.199, v_ref= 0.050, time_p = 27.687495, P_tot = 0.415740
# EPOCH = 867460.139373, wall = 123.87 ms, jitter = 123.87 ms  delta c=+51, v= 0.199, v_ref= 0.050, time_p = 27.812495, P_tot = 0.415729
# EPOCH = 867460.259536, wall = 120.16 ms, jitter = 120.16 ms  delta c=+51, v= 0.199, v_ref= 0.050, time_p = 27.937495, P_tot = 0.415788
# EPOCH = 867460.430620, wall = 171.08 ms, jitter = 171.08 ms  delta c=+51, v= 0.199, v_ref= 0.053, time_p = 28.062495, P_tot = 0.415794
# EPOCH = 867460.713516, wall = 282.90 ms, jitter = 282.90 ms  delta c=+52, v= 0.203, v_ref= 0.053, time_p = 28.187495, P_tot = 0.415707
# EPOCH = 867460.814380, wall = 100.86 ms, jitter = 100.86 ms  delta c=+51, v= 0.199, v_ref= 0.053, time_p = 28.312495, P_tot = 0.415730
# EPOCH = 867461.029654, wall = 215.27 ms, jitter = 215.27 ms  delta c=+51, v= 0.199, v_ref= 0.053, time_p = 28.437495, P_tot = 0.415826
# EPOCH = 867461.204037, wall = 174.38 ms, jitter = 174.38 ms  delta c=+51, v= 0.199, v_ref= 0.053, time_p = 28.562495, P_tot = 0.415796
# EPOCH = 867461.285202, wall =  81.16 ms, jitter =  81.16 ms  delta c=+51, v= 0.199, v_ref= 0.053, time_p = 28.687495, P_tot = 0.415714
# EPOCH = 867461.396936, wall = 111.73 ms, jitter = 111.73 ms  delta c=+52, v= 0.203, v_ref= 0.053, time_p = 28.812495, P_tot = 0.415740
# EPOCH = 867461.509013, wall = 112.08 ms, jitter = 112.08 ms  delta c=+51, v= 0.199, v_ref= 0.053, time_p = 28.937495, P_tot = 0.415731
# EPOCH = 867461.739709, wall = 230.70 ms, jitter = 230.70 ms  delta c=+51, v= 0.199, v_ref= 0.056, time_p = 29.062495, P_tot = 0.415724
# EPOCH = 867461.893641, wall = 153.93 ms, jitter = 153.93 ms  delta c=+51, v= 0.199, v_ref= 0.056, time_p = 29.187495, P_tot = 0.415749
# EPOCH = 867462.035102, wall = 141.46 ms, jitter = 141.46 ms  delta c=+51, v= 0.199, v_ref= 0.056, time_p = 29.312495, P_tot = 0.415679
# EPOCH = 867462.164059, wall = 128.96 ms, jitter = 128.96 ms  delta c=+52, v= 0.203, v_ref= 0.056, time_p = 29.437495, P_tot = 0.415813
# EPOCH = 867462.375781, wall = 211.72 ms, jitter = 211.72 ms  delta c=+51, v= 0.199, v_ref= 0.056, time_p = 29.562495, P_tot = 0.415770
# EPOCH = 867462.500975, wall = 125.19 ms, jitter = 125.19 ms  delta c=+51, v= 0.199, v_ref= 0.056, time_p = 29.687495, P_tot = 0.415651
# EPOCH = 867462.627443, wall = 126.47 ms, jitter = 126.47 ms  delta c=+51, v= 0.199, v_ref= 0.056, time_p = 29.812495, P_tot = 0.415733
# EPOCH = 867462.763258, wall = 135.81 ms, jitter = 135.81 ms  delta c=+51, v= 0.199, v_ref= 0.056, time_p = 29.937495, P_tot = 0.415778
# EPOCH = 867462.939611, wall = 176.35 ms, jitter = 176.35 ms  delta c=+52, v= 0.203, v_ref= 0.058, time_p = 30.062495, P_tot = 0.415792
# EPOCH = 867463.033663, wall =  94.05 ms, jitter =  94.05 ms  delta c=+51, v= 0.199, v_ref= 0.058, time_p = 30.187495, P_tot = 0.415715
# EPOCH = 867463.159058, wall = 125.40 ms, jitter = 125.40 ms  delta c=+51, v= 0.199, v_ref= 0.058, time_p = 30.312495, P_tot = 0.415741
# EPOCH = 867463.273477, wall = 114.42 ms, jitter = 114.42 ms  delta c=+51, v= 0.199, v_ref= 0.058, time_p = 30.437495, P_tot = 0.415778
# EPOCH = 867463.413643, wall = 140.17 ms, jitter = 140.17 ms  delta c=+51, v= 0.199, v_ref= 0.058, time_p = 30.562495, P_tot = 0.415727
# EPOCH = 867463.567358, wall = 153.72 ms, jitter = 153.72 ms  delta c=+52, v= 0.203, v_ref= 0.058, time_p = 30.687495, P_tot = 0.415902
# EPOCH = 867463.633793, wall =  66.43 ms, jitter =  66.43 ms  delta c=+51, v= 0.199, v_ref= 0.058, time_p = 30.812495, P_tot = 0.415849
# EPOCH = 867463.801158, wall = 167.36 ms, jitter = 167.36 ms  delta c=+51, v= 0.199, v_ref= 0.058, time_p = 30.937495, P_tot = 0.415779
# EPOCH = 867464.027061, wall = 225.90 ms, jitter = 225.90 ms  delta c=+51, v= 0.199, v_ref= 0.061, time_p = 31.062495, P_tot = 0.415710
# EPOCH = 867464.142414, wall = 115.35 ms, jitter = 115.35 ms  delta c=+51, v= 0.199, v_ref= 0.061, time_p = 31.187495, P_tot = 0.415819
# EPOCH = 867464.251656, wall = 109.24 ms, jitter = 109.24 ms  delta c=+52, v= 0.203, v_ref= 0.061, time_p = 31.312495, P_tot = 0.415778
# EPOCH = 867464.370506, wall = 118.85 ms, jitter = 118.85 ms  delta c=+51, v= 0.199, v_ref= 0.061, time_p = 31.437495, P_tot = 0.415704
# EPOCH = 867464.555663, wall = 185.16 ms, jitter = 185.16 ms  delta c=+51, v= 0.199, v_ref= 0.061, time_p = 31.562495, P_tot = 0.415737
# EPOCH = 867464.755279, wall = 199.62 ms, jitter = 199.62 ms  delta c=+51, v= 0.199, v_ref= 0.061, time_p = 31.687495, P_tot = 0.415760
# EPOCH = 867464.924597, wall = 169.32 ms, jitter = 169.32 ms  delta c=+51, v= 0.199, v_ref= 0.061, time_p = 31.812495, P_tot = 0.415819
# EPOCH = 867465.015781, wall =  91.18 ms, jitter =  91.18 ms  delta c=+52, v= 0.203, v_ref= 0.061, time_p = 31.937495, P_tot = 0.415700
# EPOCH = 867465.131615, wall = 115.83 ms, jitter = 115.83 ms  delta c=+51, v= 0.199, v_ref= 0.064, time_p = 32.062494, P_tot = 0.415739
# EPOCH = 867465.340345, wall = 208.73 ms, jitter = 208.73 ms  delta c=+51, v= 0.199, v_ref= 0.064, time_p = 32.187494, P_tot = 0.415739
# EPOCH = 867465.544858, wall = 204.51 ms, jitter = 204.51 ms  delta c=+51, v= 0.199, v_ref= 0.064, time_p = 32.312494, P_tot = 0.415777
# EPOCH = 867465.646765, wall = 101.91 ms, jitter = 101.91 ms  delta c=+51, v= 0.199, v_ref= 0.064, time_p = 32.437494, P_tot = 0.415765
# EPOCH = 867465.919630, wall = 272.87 ms, jitter = 272.87 ms  delta c=+52, v= 0.203, v_ref= 0.064, time_p = 32.562494, P_tot = 0.415786
# EPOCH = 867466.041506, wall = 121.88 ms, jitter = 121.88 ms  delta c=+51, v= 0.199, v_ref= 0.064, time_p = 32.687494, P_tot = 0.415759
# EPOCH = 867466.149761, wall = 108.26 ms, jitter = 108.26 ms  delta c=+51, v= 0.199, v_ref= 0.064, time_p = 32.812494, P_tot = 0.415766
# EPOCH = 867466.290807, wall = 141.05 ms, jitter = 141.05 ms  delta c=+51, v= 0.199, v_ref= 0.064, time_p = 32.937494, P_tot = 0.415719
# EPOCH = 867466.393271, wall = 102.46 ms, jitter = 102.46 ms  delta c=+51, v= 0.199, v_ref= 0.067, time_p = 33.062494, P_tot = 0.415710
# EPOCH = 867466.650746, wall = 257.47 ms, jitter = 257.47 ms  delta c=+52, v= 0.203, v_ref= 0.067, time_p = 33.187494, P_tot = 0.415715
# EPOCH = 867466.788483, wall = 137.74 ms, jitter = 137.74 ms  delta c=+51, v= 0.199, v_ref= 0.067, time_p = 33.312494, P_tot = 0.415756
# EPOCH = 867466.882012, wall =  93.53 ms, jitter =  93.53 ms  delta c=+51, v= 0.199, v_ref= 0.067, time_p = 33.437494, P_tot = 0.415728
# EPOCH = 867467.175486, wall = 293.47 ms, jitter = 293.47 ms  delta c=+51, v= 0.199, v_ref= 0.067, time_p = 33.562494, P_tot = 0.415710
# EPOCH = 867467.244061, wall =  68.58 ms, jitter =  68.58 ms  delta c=+51, v= 0.199, v_ref= 0.067, time_p = 33.687494, P_tot = 0.415809
# EPOCH = 867467.407240, wall = 163.18 ms, jitter = 163.18 ms  delta c=+52, v= 0.203, v_ref= 0.067, time_p = 33.812494, P_tot = 0.415662
# EPOCH = 867467.559611, wall = 152.37 ms, jitter = 152.37 ms  delta c=+51, v= 0.199, v_ref= 0.067, time_p = 33.937494, P_tot = 0.415708
# EPOCH = 867467.774600, wall = 214.99 ms, jitter = 214.99 ms  delta c=+51, v= 0.199, v_ref= 0.069, time_p = 34.062494, P_tot = 0.415733
# EPOCH = 867467.899446, wall = 124.85 ms, jitter = 124.85 ms  delta c=+51, v= 0.199, v_ref= 0.069, time_p = 34.187494, P_tot = 0.415688
# EPOCH = 867468.038529, wall = 139.08 ms, jitter = 139.08 ms  delta c=+51, v= 0.199, v_ref= 0.069, time_p = 34.312494, P_tot = 0.415780
# EPOCH = 867468.116553, wall =  78.02 ms, jitter =  78.02 ms  delta c=+52, v= 0.203, v_ref= 0.069, time_p = 34.437494, P_tot = 0.415723
# EPOCH = 867468.276202, wall = 159.65 ms, jitter = 159.65 ms  delta c=+51, v= 0.199, v_ref= 0.069, time_p = 34.562494, P_tot = 0.415675
# EPOCH = 867468.409934, wall = 133.73 ms, jitter = 133.73 ms  delta c=+51, v= 0.199, v_ref= 0.069, time_p = 34.687494, P_tot = 0.415797
# EPOCH = 867468.488520, wall =  78.59 ms, jitter =  78.59 ms  delta c=+51, v= 0.199, v_ref= 0.069, time_p = 34.812494, P_tot = 0.415812
# EPOCH = 867468.637565, wall = 149.04 ms, jitter = 149.04 ms  delta c=+51, v= 0.199, v_ref= 0.069, time_p = 34.937494, P_tot = 0.415783
# EPOCH = 867468.772870, wall = 135.31 ms, jitter = 135.31 ms  delta c=+52, v= 0.203, v_ref= 0.072, time_p = 35.062494, P_tot = 0.415767
# EPOCH = 867468.914232, wall = 141.36 ms, jitter = 141.36 ms  delta c=+51, v= 0.199, v_ref= 0.072, time_p = 35.187494, P_tot = 0.415702
# EPOCH = 867469.043577, wall = 129.34 ms, jitter = 129.34 ms  delta c=+51, v= 0.199, v_ref= 0.072, time_p = 35.312494, P_tot = 0.415749
# EPOCH = 867469.115999, wall =  72.42 ms, jitter =  72.42 ms  delta c=+51, v= 0.199, v_ref= 0.072, time_p = 35.437494, P_tot = 0.415730
# EPOCH = 867469.276748, wall = 160.75 ms, jitter = 160.75 ms  delta c=+51, v= 0.199, v_ref= 0.072, time_p = 35.562494, P_tot = 0.415719
# EPOCH = 867469.394643, wall = 117.89 ms, jitter = 117.89 ms  delta c=+52, v= 0.203, v_ref= 0.072, time_p = 35.687494, P_tot = 0.415726
# EPOCH = 867469.572055, wall = 177.41 ms, jitter = 177.41 ms  delta c=+51, v= 0.199, v_ref= 0.072, time_p = 35.812494, P_tot = 0.415665
# EPOCH = 867469.644524, wall =  72.47 ms, jitter =  72.47 ms  delta c=+51, v= 0.199, v_ref= 0.072, time_p = 35.937494, P_tot = 0.415701
# EPOCH = 867469.802798, wall = 158.27 ms, jitter = 158.27 ms  delta c=+51, v= 0.199, v_ref= 0.075, time_p = 36.062494, P_tot = 0.415800
# EPOCH = 867470.002822, wall = 200.02 ms, jitter = 200.02 ms  delta c=+51, v= 0.199, v_ref= 0.075, time_p = 36.187494, P_tot = 0.415760
# EPOCH = 867470.148132, wall = 145.31 ms, jitter = 145.31 ms  delta c=+52, v= 0.203, v_ref= 0.075, time_p = 36.312494, P_tot = 0.415812
# EPOCH = 867470.268406, wall = 120.27 ms, jitter = 120.27 ms  delta c=+51, v= 0.199, v_ref= 0.075, time_p = 36.437494, P_tot = 0.415749
# EPOCH = 867470.406025, wall = 137.62 ms, jitter = 137.62 ms  delta c=+51, v= 0.199, v_ref= 0.075, time_p = 36.562494, P_tot = 0.415718
# EPOCH = 867470.527924, wall = 121.90 ms, jitter = 121.90 ms  delta c=+51, v= 0.199, v_ref= 0.075, time_p = 36.687494, P_tot = 0.415744
# EPOCH = 867470.644221, wall = 116.30 ms, jitter = 116.30 ms  delta c=+51, v= 0.199, v_ref= 0.075, time_p = 36.812494, P_tot = 0.415823
# EPOCH = 867470.747117, wall = 102.90 ms, jitter = 102.90 ms  delta c=+52, v= 0.203, v_ref= 0.075, time_p = 36.937494, P_tot = 0.415781
# EPOCH = 867470.874536, wall = 127.42 ms, jitter = 127.42 ms  delta c=+51, v= 0.199, v_ref= 0.078, time_p = 37.062494, P_tot = 0.415701
# EPOCH = 867471.017597, wall = 143.06 ms, jitter = 143.06 ms  delta c=+51, v= 0.199, v_ref= 0.078, time_p = 37.187494, P_tot = 0.415762
# EPOCH = 867471.125888, wall = 108.29 ms, jitter = 108.29 ms  delta c=+51, v= 0.199, v_ref= 0.078, time_p = 37.312494, P_tot = 0.415745
# EPOCH = 867471.289324, wall = 163.44 ms, jitter = 163.44 ms  delta c=+51, v= 0.199, v_ref= 0.078, time_p = 37.437494, P_tot = 0.415743
# EPOCH = 867471.403258, wall = 113.93 ms, jitter = 113.93 ms  delta c=+52, v= 0.203, v_ref= 0.078, time_p = 37.562494, P_tot = 0.415784
# EPOCH = 867471.524478, wall = 121.22 ms, jitter = 121.22 ms  delta c=+51, v= 0.199, v_ref= 0.078, time_p = 37.687494, P_tot = 0.415717
# EPOCH = 867471.635008, wall = 110.53 ms, jitter = 110.53 ms  delta c=+51, v= 0.199, v_ref= 0.078, time_p = 37.812494, P_tot = 0.415742
# EPOCH = 867471.761455, wall = 126.45 ms, jitter = 126.45 ms  delta c=+51, v= 0.199, v_ref= 0.078, time_p = 37.937494, P_tot = 0.415737
# EPOCH = 867471.955113, wall = 193.66 ms, jitter = 193.66 ms  delta c=+51, v= 0.199, v_ref= 0.081, time_p = 38.062494, P_tot = 0.415740
# EPOCH = 867472.015521, wall =  60.41 ms, jitter =  60.41 ms  delta c=+52, v= 0.203, v_ref= 0.081, time_p = 38.187494, P_tot = 0.415753
# EPOCH = 867472.189122, wall = 173.60 ms, jitter = 173.60 ms  delta c=+51, v= 0.199, v_ref= 0.081, time_p = 38.312494, P_tot = 0.415765
# EPOCH = 867472.403802, wall = 214.68 ms, jitter = 214.68 ms  delta c=+51, v= 0.199, v_ref= 0.081, time_p = 38.437494, P_tot = 0.415728
# EPOCH = 867472.521290, wall = 117.49 ms, jitter = 117.49 ms  delta c=+51, v= 0.199, v_ref= 0.081, time_p = 38.562494, P_tot = 0.415769
# EPOCH = 867472.666597, wall = 145.31 ms, jitter = 145.31 ms  delta c=+51, v= 0.199, v_ref= 0.081, time_p = 38.687494, P_tot = 0.415827
# EPOCH = 867472.799629, wall = 133.03 ms, jitter = 133.03 ms  delta c=+52, v= 0.203, v_ref= 0.081, time_p = 38.812494, P_tot = 0.415759
# EPOCH = 867473.014557, wall = 214.93 ms, jitter = 214.93 ms  delta c=+51, v= 0.199, v_ref= 0.081, time_p = 38.937494, P_tot = 0.415775
# EPOCH = 867473.174192, wall = 159.64 ms, jitter = 159.64 ms  delta c=+51, v= 0.199, v_ref= 0.083, time_p = 39.062494, P_tot = 0.415784
# EPOCH = 867473.394437, wall = 220.24 ms, jitter = 220.24 ms  delta c=+51, v= 0.199, v_ref= 0.083, time_p = 39.187494, P_tot = 0.415741
# EPOCH = 867473.497078, wall = 102.64 ms, jitter = 102.64 ms  delta c=+51, v= 0.199, v_ref= 0.083, time_p = 39.312494, P_tot = 0.415799
# EPOCH = 867473.730137, wall = 233.06 ms, jitter = 233.06 ms  delta c=+52, v= 0.203, v_ref= 0.083, time_p = 39.437494, P_tot = 0.415733
# EPOCH = 867473.824921, wall =  94.78 ms, jitter =  94.78 ms  delta c=+51, v= 0.199, v_ref= 0.083, time_p = 39.562494, P_tot = 0.415747
# EPOCH = 867474.000107, wall = 175.19 ms, jitter = 175.19 ms  delta c=+51, v= 0.199, v_ref= 0.083, time_p = 39.687494, P_tot = 0.415707
# EPOCH = 867474.118860, wall = 118.75 ms, jitter = 118.75 ms  delta c=+51, v= 0.199, v_ref= 0.083, time_p = 39.812494, P_tot = 0.415783
# EPOCH = 867474.268411, wall = 149.55 ms, jitter = 149.55 ms  delta c=+51, v= 0.199, v_ref= 0.083, time_p = 39.937494, P_tot = 0.415708
# EPOCH = 867474.427094, wall = 158.68 ms, jitter = 158.68 ms  delta c=+52, v= 0.203, v_ref= 0.086, time_p = 40.062494, P_tot = 0.415787
# EPOCH = 867474.500541, wall =  73.45 ms, jitter =  73.45 ms  delta c=+51, v= 0.199, v_ref= 0.086, time_p = 40.187494, P_tot = 0.415669
# EPOCH = 867474.671252, wall = 170.71 ms, jitter = 170.71 ms  delta c=+51, v= 0.199, v_ref= 0.086, time_p = 40.312494, P_tot = 0.415722
# EPOCH = 867474.786827, wall = 115.58 ms, jitter = 115.58 ms  delta c=+51, v= 0.199, v_ref= 0.086, time_p = 40.437494, P_tot = 0.415681
# EPOCH = 867474.905362, wall = 118.53 ms, jitter = 118.53 ms  delta c=+51, v= 0.199, v_ref= 0.086, time_p = 40.562494, P_tot = 0.415749
# EPOCH = 867475.026330, wall = 120.97 ms, jitter = 120.97 ms  delta c=+52, v= 0.203, v_ref= 0.086, time_p = 40.687494, P_tot = 0.415697
# EPOCH = 867475.121067, wall =  94.74 ms, jitter =  94.74 ms  delta c=+51, v= 0.199, v_ref= 0.086, time_p = 40.812494, P_tot = 0.415706
# EPOCH = 867475.262245, wall = 141.18 ms, jitter = 141.18 ms  delta c=+51, v= 0.199, v_ref= 0.086, time_p = 40.937494, P_tot = 0.415809
# EPOCH = 867475.426737, wall = 164.49 ms, jitter = 164.49 ms  delta c=+51, v= 0.199, v_ref= 0.089, time_p = 41.062494, P_tot = 0.415693
# EPOCH = 867475.504657, wall =  77.92 ms, jitter =  77.92 ms  delta c=+51, v= 0.199, v_ref= 0.089, time_p = 41.187494, P_tot = 0.415709
# EPOCH = 867475.653331, wall = 148.67 ms, jitter = 148.67 ms  delta c=+52, v= 0.203, v_ref= 0.089, time_p = 41.312494, P_tot = 0.415797
# EPOCH = 867475.756898, wall = 103.57 ms, jitter = 103.57 ms  delta c=+51, v= 0.199, v_ref= 0.089, time_p = 41.437494, P_tot = 0.415730
# EPOCH = 867475.886041, wall = 129.14 ms, jitter = 129.14 ms  delta c=+51, v= 0.199, v_ref= 0.089, time_p = 41.562494, P_tot = 0.415723
# EPOCH = 867476.017242, wall = 131.20 ms, jitter = 131.20 ms  delta c=+51, v= 0.199, v_ref= 0.089, time_p = 41.687494, P_tot = 0.415770
# EPOCH = 867476.131360, wall = 114.12 ms, jitter = 114.12 ms  delta c=+51, v= 0.199, v_ref= 0.089, time_p = 41.812494, P_tot = 0.415752
# EPOCH = 867476.282514, wall = 151.15 ms, jitter = 151.15 ms  delta c=+52, v= 0.203, v_ref= 0.089, time_p = 41.937494, P_tot = 0.415739
# EPOCH = 867476.361829, wall =  79.31 ms, jitter =  79.31 ms  delta c=+51, v= 0.199, v_ref= 0.092, time_p = 42.062494, P_tot = 0.415833
# EPOCH = 867476.518993, wall = 157.16 ms, jitter = 157.16 ms  delta c=+51, v= 0.199, v_ref= 0.092, time_p = 42.187494, P_tot = 0.415736
# EPOCH = 867476.643522, wall = 124.53 ms, jitter = 124.53 ms  delta c=+51, v= 0.199, v_ref= 0.092, time_p = 42.312494, P_tot = 0.415776
# EPOCH = 867476.763217, wall = 119.69 ms, jitter = 119.69 ms  delta c=+51, v= 0.199, v_ref= 0.092, time_p = 42.437494, P_tot = 0.415682
# EPOCH = 867476.896779, wall = 133.56 ms, jitter = 133.56 ms  delta c=+52, v= 0.203, v_ref= 0.092, time_p = 42.562494, P_tot = 0.415799
# EPOCH = 867477.029545, wall = 132.77 ms, jitter = 132.77 ms  delta c=+51, v= 0.199, v_ref= 0.092, time_p = 42.687494, P_tot = 0.415736
# EPOCH = 867477.149595, wall = 120.05 ms, jitter = 120.05 ms  delta c=+51, v= 0.199, v_ref= 0.092, time_p = 42.812494, P_tot = 0.415787
# EPOCH = 867477.247731, wall =  98.14 ms, jitter =  98.14 ms  delta c=+51, v= 0.199, v_ref= 0.092, time_p = 42.937494, P_tot = 0.415730
# EPOCH = 867477.407405, wall = 159.67 ms, jitter = 159.67 ms  delta c=+51, v= 0.199, v_ref= 0.094, time_p = 43.062494, P_tot = 0.415720
# EPOCH = 867477.522638, wall = 115.23 ms, jitter = 115.23 ms  delta c=+52, v= 0.203, v_ref= 0.094, time_p = 43.187494, P_tot = 0.415828
# EPOCH = 867477.631798, wall = 109.16 ms, jitter = 109.16 ms  delta c=+51, v= 0.199, v_ref= 0.094, time_p = 43.312494, P_tot = 0.415717
# EPOCH = 867477.767769, wall = 135.97 ms, jitter = 135.97 ms  delta c=+51, v= 0.199, v_ref= 0.094, time_p = 43.437494, P_tot = 0.415810
# EPOCH = 867478.011433, wall = 243.66 ms, jitter = 243.66 ms  delta c=+51, v= 0.199, v_ref= 0.094, time_p = 43.562494, P_tot = 0.415732
# EPOCH = 867478.143253, wall = 131.82 ms, jitter = 131.82 ms  delta c=+51, v= 0.199, v_ref= 0.094, time_p = 43.687494, P_tot = 0.415720
# EPOCH = 867478.256166, wall = 112.91 ms, jitter = 112.91 ms  delta c=+52, v= 0.203, v_ref= 0.094, time_p = 43.812494, P_tot = 0.415829
# EPOCH = 867478.391239, wall = 135.07 ms, jitter = 135.07 ms  delta c=+51, v= 0.199, v_ref= 0.094, time_p = 43.937494, P_tot = 0.415739
# EPOCH = 867478.511812, wall = 120.57 ms, jitter = 120.57 ms  delta c=+51, v= 0.199, v_ref= 0.097, time_p = 44.062494, P_tot = 0.415686
# EPOCH = 867478.642904, wall = 131.09 ms, jitter = 131.09 ms  delta c=+51, v= 0.199, v_ref= 0.097, time_p = 44.187494, P_tot = 0.415783
# EPOCH = 867478.748713, wall = 105.81 ms, jitter = 105.81 ms  delta c=+51, v= 0.199, v_ref= 0.097, time_p = 44.312494, P_tot = 0.415752
# ...
# EPOCH = 867511.777166, wall = 133.09 ms, jitter = 133.09 ms  delta c=+51, v= 0.199, v_ref= 0.183, time_p = 75.312496, P_tot = 0.415777
# EPOCH = 867511.886041, wall = 108.87 ms, jitter = 108.87 ms  delta c=+51, v= 0.199, v_ref= 0.183, time_p = 75.437496, P_tot = 0.415799
# EPOCH = 867512.018595, wall = 132.55 ms, jitter = 132.55 ms  delta c=+51, v= 0.199, v_ref= 0.183, time_p = 75.562496, P_tot = 0.415732
# EPOCH = 867512.149555, wall = 130.96 ms, jitter = 130.96 ms  delta c=+52, v= 0.203, v_ref= 0.183, time_p = 75.687496, P_tot = 0.415748
# EPOCH = 867512.284914, wall = 135.36 ms, jitter = 135.36 ms  delta c=+51, v= 0.199, v_ref= 0.183, time_p = 75.812496, P_tot = 0.415734
# EPOCH = 867512.397362, wall = 112.45 ms, jitter = 112.45 ms  delta c=+51, v= 0.199, v_ref= 0.183, time_p = 75.937496, P_tot = 0.415769
# EPOCH = 867512.499789, wall = 102.43 ms, jitter = 102.43 ms  delta c=+51, v= 0.199, v_ref= 0.186, time_p = 76.062496, P_tot = 0.415750
# EPOCH = 867512.659146, wall = 159.36 ms, jitter = 159.36 ms  delta c=+51, v= 0.199, v_ref= 0.186, time_p = 76.187496, P_tot = 0.415799
# EPOCH = 867512.747573, wall =  88.43 ms, jitter =  88.43 ms  delta c=+52, v= 0.203, v_ref= 0.186, time_p = 76.312496, P_tot = 0.415733
# EPOCH = 867512.896665, wall = 149.09 ms, jitter = 149.09 ms  delta c=+51, v= 0.199, v_ref= 0.186, time_p = 76.437496, P_tot = 0.415770
# EPOCH = 867513.030943, wall = 134.28 ms, jitter = 134.28 ms  delta c=+51, v= 0.199, v_ref= 0.186, time_p = 76.562496, P_tot = 0.415711
# EPOCH = 867513.134311, wall = 103.37 ms, jitter = 103.37 ms  delta c=+51, v= 0.199, v_ref= 0.186, time_p = 76.687496, P_tot = 0.415748
# EPOCH = 867513.275460, wall = 141.15 ms, jitter = 141.15 ms  delta c=+51, v= 0.199, v_ref= 0.186, time_p = 76.812496, P_tot = 0.415733
# EPOCH = 867513.396555, wall = 121.10 ms, jitter = 121.10 ms  delta c=+52, v= 0.203, v_ref= 0.186, time_p = 76.937496, P_tot = 0.415756
# EPOCH = 867513.509627, wall = 113.07 ms, jitter = 113.07 ms  delta c=+51, v= 0.199, v_ref= 0.189, time_p = 77.062496, P_tot = 0.415735
# EPOCH = 867513.627700, wall = 118.07 ms, jitter = 118.07 ms  delta c=+51, v= 0.199, v_ref= 0.189, time_p = 77.187496, P_tot = 0.415828
# EPOCH = 867513.785935, wall = 158.24 ms, jitter = 158.24 ms  delta c=+51, v= 0.199, v_ref= 0.189, time_p = 77.312496, P_tot = 0.415759
# EPOCH = 867513.873063, wall =  87.13 ms, jitter =  87.13 ms  delta c=+51, v= 0.199, v_ref= 0.189, time_p = 77.437496, P_tot = 0.415826
# EPOCH = 867514.014554, wall = 141.49 ms, jitter = 141.49 ms  delta c=+52, v= 0.203, v_ref= 0.189, time_p = 77.562496, P_tot = 0.415776
# EPOCH = 867514.154034, wall = 139.48 ms, jitter = 139.48 ms  delta c=+51, v= 0.199, v_ref= 0.189, time_p = 77.687496, P_tot = 0.415849
# EPOCH = 867514.270158, wall = 116.12 ms, jitter = 116.12 ms  delta c=+51, v= 0.199, v_ref= 0.189, time_p = 77.812496, P_tot = 0.415790
# EPOCH = 867514.381018, wall = 110.86 ms, jitter = 110.86 ms  delta c=+51, v= 0.199, v_ref= 0.189, time_p = 77.937496, P_tot = 0.415797
# EPOCH = 867514.507651, wall = 126.63 ms, jitter = 126.63 ms  delta c=+51, v= 0.199, v_ref= 0.192, time_p = 78.062496, P_tot = 0.415762
# EPOCH = 867514.661143, wall = 153.49 ms, jitter = 153.49 ms  delta c=+52, v= 0.203, v_ref= 0.192, time_p = 78.187496, P_tot = 0.415725
# EPOCH = 867514.794180, wall = 133.04 ms, jitter = 133.04 ms  delta c=+51, v= 0.199, v_ref= 0.192, time_p = 78.312496, P_tot = 0.415814
# EPOCH = 867514.896057, wall = 101.88 ms, jitter = 101.88 ms  delta c=+51, v= 0.199, v_ref= 0.192, time_p = 78.437496, P_tot = 0.415727
# EPOCH = 867515.146082, wall = 250.02 ms, jitter = 250.02 ms  delta c=+51, v= 0.199, v_ref= 0.192, time_p = 78.562496, P_tot = 0.415760
# EPOCH = 867515.277508, wall = 131.43 ms, jitter = 131.43 ms  delta c=+51, v= 0.199, v_ref= 0.192, time_p = 78.687496, P_tot = 0.415775
# EPOCH = 867515.368119, wall =  90.61 ms, jitter =  90.61 ms  delta c=+52, v= 0.203, v_ref= 0.192, time_p = 78.812496, P_tot = 0.415721
# EPOCH = 867515.512343, wall = 144.22 ms, jitter = 144.22 ms  delta c=+51, v= 0.199, v_ref= 0.192, time_p = 78.937496, P_tot = 0.415832
# EPOCH = 867515.620826, wall = 108.48 ms, jitter = 108.48 ms  delta c=+51, v= 0.199, v_ref= 0.194, time_p = 79.062496, P_tot = 0.415774
# EPOCH = 867515.762493, wall = 141.67 ms, jitter = 141.67 ms  delta c=+51, v= 0.199, v_ref= 0.194, time_p = 79.187496, P_tot = 0.415726
# EPOCH = 867515.901971, wall = 139.48 ms, jitter = 139.48 ms  delta c=+51, v= 0.199, v_ref= 0.194, time_p = 79.312496, P_tot = 0.415748
# EPOCH = 867516.019714, wall = 117.74 ms, jitter = 117.74 ms  delta c=+52, v= 0.203, v_ref= 0.194, time_p = 79.437496, P_tot = 0.415707
# EPOCH = 867516.158203, wall = 138.49 ms, jitter = 138.49 ms  delta c=+51, v= 0.199, v_ref= 0.194, time_p = 79.562496, P_tot = 0.415742
# EPOCH = 867516.277712, wall = 119.51 ms, jitter = 119.51 ms  delta c=+51, v= 0.199, v_ref= 0.194, time_p = 79.687496, P_tot = 0.415797
# EPOCH = 867516.371985, wall =  94.27 ms, jitter =  94.27 ms  delta c=+51, v= 0.199, v_ref= 0.194, time_p = 79.812496, P_tot = 0.415775
# EPOCH = 867516.529964, wall = 157.98 ms, jitter = 157.98 ms  delta c=+51, v= 0.199, v_ref= 0.194, time_p = 79.937496, P_tot = 0.415833
# EPOCH = 867516.666109, wall = 136.15 ms, jitter = 136.15 ms  delta c=+52, v= 0.203, v_ref= 0.197, time_p = 80.062496, P_tot = 0.415824
# EPOCH = 867516.798290, wall = 132.18 ms, jitter = 132.18 ms  delta c=+51, v= 0.199, v_ref= 0.197, time_p = 80.187496, P_tot = 0.415670
# EPOCH = 867516.899926, wall = 101.64 ms, jitter = 101.64 ms  delta c=+51, v= 0.199, v_ref= 0.197, time_p = 80.312496, P_tot = 0.415804
# EPOCH = 867517.065579, wall = 165.65 ms, jitter = 165.65 ms  delta c=+51, v= 0.199, v_ref= 0.197, time_p = 80.437496, P_tot = 0.415766
# EPOCH = 867517.267532, wall = 201.95 ms, jitter = 201.95 ms  delta c=+51, v= 0.199, v_ref= 0.197, time_p = 80.562496, P_tot = 0.415811
# EPOCH = 867517.397354, wall = 129.82 ms, jitter = 129.82 ms  delta c=+52, v= 0.203, v_ref= 0.197, time_p = 80.687496, P_tot = 0.415766
# EPOCH = 867517.509245, wall = 111.89 ms, jitter = 111.89 ms  delta c=+51, v= 0.199, v_ref= 0.197, time_p = 80.812496, P_tot = 0.415754
# EPOCH = 867517.647512, wall = 138.27 ms, jitter = 138.27 ms  delta c=+51, v= 0.199, v_ref= 0.197, time_p = 80.937496, P_tot = 0.415787
# EPOCH = 867517.747861, wall = 100.35 ms, jitter = 100.35 ms  delta c=+51, v= 0.199, v_ref= 0.200, time_p = 81.062496, P_tot = 0.415721
# EPOCH = 867517.891303, wall = 143.44 ms, jitter = 143.44 ms  delta c=+51, v= 0.199, v_ref= 0.200, time_p = 81.187496, P_tot = 0.415701
# EPOCH = 867518.022573, wall = 131.27 ms, jitter = 131.27 ms  delta c=+52, v= 0.203, v_ref= 0.200, time_p = 81.312496, P_tot = 0.415729
# EPOCH = 867518.181151, wall = 158.58 ms, jitter = 158.58 ms  delta c=+51, v= 0.199, v_ref= 0.200, time_p = 81.437496, P_tot = 0.415692
# EPOCH = 867518.375016, wall = 193.87 ms, jitter = 193.87 ms  delta c=+51, v= 0.199, v_ref= 0.200, time_p = 81.562496, P_tot = 0.415800
# EPOCH = 867518.517670, wall = 142.65 ms, jitter = 142.65 ms  delta c=+51, v= 0.199, v_ref= 0.200, time_p = 81.687496, P_tot = 0.415732
# EPOCH = 867518.639808, wall = 122.14 ms, jitter = 122.14 ms  delta c=+51, v= 0.199, v_ref= 0.200, time_p = 81.812496, P_tot = 0.415717
# EPOCH = 867518.777954, wall = 138.15 ms, jitter = 138.15 ms  delta c=+52, v= 0.203, v_ref= 0.200, time_p = 81.937496, P_tot = 0.415752
# EPOCH = 867518.904876, wall = 126.92 ms, jitter = 126.92 ms  delta c=+51, v= 0.199, v_ref= 0.203, time_p = 82.062496, P_tot = 0.415772
# EPOCH = 867519.027849, wall = 122.97 ms, jitter = 122.97 ms  delta c=+51, v= 0.199, v_ref= 0.203, time_p = 82.187496, P_tot = 0.415795
# EPOCH = 867519.181859, wall = 154.01 ms, jitter = 154.01 ms  delta c=+51, v= 0.199, v_ref= 0.203, time_p = 82.312496, P_tot = 0.415775
# EPOCH = 867519.260521, wall =  78.66 ms, jitter =  78.66 ms  delta c=+51, v= 0.199, v_ref= 0.203, time_p = 82.437496, P_tot = 0.415711
# EPOCH = 867519.393094, wall = 132.57 ms, jitter = 132.57 ms  delta c=+52, v= 0.203, v_ref= 0.203, time_p = 82.562496, P_tot = 0.415751
# EPOCH = 867519.512703, wall = 119.61 ms, jitter = 119.61 ms  delta c=+51, v= 0.199, v_ref= 0.203, time_p = 82.687496, P_tot = 0.415748
# EPOCH = 867519.626159, wall = 113.46 ms, jitter = 113.46 ms  delta c=+51, v= 0.199, v_ref= 0.203, time_p = 82.812496, P_tot = 0.415776
# EPOCH = 867519.746209, wall = 120.05 ms, jitter = 120.05 ms  delta c=+51, v= 0.199, v_ref= 0.203, time_p = 82.937496, P_tot = 0.415758
# EPOCH = 867519.901728, wall = 155.52 ms, jitter = 155.52 ms  delta c=+51, v= 0.199, v_ref= 0.206, time_p = 83.062496, P_tot = 0.415774
# EPOCH = 867520.047697, wall = 145.97 ms, jitter = 145.97 ms  delta c=+52, v= 0.203, v_ref= 0.206, time_p = 83.187496, P_tot = 0.415770
# EPOCH = 867520.128721, wall =  81.02 ms, jitter =  81.02 ms  delta c=+51, v= 0.199, v_ref= 0.206, time_p = 83.312496, P_tot = 0.415825
# EPOCH = 867520.262055, wall = 133.33 ms, jitter = 133.33 ms  delta c=+51, v= 0.199, v_ref= 0.206, time_p = 83.437496, P_tot = 0.415738
# EPOCH = 867520.394312, wall = 132.26 ms, jitter = 132.26 ms  delta c=+51, v= 0.199, v_ref= 0.206, time_p = 83.562496, P_tot = 0.415733
# EPOCH = 867520.528268, wall = 133.96 ms, jitter = 133.96 ms  delta c=+51, v= 0.199, v_ref= 0.206, time_p = 83.687496, P_tot = 0.415785
# EPOCH = 867520.643018, wall = 114.75 ms, jitter = 114.75 ms  delta c=+52, v= 0.203, v_ref= 0.206, time_p = 83.812496, P_tot = 0.415752
# EPOCH = 867520.768092, wall = 125.07 ms, jitter = 125.07 ms  delta c=+51, v= 0.199, v_ref= 0.206, time_p = 83.937496, P_tot = 0.415778
# EPOCH = 867520.921519, wall = 153.43 ms, jitter = 153.43 ms  delta c=+51, v= 0.199, v_ref= 0.208, time_p = 84.062496, P_tot = 0.415637
# EPOCH = 867521.141155, wall = 219.64 ms, jitter = 219.64 ms  delta c=+51, v= 0.199, v_ref= 0.208, time_p = 84.187496, P_tot = 0.415846
# EPOCH = 867521.276227, wall = 135.07 ms, jitter = 135.07 ms  delta c=+51, v= 0.199, v_ref= 0.208, time_p = 84.312496, P_tot = 0.415724
# EPOCH = 867521.394693, wall = 118.47 ms, jitter = 118.47 ms  delta c=+52, v= 0.203, v_ref= 0.208, time_p = 84.437496, P_tot = 0.415744
# EPOCH = 867521.540258, wall = 145.56 ms, jitter = 145.56 ms  delta c=+51, v= 0.199, v_ref= 0.208, time_p = 84.562496, P_tot = 0.415688
# EPOCH = 867521.660301, wall = 120.04 ms, jitter = 120.04 ms  delta c=+51, v= 0.199, v_ref= 0.208, time_p = 84.687496, P_tot = 0.415676
# EPOCH = 867521.931432, wall = 271.13 ms, jitter = 271.13 ms  delta c=+51, v= 0.199, v_ref= 0.208, time_p = 84.812496, P_tot = 0.415668
# EPOCH = 867522.003058, wall =  71.63 ms, jitter =  71.63 ms  delta c=+51, v= 0.199, v_ref= 0.208, time_p = 84.937496, P_tot = 0.415743
# EPOCH = 867522.143483, wall = 140.42 ms, jitter = 140.42 ms  delta c=+52, v= 0.203, v_ref= 0.211, time_p = 85.062496, P_tot = 0.415691
# EPOCH = 867522.249918, wall = 106.43 ms, jitter = 106.43 ms  delta c=+51, v= 0.199, v_ref= 0.211, time_p = 85.187496, P_tot = 0.415621
# EPOCH = 867522.405463, wall = 155.55 ms, jitter = 155.55 ms  delta c=+51, v= 0.199, v_ref= 0.211, time_p = 85.312496, P_tot = 0.415769
# EPOCH = 867522.506038, wall = 100.58 ms, jitter = 100.58 ms  delta c=+51, v= 0.199, v_ref= 0.211, time_p = 85.437496, P_tot = 0.415704
# EPOCH = 867522.656563, wall = 150.52 ms, jitter = 150.52 ms  delta c=+51, v= 0.199, v_ref= 0.211, time_p = 85.562496, P_tot = 0.415764
# EPOCH = 867522.792272, wall = 135.71 ms, jitter = 135.71 ms  delta c=+52, v= 0.203, v_ref= 0.211, time_p = 85.687496, P_tot = 0.415703
# EPOCH = 867522.871055, wall =  78.78 ms, jitter =  78.78 ms  delta c=+51, v= 0.199, v_ref= 0.211, time_p = 85.812496, P_tot = 0.415737
# EPOCH = 867523.049492, wall = 178.44 ms, jitter = 178.44 ms  delta c=+51, v= 0.199, v_ref= 0.211, time_p = 85.937496, P_tot = 0.415819
# EPOCH = 867523.281151, wall = 231.66 ms, jitter = 231.66 ms  delta c=+51, v= 0.199, v_ref= 0.214, time_p = 86.062496, P_tot = 0.415728
# EPOCH = 867523.367683, wall =  86.53 ms, jitter =  86.53 ms  delta c=+51, v= 0.199, v_ref= 0.214, time_p = 86.187496, P_tot = 0.415728
# EPOCH = 867523.571169, wall = 203.49 ms, jitter = 203.49 ms  delta c=+52, v= 0.203, v_ref= 0.214, time_p = 86.312496, P_tot = 0.415612
# EPOCH = 867523.651831, wall =  80.66 ms, jitter =  80.66 ms  delta c=+51, v= 0.199, v_ref= 0.214, time_p = 86.437496, P_tot = 0.415808
# EPOCH = 867523.958114, wall = 306.28 ms, jitter = 306.28 ms  delta c=+51, v= 0.199, v_ref= 0.214, time_p = 86.562496, P_tot = 0.415717
# EPOCH = 867524.043230, wall =  85.12 ms, jitter =  85.12 ms  delta c=+51, v= 0.199, v_ref= 0.214, time_p = 86.687496, P_tot = 0.415747
# EPOCH = 867524.169432, wall = 126.20 ms, jitter = 126.20 ms  delta c=+51, v= 0.199, v_ref= 0.214, time_p = 86.812496, P_tot = 0.415794
# EPOCH = 867524.414690, wall = 245.26 ms, jitter = 245.26 ms  delta c=+52, v= 0.203, v_ref= 0.214, time_p = 86.937496, P_tot = 0.415778
# EPOCH = 867524.529290, wall = 114.60 ms, jitter = 114.60 ms  delta c=+51, v= 0.199, v_ref= 0.217, time_p = 87.062496, P_tot = 0.415756
# EPOCH = 867524.670007, wall = 140.72 ms, jitter = 140.72 ms  delta c=+51, v= 0.199, v_ref= 0.217, time_p = 87.187496, P_tot = 0.415791
# EPOCH = 867524.756302, wall =  86.29 ms, jitter =  86.29 ms  delta c=+51, v= 0.199, v_ref= 0.217, time_p = 87.312496, P_tot = 0.415817
# EPOCH = 867524.906610, wall = 150.31 ms, jitter = 150.31 ms  delta c=+51, v= 0.199, v_ref= 0.217, time_p = 87.437496, P_tot = 0.415839
# EPOCH = 867525.039332, wall = 132.72 ms, jitter = 132.72 ms  delta c=+52, v= 0.203, v_ref= 0.217, time_p = 87.562496, P_tot = 0.415749
# EPOCH = 867525.171993, wall = 132.66 ms, jitter = 132.66 ms  delta c=+51, v= 0.199, v_ref= 0.217, time_p = 87.687496, P_tot = 0.415775
# EPOCH = 867525.422332, wall = 250.34 ms, jitter = 250.34 ms  delta c=+51, v= 0.199, v_ref= 0.217, time_p = 87.812496, P_tot = 0.415746
# EPOCH = 867525.670634, wall = 248.30 ms, jitter = 248.30 ms  delta c=+51, v= 0.199, v_ref= 0.217, time_p = 87.937496, P_tot = 0.415796
# EPOCH = 867526.031619, wall = 360.99 ms, jitter = 360.99 ms  delta c=+51, v= 0.199, v_ref= 0.219, time_p = 88.062496, P_tot = 0.415796
# EPOCH = 867526.241974, wall = 210.36 ms, jitter = 210.36 ms  delta c=+52, v= 0.203, v_ref= 0.219, time_p = 88.187496, P_tot = 0.415801
# EPOCH = 867526.409084, wall = 167.11 ms, jitter = 167.11 ms  delta c=+51, v= 0.199, v_ref= 0.219, time_p = 88.312496, P_tot = 0.415719
# EPOCH = 867526.542374, wall = 133.29 ms, jitter = 133.29 ms  delta c=+51, v= 0.199, v_ref= 0.219, time_p = 88.437496, P_tot = 0.415747
# EPOCH = 867526.830695, wall = 288.32 ms, jitter = 288.32 ms  delta c=+51, v= 0.199, v_ref= 0.219, time_p = 88.562496, P_tot = 0.415670
# EPOCH = 867526.922352, wall =  91.66 ms, jitter =  91.66 ms  delta c=+51, v= 0.199, v_ref= 0.219, time_p = 88.687496, P_tot = 0.415801
# EPOCH = 867527.195448, wall = 273.10 ms, jitter = 273.10 ms  delta c=+52, v= 0.203, v_ref= 0.219, time_p = 88.812496, P_tot = 0.415780
# EPOCH = 867527.262320, wall =  66.87 ms, jitter =  66.87 ms  delta c=+51, v= 0.199, v_ref= 0.219, time_p = 88.937496, P_tot = 0.415727
# EPOCH = 867527.534748, wall = 272.43 ms, jitter = 272.43 ms  delta c=+51, v= 0.199, v_ref= 0.222, time_p = 89.062496, P_tot = 0.415740
# EPOCH = 867527.638123, wall = 103.37 ms, jitter = 103.37 ms  delta c=+51, v= 0.199, v_ref= 0.222, time_p = 89.187496, P_tot = 0.415711
# EPOCH = 867527.788871, wall = 150.75 ms, jitter = 150.75 ms  delta c=+51, v= 0.199, v_ref= 0.222, time_p = 89.312496, P_tot = 0.415835
# EPOCH = 867527.928175, wall = 139.30 ms, jitter = 139.30 ms  delta c=+52, v= 0.203, v_ref= 0.222, time_p = 89.437496, P_tot = 0.415766
# EPOCH = 867528.162662, wall = 234.49 ms, jitter = 234.49 ms  delta c=+51, v= 0.199, v_ref= 0.222, time_p = 89.562496, P_tot = 0.415741
# EPOCH = 867528.267099, wall = 104.44 ms, jitter = 104.44 ms  delta c=+51, v= 0.199, v_ref= 0.222, time_p = 89.687496, P_tot = 0.415752
# EPOCH = 867528.395944, wall = 128.84 ms, jitter = 128.84 ms  delta c=+51, v= 0.199, v_ref= 0.222, time_p = 89.812496, P_tot = 0.415700
# EPOCH = 867528.597284, wall = 201.34 ms, jitter = 201.34 ms  delta c=+51, v= 0.199, v_ref= 0.222, time_p = 89.937496, P_tot = 0.415796
# Graceful shutdown.
