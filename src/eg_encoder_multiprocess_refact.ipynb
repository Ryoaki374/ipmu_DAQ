# %%
import time, threading, queue, sys, gc
from typing import Tuple

import numpy as np
import pyqtgraph as pg
from PyQt6 import QtCore
from collections import deque

import logging, logging.handlers

import h5py, pathlib
from datetime import datetime

# %% [markdown]
# | **速度目標 [rps]** | **1秒当たり [pulses / s]** | **1iterあたり [pulses]** | **カウント** | **再構成速度 (UP / DOWN) \[rps]** | **偏差 \[%]** |
# | ----------------- | -------------------------- | --------------------------- | ----------------------- | ------------------------------- | -------------------------- |
# | 0.1               | 204.8                      | 25.6                        | 26<br>25                | 0.102<br>0.09765625             | +1.56<br>−2.34             |
# | 0.2               | 409.6                      | 51.2                        | 52<br>51                | 0.203<br>0.19921875             | +1.56<br>−0.39             |
# | 0.3               | 614.4                      | 76.8                        | 77<br>76                | 0.301<br>0.296875               | +0.26<br>−1.04             |
# | 0.4               | 819.2                      | 102.4                       | 103<br>102              | 0.402<br>0.3984375              | +0.59<br>−0.39             |
# | 0.5               | 1 024.0                    | 128.0                       | 128<br>128              | 0.500<br>0.500                  | 0.00<br>0.00               |
# | 0.6               | 1 228.8                    | 153.6                       | 154<br>153              | 0.602<br>0.59765625             | +0.26<br>−0.39             |
# | 0.7               | 1 433.6                    | 179.2                       | 180<br>179              | 0.703<br>0.69921875             | +0.45<br>−0.11             |
# | 0.8               | 1 638.4                    | 204.8                       | 205<br>204              | 0.801<br>0.796875               | +0.10<br>−0.39             |
# | 0.9               | 1 843.2                    | 230.4                       | 231<br>230              | 0.902<br>0.8984375              | +0.26<br>−0.17             |
# | 1.0               | 2 048.0                    | 256.0                       | 256<br>256              | 1.000<br>1.000                  | 0.00<br>0.00               |

# %%
# ------------------------------------------------------------  parameters
DEBUG = True  # set True for jitter log
SAMPLE_RATE = 100_000  # Hz
GEN_CHUNK_SEC = 0.1 # corresponds to PROC_INTERVAL up to 0.05
PROC_INTERVAL = 0.125          # process rate

CHUNK_SEC     = GEN_CHUNK_SEC
N_SAMPLES_GEN = int(SAMPLE_RATE * GEN_CHUNK_SEC) # 100_000 * 0.05 = 5000
SAMPLES_PROC = int(PROC_INTERVAL * SAMPLE_RATE) # 0.125s * 100kHz = 12500
QUEUE_DEPTH = 40  # raw AB backlog
QUAD_DEPTH = 40  # processed backlog (same)
RUN_SEC = 600  # auto‑stop after 10 s
DISPLAY_SEC = RUN_SEC+600
PLOT_SEC = 0.02  # *** fixed x-axis window width (s) ***
GUI_INTERVAL_MS = 50  # update interval (ms) e.g. 50ms = 20Hz

PULSE_HEIGHT = 5.0  # amplitude
INPUT_VELOCITY = 0.1  # rps

PULSE_WIDTH = 1 / (INPUT_VELOCITY * 512)  # period  (s)
PULSE_DUTY = 0.5  # duty
PULSE_PHASE_A = 0.0  # phase offset (s)
PULSE_PHASE_B = -PULSE_WIDTH / 4  # phase offset (s)

QUADPULSE_WIDTH = 0.00025  # width (s) assuming 4x given 1 rps
THRESHOLD_DEFAULT = 2.5  # logic threshold (V)

IDEAL_CPS = INPUT_VELOCITY   # counts/s (constant ideal)

# GUI buffer lengths (empirical)
HISTORY = int(SAMPLE_RATE * PLOT_SEC)
COUNT_HISTORY = int(RUN_SEC / GEN_CHUNK_SEC)
VELO_HISTORY = COUNT_HISTORY

# ------------------------------------------------------------  logging
LOG_CHUNK = 1024       # flush log queue every LOG_CHUNK messages




# ------------------------------------------------------------  queues & stop flag
buf_q = queue.Queue(maxsize=QUEUE_DEPTH)  # raw (t, A, B)
quad_q = queue.Queue(maxsize=QUAD_DEPTH)  # processed (t, A, B, quad)
stop_writer = threading.Event()

log_q = queue.Queue(maxsize=0)
queue_h = logging.handlers.QueueHandler(log_q)
logger = logging.getLogger("debug")
logger.setLevel(logging.INFO)
logger.addHandler(queue_h)

# %%
run_dir = pathlib.Path("../runs")
run_dir.mkdir(exist_ok=True)
timestamp = datetime.now().strftime("%y%m%d%H%M%S")
h5path = f"{run_dir}/{timestamp}.h5"

h5f = h5py.File(h5path, "w")
dset = h5f.create_dataset(
    "log", shape=(0, 3), maxshape=(None, 3),
    dtype=np.float32, chunks=(LOG_CHUNK, 3), compression="gzip"
)

print("dset shape  =", dset.shape)
print("dset maxshape =", dset.maxshape)
# Out:
# dset shape  = (0, 3)
# dset maxshape = (None, 3)

# %%
def gen_chunk_pulse(
    t: np.ndarray,
    *,
    height: float = PULSE_HEIGHT,
    width: float = PULSE_WIDTH,
    duty: float = PULSE_DUTY,
    phase: float = 0.0,
) -> np.ndarray:
    mod = (t + phase) % width
    return np.where(mod < duty * width, height, 0.0).astype(np.float32)


REL_AXIS_GEN = (
    np.arange(N_SAMPLES_GEN, dtype=np.float32) / SAMPLE_RATE
)  # 0 ... 0.2 s

# ------------------------------------------------------------  AB → direction → quad helpers


def gen_pulse_direction(
    dA: np.ndarray,
    dB: np.ndarray,
    *,
    threshold: float,
    prev_A: bool | None = None,
    prev_B: bool | None = None,
) -> tuple[np.ndarray, bool, bool]:
    """
    Detect direction for one block **with perfect edge coverage**.

    Parameters
    ----------
    dA, dB : ndarray[float32]
        Analog levels of phase-A / phase-B for the current block.
    threshold : float
        Logic threshold [V].
    prev_A, prev_B : bool | None
        Logical state of A/B *at the end of the PREVIOUS block*.
        • If None (first block), the function falls back to the
          “self-shift” method used before.

    Returns
    -------
    dir_log : ndarray[int8]
        +1 = CW edge, –1 = CCW edge, 0 = no edge.
    last_A, last_B : bool
        Logical state of A/B at the *end* of this block — feed these
        into the next call to avoid losing the boundary edge.
    """
    # --- current logic level ----------------------------------------
    A = dA > threshold
    B = dB > threshold

    # --- previous sample for XOR -----------------------------------
    if prev_A is None:  # first block → old behaviour
        A_prev = np.concatenate(([A[0]], A[:-1]))
        B_prev = np.concatenate(([B[0]], B[:-1]))
    else:               # use states carried over from last block
        A_prev = np.concatenate(([prev_A], A[:-1]))
        B_prev = np.concatenate(([prev_B], B[:-1]))

    dir_log = (B_prev ^ A).astype(int) - (A_prev ^ B).astype(int)

    return dir_log.astype(np.int8), bool(A[-1]), bool(B[-1])

def pulse_count(dir_log: np.ndarray) -> int:
    #return int(np.sum(dir_log))
    return np.sum(dir_log)


def gen_quad_pulse(
    t: np.ndarray, dir_log: np.ndarray, width: float, height: float, sampling_rate: int
) -> np.ndarray:
    samples = int(width * sampling_rate)
    if samples <= 0:
        return np.zeros_like(dir_log, dtype=np.float32)
    base = np.full(samples, height, dtype=np.float32)
    return np.convolve(dir_log, base, mode="full")[: len(t)]


# ------------------------------------------------------------  producer thread
def generator() -> None:
    """Generate AB rectangular-wave chunks at real-time cadence."""
    chunk_idx = 0
    next_t = time.perf_counter()
    while not stop_writer.is_set():
        base = chunk_idx * GEN_CHUNK_SEC
        t_axis = REL_AXIS_GEN + base
        pulse_A = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_A)
        pulse_B = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_B)
        try:
            buf_q.put_nowait((t_axis, pulse_A, pulse_B))
        except queue.Full:
            pass

        chunk_idx += 1
        next_t += GEN_CHUNK_SEC
        sleep = next_t - time.perf_counter()
        if sleep > 0:
            time.sleep(sleep)
        else:
            next_t = time.perf_counter()


# ------------------------------------------------------------  consumer thread
def log_listener():
    handler = logging.StreamHandler(sys.stdout)
    listener = logging.handlers.QueueListener(log_q, handler)
    listener.start()
    stop_writer.wait()
    listener.stop()

def command_freq(t_DC, step, rst, target_freq, proc_interval):

    time = np.arange(0, t_DC+36000*target_freq/(step/rst)+60*60*2, proc_interval, dtype=np.float32)
    freq = np.zeros(int((t_DC+36000*target_freq/(step/rst)+60*60*2)*(1/proc_interval)), dtype=np.float32)

    # Refactoring suggestions
    # 1. Use numpy's vectorized operations instead of loops for better performance.
    # eg. precomupte the indices and use numpy's advanced indexing
    # n_dc       = int(np.round(t_dc / sample_dt))
    # freq[:n_dc] = 0.0

    for i in range(int(t_DC*(1/proc_interval))): #DCの速度指令値=0rps
        freq[i] = 0.0

    for i in range(int(36000*target_freq/step)): #加速中の速度指令値
        for j in range(int(rst*(1/proc_interval))):
            freq[int((t_DC+i*rst)*(1/proc_interval)+j)] = target_freq/36000*step*(i+1)

    for i in range(int(60*60*2*(1/proc_interval))): #Stableの速度指令値
        freq[int((t_DC+36000*target_freq/(step/rst))*(1/proc_interval))+i] = target_freq

    return time, freq

class IdealVelocityProvider:
    def __init__(self, duration: float, dt: float) -> None:
        #num_points: int = int(duration / dt) + 1
        #self.time_axis: np.ndarray = np.linspace(0.0, duration, num_points, dtype=np.float32)
        #self.velocity:  np.ndarray = np.full(num_points, IDEAL_CPS, dtype=np.float32)
        self.time_axis, self.velocity = command_freq(90, 5, 1, 1, proc_interval=PROC_INTERVAL)

    def slice(self, t_start: float, t_end: float) -> tuple[np.ndarray, np.ndarray]:
        """Return the time and velocity arrays that fall within [t_start, t_end]."""
        idx_start, idx_end = np.searchsorted(self.time_axis, [t_start, t_end])
        return self.time_axis[idx_start:idx_end], self.velocity[idx_start:idx_end]

ideal: IdealVelocityProvider | None = None  # initialised lazily in processor()


def processor() -> None:
    """
    deque ベース（旧方式）に戻したリアルタイム・コンシューマ。
    - buf_q から取り出した A/B チャンクを deque(Ring) に追加
    - PROC_INTERVAL ごとに SAMPLES_PROC 分を popleft
    - 理想速度 (IdealVelocityProvider) のスライスを同梱して quad_q へ送信
    ※ logger.info() のフォーマットは従来どおり維持
    dequeにしないとバグる
    """
    # ---------- one-time init ----------
    global ideal_provider
    if 'ideal_provider' not in globals() or ideal_provider is None:
        ideal_provider = IdealVelocityProvider(RUN_SEC, PROC_INTERVAL)

    # ---------- logging ----------
    buf = np.empty((LOG_CHUNK, 3), dtype=np.float32)  # 内部バッファ
    buf_len = 0
    print("buf shape =", buf.shape)

    # --- Python deque リングバッファ ---
    ring_t: deque[np.float32] = deque()
    ring_a: deque[np.float32] = deque()
    ring_b: deque[np.float32] = deque()
    last_A = last_B = None

    next_proc = time.perf_counter()
    cum_count = 0
    last_ts   = next_proc

    while not stop_writer.is_set():
        # ---------- 非ブロッキングで出来るだけ取り込む ----------
        try:
            while True:
                t, pA, pB = buf_q.get_nowait()
                ring_t.extend(t); ring_a.extend(pA); ring_b.extend(pB)
                buf_q.task_done()
        except queue.Empty:
            pass

        # ---------- 次の処理時刻まで待機 ----------
        now = time.perf_counter()
        if now < next_proc:
            time.sleep(next_proc - now)
            continue
        next_proc += PROC_INTERVAL

        # ---------- サンプル不足ならスキップ ----------
        if len(ring_t) < SAMPLES_PROC:
            continue

        # ---------- deque → NumPy へコピー ----------
        t_blk = np.array([ring_t.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        a_blk = np.array([ring_a.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        b_blk = np.array([ring_b.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)

        # ---------- 信号処理 ----------
        dir_log, last_A, last_B = gen_pulse_direction(
            a_blk, b_blk,
            threshold=THRESHOLD_DEFAULT,
            prev_A=last_A, prev_B=last_B
        )
        quad_sig  = gen_quad_pulse(t_blk, dir_log, QUADPULSE_WIDTH, PULSE_HEIGHT, SAMPLE_RATE)
        delta_cnt = pulse_count(dir_log)
        cum_count += delta_cnt
        velocity  = delta_cnt / PROC_INTERVAL / 2048

        # ---------- 理想速度スライス ----------
        t_ref, v_ref = ideal_provider.slice(t_blk[0], t_blk[-1])

        # ---------- ログ ----------
        if DEBUG:
            now = time.perf_counter()
            jitter = (now - last_ts) * 1e3
            logger.info(
                "EPOCH = %f, wall = %6.2f ms, jitter = %6.2f ms  delta c=%+d, v=%6.3f, len(dir_log)=%d, buf_len=%d",
                now, jitter, (now - last_ts) * 1e3,
                delta_cnt, velocity, len(dir_log), buf_len
            )
            last_ts = now

        # ---------- GUI へ送信 ----------
        try:
            quad_q.put_nowait(
                (t_blk, a_blk, b_blk, quad_sig,
                 t_blk[-1], cum_count, velocity,
                 t_ref, v_ref)
            )
        except queue.Full:
            pass

         # ---- append to buffer ----
        buf[buf_len] = (t_blk[-1], (v_ref[-1] if v_ref.size else 0.0), velocity)
        buf_len += 1
        if buf_len == buf.shape[0]:
            n = dset.shape[0]
            dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf
            buf_len = 0

     # ---- final flush ----
    if buf_len:
        n = dset.shape[0]
        dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf[:buf_len]
    h5f.close()


def start_gui() -> None:
    pg.setConfigOptions(useOpenGL=True, background="w", foreground="k")
    app = pg.mkQApp("Live plots")

    win = pg.GraphicsLayoutWidget(title="DEMO")

    layout = win.ci.layout                 # GraphicsLayout の中身
    layout.setColumnStretchFactor(0, 3)
    layout.setColumnStretchFactor(1, 5)
    #win_sig = pg.GraphicsLayoutWidget(show=True, title="Signal")
    #win_vel = pg.GraphicsLayoutWidget(show=True, title="Velocity")

    #win_sig.resize(800, 600)
    #win_vel.resize(800, 600)
    #win_sig.show()


    win.resize(800, 600)
    win.show()

    # [0, 0] A/B -------------------------------------------------------
    plt_ab = win.addPlot(row=0, col=0, title="RAW A / B")
    curve_A = plt_ab.plot(pen=pg.mkPen("#ff4b00", width=3))
    curve_B = plt_ab.plot(pen=pg.mkPen("#005aff", width=3))
    plt_ab.setLabel("left", "Amplitude [V]")
    plt_ab.setLabel("bottom", "Time [s]")
    plt_ab.setYRange(-0.5, PULSE_HEIGHT + 0.5)

    # [1,0] Quad waveform --------------------------------------------
    plt_q = win.addPlot(row=1, col=0, title="Quad pulse")
    curve_Q = plt_q.plot(pen=pg.mkPen("m", width=3))
    plt_q.setLabel("left", "Amplitude [V]")
    plt_q.setLabel("bottom", "Time [s]")
    plt_q.setYRange(-PULSE_HEIGHT - 0.5, PULSE_HEIGHT + 0.5)

    # [0,1] count (fixed x-axis) -------------------------------------
    plt_cnt = win.addPlot(row=0, col=1, title="Velovity - Command")
    curve_cnt = plt_cnt.plot(pen=pg.mkPen("#03af7a", width=3))
    #plt_cnt.setXRange(0, RUN_SEC, padding=0)
    #plt_cnt.enableAutoRange("x", True)
    plt_cnt.setLabel("left", "Diff")
    plt_cnt.setLabel("bottom", "Time [s]")

    # [1,1] velocity (fixed x-axis) ----------------------------------
    plt_vel = win.addPlot(row=1, col=1, title="Velocity")
    curve_vel     = plt_vel.plot(pen=pg.mkPen("#00a0e9", width=3))   # measured
    curve_vel_ref = plt_vel.plot(pen=pg.mkPen("#a05aff", width=3))   # ideal (new)
    #plt_vel.setXRange(0, RUN_SEC, padding=0)
    #plt_vel.enableAutoRange("x", True)
    plt_vel.setLabel("left", "Velocity [rps]")
    plt_vel.setLabel("bottom", "Time [s]")

    # buffers ---------------------------------------------------------
    xs = ya = yb = yq = np.empty(0, dtype=np.float32)
    xs_cnt = y_cnt = np.empty(0, dtype=np.float32)
    xs_vel = y_vel = np.empty(0, dtype=np.float32)
    xr = yr = np.empty(0, dtype=np.float32)       # ideal velocity buffers (new)

    def refresh():
        nonlocal xs, ya, yb, yq, xs_cnt, y_cnt, xs_vel, y_vel, xr, yr
        try:
            while True:
                # receive processed data (+ ideal velocity slice)
                t_ax, pA, pB, qsig, t_end, cum_cnt, vel, t_ref, v_ref = quad_q.get_nowait()

                xs = np.concatenate((xs, t_ax))[-HISTORY:]
                ya = np.concatenate((ya, pA))[-HISTORY:]
                yb = np.concatenate((yb, pB))[-HISTORY:]
                yq = np.concatenate((yq, qsig))[-HISTORY:]

                xs_cnt = np.append(xs_cnt, t_end)[-COUNT_HISTORY:]
                y_cnt  = np.append(y_cnt, vel-v_ref)[-COUNT_HISTORY:]

                xs_vel = np.append(xs_vel, t_end)[-VELO_HISTORY:]
                y_vel  = np.append(y_vel, vel)[-VELO_HISTORY:]

                xr = np.concatenate((xr, t_ref))[-VELO_HISTORY:]
                yr = np.concatenate((yr, v_ref))[-VELO_HISTORY:]

                quad_q.task_done()
        except queue.Empty:
            pass

        # scrolling window for waveforms only
        if xs.size:
            start = xs[-1] - PLOT_SEC
            plt_ab.setXRange(start, xs[-1], padding=0)
            plt_q.setXRange(start, xs[-1], padding=0)

        # --- auto-range for count/velocity ---
        if xs_cnt.size:
            plt_cnt.setXRange(xs_cnt[-1]-10, xs_cnt[-1], padding=0)

        if xs_vel.size:
            plt_vel.setXRange(xs_vel[-1]-10, xs_vel[-1], padding=0)

        # --- push data to curves ---
        curve_A.setData(xs, ya)
        curve_B.setData(xs, yb)
        curve_Q.setData(xs, yq)
        curve_cnt.setData(xs_cnt, y_cnt)
        curve_vel.setData(xs_vel, y_vel)
        curve_vel_ref.setData(xr, yr)

    timer = QtCore.QTimer()
    timer.timeout.connect(refresh)
    timer.start(GUI_INTERVAL_MS)

    # auto-stop after RUN_SEC
    QtCore.QTimer.singleShot(int(RUN_SEC * 1000), lambda: (stop_writer.set(), app.quit()))
    app.exec()

# %%
if __name__ == "__main__":
    threading.Thread(target=log_listener, daemon=True).start()  # start log listener

    gen_th  = threading.Thread(target=generator, daemon=True)
    proc_th = threading.Thread(target=processor, daemon=True)

    gen_th.start()
    proc_th.start()
    # con_th.start()

    start_gui()  # blocks until the user closes the window or timer expires

    # join threads and exit
    stop_writer.set()
    gen_th.join()
    proc_th.join()

    print("Graceful shutdown.")
# Out:
# buf shape = (1024, 3)
# EPOCH = 431566.609173, wall = 955.38 ms, jitter = 955.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=0
# EPOCH = 431566.702873, wall =  93.70 ms, jitter =  93.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1
# EPOCH = 431566.723712, wall =  20.84 ms, jitter =  20.84 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=2
# EPOCH = 431566.736137, wall =  12.42 ms, jitter =  12.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=3
# EPOCH = 431567.061252, wall = 325.12 ms, jitter = 325.12 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=4
# EPOCH = 431567.185815, wall = 124.56 ms, jitter = 124.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=5
# EPOCH = 431567.289527, wall = 103.71 ms, jitter = 103.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=6
# EPOCH = 431567.423574, wall = 134.05 ms, jitter = 134.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=7
# EPOCH = 431567.555136, wall = 131.56 ms, jitter = 131.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=8
# EPOCH = 431567.669971, wall = 114.84 ms, jitter = 114.84 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=9
# EPOCH = 431567.802076, wall = 132.10 ms, jitter = 132.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=10
# EPOCH = 431567.917599, wall = 115.52 ms, jitter = 115.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=11
# EPOCH = 431568.054794, wall = 137.19 ms, jitter = 137.19 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=12
# EPOCH = 431568.170090, wall = 115.30 ms, jitter = 115.30 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=13
# EPOCH = 431568.313996, wall = 143.91 ms, jitter = 143.91 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=14
# EPOCH = 431568.421253, wall = 107.26 ms, jitter = 107.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=15
# EPOCH = 431568.539135, wall = 117.88 ms, jitter = 117.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=16
# EPOCH = 431568.669371, wall = 130.24 ms, jitter = 130.24 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=17
# EPOCH = 431568.824257, wall = 154.89 ms, jitter = 154.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=18
# EPOCH = 431568.934068, wall = 109.81 ms, jitter = 109.81 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=19
# EPOCH = 431569.042457, wall = 108.39 ms, jitter = 108.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=20
# EPOCH = 431569.177083, wall = 134.63 ms, jitter = 134.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=21
# EPOCH = 431569.321377, wall = 144.29 ms, jitter = 144.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=22
# EPOCH = 431569.434481, wall = 113.10 ms, jitter = 113.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=23
# EPOCH = 431569.553005, wall = 118.52 ms, jitter = 118.52 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=24
# EPOCH = 431569.685293, wall = 132.29 ms, jitter = 132.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=25
# EPOCH = 431569.820301, wall = 135.01 ms, jitter = 135.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=26
# EPOCH = 431569.942529, wall = 122.23 ms, jitter = 122.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=27
# EPOCH = 431570.045232, wall = 102.70 ms, jitter = 102.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=28
# EPOCH = 431570.167254, wall = 122.02 ms, jitter = 122.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=29
# EPOCH = 431570.310483, wall = 143.23 ms, jitter = 143.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=30
# EPOCH = 431570.416581, wall = 106.10 ms, jitter = 106.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=31
# EPOCH = 431570.554300, wall = 137.72 ms, jitter = 137.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=32
# EPOCH = 431570.684136, wall = 129.84 ms, jitter = 129.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=33
# EPOCH = 431570.792411, wall = 108.28 ms, jitter = 108.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=34
# EPOCH = 431570.918444, wall = 126.03 ms, jitter = 126.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=35
# EPOCH = 431571.060052, wall = 141.61 ms, jitter = 141.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=36
# EPOCH = 431571.184774, wall = 124.72 ms, jitter = 124.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=37
# EPOCH = 431571.285259, wall = 100.48 ms, jitter = 100.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=38
# EPOCH = 431571.426379, wall = 141.12 ms, jitter = 141.12 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=39
# EPOCH = 431571.572184, wall = 145.80 ms, jitter = 145.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=40
# EPOCH = 431571.677472, wall = 105.29 ms, jitter = 105.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=41
# EPOCH = 431571.785584, wall = 108.11 ms, jitter = 108.11 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=42
# EPOCH = 431571.925321, wall = 139.74 ms, jitter = 139.74 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=43
# EPOCH = 431572.046862, wall = 121.54 ms, jitter = 121.54 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=44
# EPOCH = 431572.193598, wall = 146.74 ms, jitter = 146.74 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=45
# EPOCH = 431572.297132, wall = 103.53 ms, jitter = 103.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=46
# EPOCH = 431572.431064, wall = 133.93 ms, jitter = 133.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=47
# EPOCH = 431572.557073, wall = 126.01 ms, jitter = 126.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=48
# EPOCH = 431572.678847, wall = 121.77 ms, jitter = 121.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=49
# EPOCH = 431572.796326, wall = 117.48 ms, jitter = 117.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=50
# EPOCH = 431572.913325, wall = 117.00 ms, jitter = 117.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=51
# EPOCH = 431573.049504, wall = 136.18 ms, jitter = 136.18 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=52
# EPOCH = 431573.186483, wall = 136.98 ms, jitter = 136.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=53
# EPOCH = 431573.304046, wall = 117.56 ms, jitter = 117.56 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=54
# EPOCH = 431573.423712, wall = 119.67 ms, jitter = 119.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=55
# EPOCH = 431573.585993, wall = 162.28 ms, jitter = 162.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=56
# EPOCH = 431573.671251, wall =  85.26 ms, jitter =  85.26 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=57
# EPOCH = 431573.808920, wall = 137.67 ms, jitter = 137.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=58
# EPOCH = 431573.916948, wall = 108.03 ms, jitter = 108.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=59
# EPOCH = 431574.067919, wall = 150.97 ms, jitter = 150.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=60
# EPOCH = 431574.183750, wall = 115.83 ms, jitter = 115.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=61
# EPOCH = 431574.307774, wall = 124.02 ms, jitter = 124.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=62
# EPOCH = 431574.445388, wall = 137.61 ms, jitter = 137.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=63
# EPOCH = 431574.549955, wall = 104.57 ms, jitter = 104.57 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=64
# EPOCH = 431574.664463, wall = 114.51 ms, jitter = 114.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=65
# EPOCH = 431574.806351, wall = 141.89 ms, jitter = 141.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=66
# EPOCH = 431574.920518, wall = 114.17 ms, jitter = 114.17 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=67
# EPOCH = 431575.050035, wall = 129.52 ms, jitter = 129.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=68
# EPOCH = 431575.161220, wall = 111.18 ms, jitter = 111.18 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=69
# EPOCH = 431575.297136, wall = 135.92 ms, jitter = 135.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=70
# EPOCH = 431575.419507, wall = 122.37 ms, jitter = 122.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=71
# EPOCH = 431575.572061, wall = 152.55 ms, jitter = 152.55 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=72
# EPOCH = 431575.666866, wall =  94.81 ms, jitter =  94.81 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=73
# EPOCH = 431575.800330, wall = 133.46 ms, jitter = 133.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=74
# EPOCH = 431575.916120, wall = 115.79 ms, jitter = 115.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=75
# EPOCH = 431576.039094, wall = 122.97 ms, jitter = 122.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=76
# EPOCH = 431576.174280, wall = 135.19 ms, jitter = 135.19 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=77
# EPOCH = 431576.297681, wall = 123.40 ms, jitter = 123.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=78
# EPOCH = 431576.419187, wall = 121.51 ms, jitter = 121.51 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=79
# EPOCH = 431576.550294, wall = 131.11 ms, jitter = 131.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=80
# EPOCH = 431576.685775, wall = 135.48 ms, jitter = 135.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=81
# EPOCH = 431576.811065, wall = 125.29 ms, jitter = 125.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=82
# EPOCH = 431576.913249, wall = 102.18 ms, jitter = 102.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=83
# EPOCH = 431577.064599, wall = 151.35 ms, jitter = 151.35 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=84
# EPOCH = 431577.190285, wall = 125.69 ms, jitter = 125.69 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=85
# EPOCH = 431577.287520, wall =  97.24 ms, jitter =  97.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=86
# EPOCH = 431577.431551, wall = 144.03 ms, jitter = 144.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=87
# EPOCH = 431577.550312, wall = 118.76 ms, jitter = 118.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=88
# EPOCH = 431577.678241, wall = 127.93 ms, jitter = 127.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=89
# EPOCH = 431577.794668, wall = 116.43 ms, jitter = 116.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=90
# EPOCH = 431577.916712, wall = 122.04 ms, jitter = 122.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=91
# EPOCH = 431578.041496, wall = 124.78 ms, jitter = 124.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=92
# EPOCH = 431578.184653, wall = 143.16 ms, jitter = 143.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=93
# EPOCH = 431578.288652, wall = 104.00 ms, jitter = 104.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=94
# EPOCH = 431578.425548, wall = 136.90 ms, jitter = 136.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=95
# EPOCH = 431578.544286, wall = 118.74 ms, jitter = 118.74 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=96
# EPOCH = 431578.666733, wall = 122.45 ms, jitter = 122.45 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=97
# EPOCH = 431578.817595, wall = 150.86 ms, jitter = 150.86 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=98
# EPOCH = 431578.930834, wall = 113.24 ms, jitter = 113.24 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=99
# EPOCH = 431579.048917, wall = 118.08 ms, jitter = 118.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=100
# EPOCH = 431579.172308, wall = 123.39 ms, jitter = 123.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=101
# EPOCH = 431579.296966, wall = 124.66 ms, jitter = 124.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=102
# EPOCH = 431579.422438, wall = 125.47 ms, jitter = 125.47 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=103
# EPOCH = 431579.547741, wall = 125.30 ms, jitter = 125.30 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=104
# EPOCH = 431579.669873, wall = 122.13 ms, jitter = 122.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=105
# EPOCH = 431579.795991, wall = 126.12 ms, jitter = 126.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=106
# EPOCH = 431579.917184, wall = 121.19 ms, jitter = 121.19 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=107
# EPOCH = 431580.046538, wall = 129.35 ms, jitter = 129.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=108
# EPOCH = 431580.169560, wall = 123.02 ms, jitter = 123.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=109
# EPOCH = 431580.294842, wall = 125.28 ms, jitter = 125.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=110
# EPOCH = 431580.414347, wall = 119.51 ms, jitter = 119.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=111
# EPOCH = 431580.544377, wall = 130.03 ms, jitter = 130.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=112
# EPOCH = 431580.660437, wall = 116.06 ms, jitter = 116.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=113
# EPOCH = 431580.789894, wall = 129.46 ms, jitter = 129.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=114
# EPOCH = 431580.939095, wall = 149.20 ms, jitter = 149.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=115
# EPOCH = 431581.062447, wall = 123.35 ms, jitter = 123.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=116
# EPOCH = 431581.185143, wall = 122.70 ms, jitter = 122.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=117
# EPOCH = 431581.304391, wall = 119.25 ms, jitter = 119.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=118
# EPOCH = 431581.444407, wall = 140.02 ms, jitter = 140.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=119
# EPOCH = 431581.544624, wall = 100.22 ms, jitter = 100.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=120
# EPOCH = 431581.674571, wall = 129.95 ms, jitter = 129.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=121
# EPOCH = 431581.789211, wall = 114.64 ms, jitter = 114.64 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=122
# EPOCH = 431581.927978, wall = 138.77 ms, jitter = 138.77 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=123
# EPOCH = 431582.039473, wall = 111.50 ms, jitter = 111.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=124
# EPOCH = 431582.173146, wall = 133.67 ms, jitter = 133.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=125
# EPOCH = 431582.305857, wall = 132.71 ms, jitter = 132.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=126
# EPOCH = 431582.412862, wall = 107.01 ms, jitter = 107.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=127
# EPOCH = 431582.538543, wall = 125.68 ms, jitter = 125.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=128
# EPOCH = 431582.663336, wall = 124.79 ms, jitter = 124.79 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=129
# EPOCH = 431582.807876, wall = 144.54 ms, jitter = 144.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=130
# EPOCH = 431582.936292, wall = 128.42 ms, jitter = 128.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=131
# EPOCH = 431583.036049, wall =  99.76 ms, jitter =  99.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=132
# EPOCH = 431583.162461, wall = 126.41 ms, jitter = 126.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=133
# EPOCH = 431583.313208, wall = 150.75 ms, jitter = 150.75 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=134
# EPOCH = 431583.434081, wall = 120.87 ms, jitter = 120.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=135
# EPOCH = 431583.541531, wall = 107.45 ms, jitter = 107.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=136
# EPOCH = 431583.669590, wall = 128.06 ms, jitter = 128.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=137
# EPOCH = 431583.787865, wall = 118.28 ms, jitter = 118.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=138
# EPOCH = 431583.914206, wall = 126.34 ms, jitter = 126.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=139
# EPOCH = 431584.038804, wall = 124.60 ms, jitter = 124.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=140
# EPOCH = 431584.183638, wall = 144.83 ms, jitter = 144.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=141
# EPOCH = 431584.311647, wall = 128.01 ms, jitter = 128.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=142
# EPOCH = 431584.413952, wall = 102.30 ms, jitter = 102.30 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=143
# EPOCH = 431584.540691, wall = 126.74 ms, jitter = 126.74 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=144
# EPOCH = 431584.659768, wall = 119.08 ms, jitter = 119.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=145
# EPOCH = 431584.787944, wall = 128.18 ms, jitter = 128.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=146
# EPOCH = 431584.947822, wall = 159.88 ms, jitter = 159.88 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=147
# EPOCH = 431585.052511, wall = 104.69 ms, jitter = 104.69 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=148
# EPOCH = 431585.190274, wall = 137.76 ms, jitter = 137.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=149
# EPOCH = 431585.334839, wall = 144.57 ms, jitter = 144.57 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=150
# EPOCH = 431585.415895, wall =  81.06 ms, jitter =  81.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=151
# EPOCH = 431585.554738, wall = 138.84 ms, jitter = 138.84 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=152
# EPOCH = 431585.689254, wall = 134.52 ms, jitter = 134.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=153
# EPOCH = 431585.794312, wall = 105.06 ms, jitter = 105.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=154
# EPOCH = 431585.931208, wall = 136.90 ms, jitter = 136.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=155
# EPOCH = 431586.037066, wall = 105.86 ms, jitter = 105.86 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=156
# EPOCH = 431586.165767, wall = 128.70 ms, jitter = 128.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=157
# EPOCH = 431586.310911, wall = 145.14 ms, jitter = 145.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=158
# EPOCH = 431586.436533, wall = 125.62 ms, jitter = 125.62 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=159
# EPOCH = 431586.543188, wall = 106.65 ms, jitter = 106.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=160
# EPOCH = 431586.675263, wall = 132.08 ms, jitter = 132.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=161
# EPOCH = 431586.811935, wall = 136.67 ms, jitter = 136.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=162
# EPOCH = 431586.944059, wall = 132.12 ms, jitter = 132.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=163
# EPOCH = 431587.053742, wall = 109.68 ms, jitter = 109.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=164
# EPOCH = 431587.204946, wall = 151.20 ms, jitter = 151.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=165
# EPOCH = 431587.304968, wall = 100.02 ms, jitter = 100.02 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=166
# EPOCH = 431587.411627, wall = 106.66 ms, jitter = 106.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=167
# EPOCH = 431587.537311, wall = 125.68 ms, jitter = 125.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=168
# EPOCH = 431587.676357, wall = 139.05 ms, jitter = 139.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=169
# EPOCH = 431587.830477, wall = 154.12 ms, jitter = 154.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=170
# EPOCH = 431587.936804, wall = 106.33 ms, jitter = 106.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=171
# EPOCH = 431588.045370, wall = 108.57 ms, jitter = 108.57 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=172
# EPOCH = 431588.178187, wall = 132.82 ms, jitter = 132.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=173
# EPOCH = 431588.288160, wall = 109.97 ms, jitter = 109.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=174
# EPOCH = 431588.431072, wall = 142.91 ms, jitter = 142.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=175
# EPOCH = 431588.560519, wall = 129.45 ms, jitter = 129.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=176
# EPOCH = 431588.664349, wall = 103.83 ms, jitter = 103.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=177
# EPOCH = 431588.799147, wall = 134.80 ms, jitter = 134.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=178
# EPOCH = 431588.933402, wall = 134.26 ms, jitter = 134.26 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=179
# EPOCH = 431589.058004, wall = 124.60 ms, jitter = 124.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=180
# EPOCH = 431589.174281, wall = 116.28 ms, jitter = 116.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=181
# EPOCH = 431589.294686, wall = 120.40 ms, jitter = 120.40 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=182
# EPOCH = 431589.423359, wall = 128.67 ms, jitter = 128.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=183
# EPOCH = 431589.561452, wall = 138.09 ms, jitter = 138.09 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=184
# EPOCH = 431589.671369, wall = 109.92 ms, jitter = 109.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=185
# EPOCH = 431589.799372, wall = 128.00 ms, jitter = 128.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=186
# EPOCH = 431589.923055, wall = 123.68 ms, jitter = 123.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=187
# EPOCH = 431590.069173, wall = 146.12 ms, jitter = 146.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=188
# EPOCH = 431590.184602, wall = 115.43 ms, jitter = 115.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=189
# EPOCH = 431590.296761, wall = 112.16 ms, jitter = 112.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=190
# EPOCH = 431590.430795, wall = 134.03 ms, jitter = 134.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=191
# EPOCH = 431590.558957, wall = 128.16 ms, jitter = 128.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=192
# EPOCH = 431590.681300, wall = 122.34 ms, jitter = 122.34 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=193
# EPOCH = 431590.812608, wall = 131.31 ms, jitter = 131.31 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=194
# EPOCH = 431590.931195, wall = 118.59 ms, jitter = 118.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=195
# EPOCH = 431591.055949, wall = 124.75 ms, jitter = 124.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=196
# EPOCH = 431591.174101, wall = 118.15 ms, jitter = 118.15 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=197
# EPOCH = 431591.321171, wall = 147.07 ms, jitter = 147.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=198
# EPOCH = 431591.425561, wall = 104.39 ms, jitter = 104.39 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=199
# EPOCH = 431591.553260, wall = 127.70 ms, jitter = 127.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=200
# EPOCH = 431591.679181, wall = 125.92 ms, jitter = 125.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=201
# EPOCH = 431591.801823, wall = 122.64 ms, jitter = 122.64 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=202
# EPOCH = 431591.930489, wall = 128.67 ms, jitter = 128.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=203
# EPOCH = 431592.064601, wall = 134.11 ms, jitter = 134.11 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=204
# EPOCH = 431592.175480, wall = 110.88 ms, jitter = 110.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=205
# EPOCH = 431592.302258, wall = 126.78 ms, jitter = 126.78 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=206
# EPOCH = 431592.417607, wall = 115.35 ms, jitter = 115.35 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=207
# EPOCH = 431592.541838, wall = 124.23 ms, jitter = 124.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=208
# EPOCH = 431592.670086, wall = 128.25 ms, jitter = 128.25 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=209
# EPOCH = 431592.789959, wall = 119.87 ms, jitter = 119.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=210
# EPOCH = 431592.913141, wall = 123.18 ms, jitter = 123.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=211
# EPOCH = 431593.046109, wall = 132.97 ms, jitter = 132.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=212
# EPOCH = 431593.177532, wall = 131.42 ms, jitter = 131.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=213
# EPOCH = 431593.311913, wall = 134.38 ms, jitter = 134.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=214
# EPOCH = 431593.439160, wall = 127.25 ms, jitter = 127.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=215
# EPOCH = 431593.564558, wall = 125.40 ms, jitter = 125.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=216
# EPOCH = 431593.665686, wall = 101.13 ms, jitter = 101.13 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=217
# EPOCH = 431593.809167, wall = 143.48 ms, jitter = 143.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=218
# EPOCH = 431593.937286, wall = 128.12 ms, jitter = 128.12 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=219
# EPOCH = 431594.062517, wall = 125.23 ms, jitter = 125.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=220
# EPOCH = 431594.186911, wall = 124.39 ms, jitter = 124.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=221
# EPOCH = 431594.291967, wall = 105.06 ms, jitter = 105.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=222
# EPOCH = 431594.413200, wall = 121.23 ms, jitter = 121.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=223
# EPOCH = 431594.558912, wall = 145.71 ms, jitter = 145.71 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=224
# EPOCH = 431594.671039, wall = 112.13 ms, jitter = 112.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=225
# EPOCH = 431594.789950, wall = 118.91 ms, jitter = 118.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=226
# EPOCH = 431594.912685, wall = 122.74 ms, jitter = 122.74 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=227
# EPOCH = 431595.063696, wall = 151.01 ms, jitter = 151.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=228
# EPOCH = 431595.181930, wall = 118.23 ms, jitter = 118.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=229
# EPOCH = 431595.291000, wall = 109.07 ms, jitter = 109.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=230
# EPOCH = 431595.418559, wall = 127.56 ms, jitter = 127.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=231
# EPOCH = 431595.542509, wall = 123.95 ms, jitter = 123.95 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=232
# EPOCH = 431595.676160, wall = 133.65 ms, jitter = 133.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=233
# EPOCH = 431595.797311, wall = 121.15 ms, jitter = 121.15 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=234
# EPOCH = 431595.946011, wall = 148.70 ms, jitter = 148.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=235
# EPOCH = 431596.038630, wall =  92.62 ms, jitter =  92.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=236
# EPOCH = 431596.161068, wall = 122.44 ms, jitter = 122.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=237
# EPOCH = 431596.288699, wall = 127.63 ms, jitter = 127.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=238
# EPOCH = 431596.426240, wall = 137.54 ms, jitter = 137.54 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=239
# EPOCH = 431596.563800, wall = 137.56 ms, jitter = 137.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=240
# EPOCH = 431596.661547, wall =  97.75 ms, jitter =  97.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=241
# EPOCH = 431596.819550, wall = 158.00 ms, jitter = 158.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=242
# EPOCH = 431596.924761, wall = 105.21 ms, jitter = 105.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=243
# EPOCH = 431597.057538, wall = 132.78 ms, jitter = 132.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=244
# EPOCH = 431597.164119, wall = 106.58 ms, jitter = 106.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=245
# EPOCH = 431597.290653, wall = 126.53 ms, jitter = 126.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=246
# EPOCH = 431597.414721, wall = 124.07 ms, jitter = 124.07 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=247
# EPOCH = 431597.539374, wall = 124.65 ms, jitter = 124.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=248
# EPOCH = 431597.668877, wall = 129.50 ms, jitter = 129.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=249
# EPOCH = 431597.793113, wall = 124.24 ms, jitter = 124.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=250
# EPOCH = 431597.921482, wall = 128.37 ms, jitter = 128.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=251
# EPOCH = 431598.062861, wall = 141.38 ms, jitter = 141.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=252
# EPOCH = 431598.163176, wall = 100.31 ms, jitter = 100.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=253
# EPOCH = 431598.294155, wall = 130.98 ms, jitter = 130.98 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=254
# EPOCH = 431598.431657, wall = 137.50 ms, jitter = 137.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=255
# EPOCH = 431598.545686, wall = 114.03 ms, jitter = 114.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=256
# EPOCH = 431598.668233, wall = 122.55 ms, jitter = 122.55 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=257
# EPOCH = 431598.810468, wall = 142.24 ms, jitter = 142.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=258
# EPOCH = 431598.931141, wall = 120.67 ms, jitter = 120.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=259
# EPOCH = 431599.050485, wall = 119.34 ms, jitter = 119.34 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=260
# EPOCH = 431599.163356, wall = 112.87 ms, jitter = 112.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=261
# EPOCH = 431599.292065, wall = 128.71 ms, jitter = 128.71 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=262
# EPOCH = 431599.413864, wall = 121.80 ms, jitter = 121.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=263
# EPOCH = 431599.543913, wall = 130.05 ms, jitter = 130.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=264
# EPOCH = 431599.675469, wall = 131.56 ms, jitter = 131.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=265
# EPOCH = 431599.789721, wall = 114.25 ms, jitter = 114.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=266
# EPOCH = 431599.914936, wall = 125.21 ms, jitter = 125.21 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=267
# EPOCH = 431600.062223, wall = 147.29 ms, jitter = 147.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=268
# EPOCH = 431600.162606, wall = 100.38 ms, jitter = 100.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=269
# EPOCH = 431600.292542, wall = 129.94 ms, jitter = 129.94 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=270
# EPOCH = 431600.430247, wall = 137.70 ms, jitter = 137.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=271
# EPOCH = 431600.559323, wall = 129.08 ms, jitter = 129.08 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=272
# EPOCH = 431600.664711, wall = 105.39 ms, jitter = 105.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=273
# EPOCH = 431600.799944, wall = 135.23 ms, jitter = 135.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=274
# EPOCH = 431600.938842, wall = 138.90 ms, jitter = 138.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=275
# EPOCH = 431601.037755, wall =  98.91 ms, jitter =  98.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=276
# EPOCH = 431601.168726, wall = 130.97 ms, jitter = 130.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=277
# EPOCH = 431601.289047, wall = 120.32 ms, jitter = 120.32 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=278
# EPOCH = 431601.412718, wall = 123.67 ms, jitter = 123.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=279
# EPOCH = 431601.538671, wall = 125.95 ms, jitter = 125.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=280
# EPOCH = 431601.682067, wall = 143.40 ms, jitter = 143.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=281
# EPOCH = 431601.828619, wall = 146.55 ms, jitter = 146.55 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=282
# EPOCH = 431601.924421, wall =  95.80 ms, jitter =  95.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=283
# EPOCH = 431602.057100, wall = 132.68 ms, jitter = 132.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=284
# EPOCH = 431602.160157, wall = 103.06 ms, jitter = 103.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=285
# EPOCH = 431602.291226, wall = 131.07 ms, jitter = 131.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=286
# EPOCH = 431602.451882, wall = 160.66 ms, jitter = 160.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=287
# EPOCH = 431602.538099, wall =  86.22 ms, jitter =  86.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=288
# EPOCH = 431602.675385, wall = 137.29 ms, jitter = 137.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=289
# EPOCH = 431602.800351, wall = 124.97 ms, jitter = 124.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=290
# EPOCH = 431602.921802, wall = 121.45 ms, jitter = 121.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=291
# EPOCH = 431603.045863, wall = 124.06 ms, jitter = 124.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=292
# EPOCH = 431603.177656, wall = 131.79 ms, jitter = 131.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=293
# EPOCH = 431603.305422, wall = 127.77 ms, jitter = 127.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=294
# EPOCH = 431603.415161, wall = 109.74 ms, jitter = 109.74 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=295
# EPOCH = 431603.553815, wall = 138.65 ms, jitter = 138.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=296
# EPOCH = 431603.672086, wall = 118.27 ms, jitter = 118.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=297
# EPOCH = 431603.800768, wall = 128.68 ms, jitter = 128.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=298
# EPOCH = 431603.931815, wall = 131.05 ms, jitter = 131.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=299
# EPOCH = 431604.052436, wall = 120.62 ms, jitter = 120.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=300
# EPOCH = 431604.191197, wall = 138.76 ms, jitter = 138.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=301
# EPOCH = 431604.300538, wall = 109.34 ms, jitter = 109.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=302
# EPOCH = 431604.442949, wall = 142.41 ms, jitter = 142.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=303
# EPOCH = 431604.552444, wall = 109.50 ms, jitter = 109.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=304
# EPOCH = 431604.673329, wall = 120.88 ms, jitter = 120.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=305
# EPOCH = 431604.799268, wall = 125.94 ms, jitter = 125.94 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=306
# EPOCH = 431604.936946, wall = 137.68 ms, jitter = 137.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=307
# EPOCH = 431605.050525, wall = 113.58 ms, jitter = 113.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=308
# EPOCH = 431605.184182, wall = 133.66 ms, jitter = 133.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=309
# EPOCH = 431605.289301, wall = 105.12 ms, jitter = 105.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=310
# EPOCH = 431605.428324, wall = 139.02 ms, jitter = 139.02 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=311
# EPOCH = 431605.560199, wall = 131.88 ms, jitter = 131.88 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=312
# EPOCH = 431605.675377, wall = 115.18 ms, jitter = 115.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=313
# EPOCH = 431605.795932, wall = 120.56 ms, jitter = 120.56 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=314
# EPOCH = 431605.916019, wall = 120.09 ms, jitter = 120.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=315
# EPOCH = 431606.051588, wall = 135.57 ms, jitter = 135.57 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=316
# EPOCH = 431606.171421, wall = 119.83 ms, jitter = 119.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=317
# EPOCH = 431606.301268, wall = 129.85 ms, jitter = 129.85 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=318
# EPOCH = 431606.420428, wall = 119.16 ms, jitter = 119.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=319
# EPOCH = 431606.549697, wall = 129.27 ms, jitter = 129.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=320
# EPOCH = 431606.665689, wall = 115.99 ms, jitter = 115.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=321
# EPOCH = 431606.802659, wall = 136.97 ms, jitter = 136.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=322
# EPOCH = 431606.954355, wall = 151.70 ms, jitter = 151.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=323
# EPOCH = 431607.059683, wall = 105.33 ms, jitter = 105.33 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=324
# EPOCH = 431607.192557, wall = 132.87 ms, jitter = 132.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=325
# EPOCH = 431607.289828, wall =  97.27 ms, jitter =  97.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=326
# EPOCH = 431607.444689, wall = 154.86 ms, jitter = 154.86 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=327
# EPOCH = 431607.556366, wall = 111.68 ms, jitter = 111.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=328
# EPOCH = 431607.685688, wall = 129.32 ms, jitter = 129.32 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=329
# EPOCH = 431607.790768, wall = 105.08 ms, jitter = 105.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=330
# EPOCH = 431607.927115, wall = 136.35 ms, jitter = 136.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=331
# EPOCH = 431608.071532, wall = 144.42 ms, jitter = 144.42 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=332
# EPOCH = 431608.177012, wall = 105.48 ms, jitter = 105.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=333
# EPOCH = 431608.313150, wall = 136.14 ms, jitter = 136.14 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=334
# EPOCH = 431608.417668, wall = 104.52 ms, jitter = 104.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=335
# EPOCH = 431608.537886, wall = 120.22 ms, jitter = 120.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=336
# EPOCH = 431608.669390, wall = 131.50 ms, jitter = 131.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=337
# EPOCH = 431608.791329, wall = 121.94 ms, jitter = 121.94 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=338
# EPOCH = 431608.919804, wall = 128.47 ms, jitter = 128.47 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=339
# EPOCH = 431609.049750, wall = 129.95 ms, jitter = 129.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=340
# EPOCH = 431609.169538, wall = 119.79 ms, jitter = 119.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=341
# EPOCH = 431609.300485, wall = 130.95 ms, jitter = 130.95 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=342
# EPOCH = 431609.432980, wall = 132.49 ms, jitter = 132.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=343
# EPOCH = 431609.544209, wall = 111.23 ms, jitter = 111.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=344
# EPOCH = 431609.685465, wall = 141.26 ms, jitter = 141.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=345
# EPOCH = 431609.788656, wall = 103.19 ms, jitter = 103.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=346
# EPOCH = 431609.927648, wall = 138.99 ms, jitter = 138.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=347
# EPOCH = 431610.064656, wall = 137.01 ms, jitter = 137.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=348
# EPOCH = 431610.178954, wall = 114.30 ms, jitter = 114.30 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=349
# EPOCH = 431610.313230, wall = 134.28 ms, jitter = 134.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=350
# EPOCH = 431610.417840, wall = 104.61 ms, jitter = 104.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=351
# EPOCH = 431610.551406, wall = 133.57 ms, jitter = 133.57 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=352
# EPOCH = 431610.673810, wall = 122.40 ms, jitter = 122.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=353
# EPOCH = 431610.800387, wall = 126.58 ms, jitter = 126.58 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=354
# EPOCH = 431610.936386, wall = 136.00 ms, jitter = 136.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=355
# EPOCH = 431611.052083, wall = 115.70 ms, jitter = 115.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=356
# EPOCH = 431611.163803, wall = 111.72 ms, jitter = 111.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=357
# EPOCH = 431611.302898, wall = 139.10 ms, jitter = 139.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=358
# EPOCH = 431611.445696, wall = 142.80 ms, jitter = 142.80 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=359
# EPOCH = 431611.555471, wall = 109.77 ms, jitter = 109.77 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=360
# EPOCH = 431611.663936, wall = 108.46 ms, jitter = 108.46 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=361
# EPOCH = 431611.812346, wall = 148.41 ms, jitter = 148.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=362
# EPOCH = 431611.945362, wall = 133.02 ms, jitter = 133.02 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=363
# EPOCH = 431612.046292, wall = 100.93 ms, jitter = 100.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=364
# EPOCH = 431612.164434, wall = 118.14 ms, jitter = 118.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=365
# EPOCH = 431612.304313, wall = 139.88 ms, jitter = 139.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=366
# EPOCH = 431612.414003, wall = 109.69 ms, jitter = 109.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=367
# EPOCH = 431612.571602, wall = 157.60 ms, jitter = 157.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=368
# EPOCH = 431612.676996, wall = 105.39 ms, jitter = 105.39 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=369
# EPOCH = 431612.789713, wall = 112.72 ms, jitter = 112.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=370
# EPOCH = 431612.916269, wall = 126.56 ms, jitter = 126.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=371
# EPOCH = 431613.047164, wall = 130.89 ms, jitter = 130.89 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=372
# EPOCH = 431613.170998, wall = 123.83 ms, jitter = 123.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=373
# EPOCH = 431613.297299, wall = 126.30 ms, jitter = 126.30 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=374
# EPOCH = 431613.424849, wall = 127.55 ms, jitter = 127.55 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=375
# EPOCH = 431613.546398, wall = 121.55 ms, jitter = 121.55 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=376
# EPOCH = 431613.676866, wall = 130.47 ms, jitter = 130.47 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=377
# EPOCH = 431613.795526, wall = 118.66 ms, jitter = 118.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=378
# EPOCH = 431613.930975, wall = 135.45 ms, jitter = 135.45 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=379
# EPOCH = 431614.064669, wall = 133.69 ms, jitter = 133.69 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=380
# EPOCH = 431614.185595, wall = 120.93 ms, jitter = 120.93 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=381
# EPOCH = 431614.313304, wall = 127.71 ms, jitter = 127.71 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=382
# EPOCH = 431614.415145, wall = 101.84 ms, jitter = 101.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=383
# EPOCH = 431614.546602, wall = 131.46 ms, jitter = 131.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=384
# EPOCH = 431614.688146, wall = 141.54 ms, jitter = 141.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=385
# EPOCH = 431614.819020, wall = 130.87 ms, jitter = 130.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=386
# EPOCH = 431614.932329, wall = 113.31 ms, jitter = 113.31 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=387
# EPOCH = 431615.053731, wall = 121.40 ms, jitter = 121.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=388
# EPOCH = 431615.171562, wall = 117.83 ms, jitter = 117.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=389
# EPOCH = 431615.294096, wall = 122.53 ms, jitter = 122.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=390
# EPOCH = 431615.415963, wall = 121.87 ms, jitter = 121.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=391
# EPOCH = 431615.547754, wall = 131.79 ms, jitter = 131.79 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=392
# EPOCH = 431615.677745, wall = 129.99 ms, jitter = 129.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=393
# EPOCH = 431615.794741, wall = 117.00 ms, jitter = 117.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=394
# EPOCH = 431615.945205, wall = 150.46 ms, jitter = 150.46 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=395
# EPOCH = 431616.055975, wall = 110.77 ms, jitter = 110.77 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=396
# EPOCH = 431616.180725, wall = 124.75 ms, jitter = 124.75 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=397
# EPOCH = 431616.285102, wall = 104.38 ms, jitter = 104.38 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=398
# EPOCH = 431616.416723, wall = 131.62 ms, jitter = 131.62 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=399
# EPOCH = 431616.557588, wall = 140.87 ms, jitter = 140.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=400
# EPOCH = 431616.677777, wall = 120.19 ms, jitter = 120.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=401
# EPOCH = 431616.803921, wall = 126.14 ms, jitter = 126.14 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=402
# EPOCH = 431616.924904, wall = 120.98 ms, jitter = 120.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=403
# EPOCH = 431617.051680, wall = 126.78 ms, jitter = 126.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=404
# EPOCH = 431617.179993, wall = 128.31 ms, jitter = 128.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=405
# EPOCH = 431617.301324, wall = 121.33 ms, jitter = 121.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=406
# EPOCH = 431617.438415, wall = 137.09 ms, jitter = 137.09 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=407
# EPOCH = 431617.555572, wall = 117.16 ms, jitter = 117.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=408
# EPOCH = 431617.666082, wall = 110.51 ms, jitter = 110.51 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=409
# EPOCH = 431617.813084, wall = 147.00 ms, jitter = 147.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=410
# EPOCH = 431617.922212, wall = 109.13 ms, jitter = 109.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=411
# EPOCH = 431618.052633, wall = 130.42 ms, jitter = 130.42 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=412
# EPOCH = 431618.164711, wall = 112.08 ms, jitter = 112.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=413
# ...
# EPOCH = 431683.776779, wall = 167.51 ms, jitter = 167.51 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=937
# EPOCH = 431683.805361, wall =  28.58 ms, jitter =  28.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=938
# EPOCH = 431683.953794, wall = 148.43 ms, jitter = 148.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=939
# EPOCH = 431684.076052, wall = 122.26 ms, jitter = 122.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=940
# EPOCH = 431684.223656, wall = 147.60 ms, jitter = 147.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=941
# EPOCH = 431684.314996, wall =  91.34 ms, jitter =  91.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=942
# EPOCH = 431684.507899, wall = 192.90 ms, jitter = 192.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=943
# EPOCH = 431684.562986, wall =  55.09 ms, jitter =  55.09 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=944
# EPOCH = 431684.760192, wall = 197.21 ms, jitter = 197.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=945
# EPOCH = 431684.953438, wall = 193.25 ms, jitter = 193.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=946
# EPOCH = 431685.096972, wall = 143.53 ms, jitter = 143.53 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=947
# EPOCH = 431685.224061, wall = 127.09 ms, jitter = 127.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=948
# EPOCH = 431685.349410, wall = 125.35 ms, jitter = 125.35 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=949
# EPOCH = 431685.443680, wall =  94.27 ms, jitter =  94.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=950
# EPOCH = 431685.591340, wall = 147.66 ms, jitter = 147.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=951
# EPOCH = 431685.736123, wall = 144.78 ms, jitter = 144.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=952
# EPOCH = 431685.851340, wall = 115.22 ms, jitter = 115.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=953
# EPOCH = 431686.015683, wall = 164.34 ms, jitter = 164.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=954
# EPOCH = 431686.114552, wall =  98.87 ms, jitter =  98.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=955
# EPOCH = 431686.183718, wall =  69.17 ms, jitter =  69.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=956
# EPOCH = 431686.346966, wall = 163.25 ms, jitter = 163.25 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=957
# EPOCH = 431686.477299, wall = 130.33 ms, jitter = 130.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=958
# EPOCH = 431686.571367, wall =  94.07 ms, jitter =  94.07 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=959
# EPOCH = 431686.684530, wall = 113.16 ms, jitter = 113.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=960
# EPOCH = 431686.845505, wall = 160.97 ms, jitter = 160.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=961
# EPOCH = 431687.013139, wall = 167.63 ms, jitter = 167.63 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=962
# EPOCH = 431687.068137, wall =  55.00 ms, jitter =  55.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=963
# EPOCH = 431687.207376, wall = 139.24 ms, jitter = 139.24 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=964
# EPOCH = 431687.380218, wall = 172.84 ms, jitter = 172.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=965
# EPOCH = 431687.488104, wall = 107.89 ms, jitter = 107.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=966
# EPOCH = 431687.711107, wall = 223.00 ms, jitter = 223.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=967
# EPOCH = 431687.844302, wall = 133.20 ms, jitter = 133.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=968
# EPOCH = 431688.042584, wall = 198.28 ms, jitter = 198.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=969
# EPOCH = 431688.111648, wall =  69.06 ms, jitter =  69.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=970
# EPOCH = 431688.206617, wall =  94.97 ms, jitter =  94.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=971
# EPOCH = 431688.354482, wall = 147.87 ms, jitter = 147.87 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=972
# EPOCH = 431688.466136, wall = 111.65 ms, jitter = 111.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=973
# EPOCH = 431688.611927, wall = 145.79 ms, jitter = 145.79 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=974
# EPOCH = 431688.746763, wall = 134.84 ms, jitter = 134.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=975
# EPOCH = 431688.802795, wall =  56.03 ms, jitter =  56.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=976
# EPOCH = 431689.004115, wall = 201.32 ms, jitter = 201.32 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=977
# EPOCH = 431689.061209, wall =  57.09 ms, jitter =  57.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=978
# EPOCH = 431689.233970, wall = 172.76 ms, jitter = 172.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=979
# EPOCH = 431689.354570, wall = 120.60 ms, jitter = 120.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=980
# EPOCH = 431689.476532, wall = 121.96 ms, jitter = 121.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=981
# EPOCH = 431689.562571, wall =  86.04 ms, jitter =  86.04 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=982
# EPOCH = 431689.733488, wall = 170.92 ms, jitter = 170.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=983
# EPOCH = 431689.817679, wall =  84.19 ms, jitter =  84.19 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=984
# EPOCH = 431690.074020, wall = 256.34 ms, jitter = 256.34 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=985
# EPOCH = 431690.209720, wall = 135.70 ms, jitter = 135.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=986
# EPOCH = 431690.313179, wall = 103.46 ms, jitter = 103.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=987
# EPOCH = 431690.483242, wall = 170.06 ms, jitter = 170.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=988
# EPOCH = 431690.585583, wall = 102.34 ms, jitter = 102.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=989
# EPOCH = 431690.747023, wall = 161.44 ms, jitter = 161.44 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=990
# EPOCH = 431690.852899, wall = 105.88 ms, jitter = 105.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=991
# EPOCH = 431690.931780, wall =  78.88 ms, jitter =  78.88 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=992
# EPOCH = 431691.108687, wall = 176.91 ms, jitter = 176.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=993
# EPOCH = 431691.234187, wall = 125.50 ms, jitter = 125.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=994
# EPOCH = 431691.345233, wall = 111.05 ms, jitter = 111.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=995
# EPOCH = 431691.463721, wall = 118.49 ms, jitter = 118.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=996
# EPOCH = 431691.590499, wall = 126.78 ms, jitter = 126.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=997
# EPOCH = 431691.702447, wall = 111.95 ms, jitter = 111.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=998
# EPOCH = 431691.817821, wall = 115.37 ms, jitter = 115.37 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=999
# EPOCH = 431691.915894, wall =  98.07 ms, jitter =  98.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1000
# EPOCH = 431692.070018, wall = 154.12 ms, jitter = 154.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1001
# EPOCH = 431692.163828, wall =  93.81 ms, jitter =  93.81 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1002
# EPOCH = 431692.347233, wall = 183.41 ms, jitter = 183.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1003
# EPOCH = 431692.429462, wall =  82.23 ms, jitter =  82.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1004
# EPOCH = 431692.557812, wall = 128.35 ms, jitter = 128.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1005
# EPOCH = 431692.695120, wall = 137.31 ms, jitter = 137.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1006
# EPOCH = 431692.806240, wall = 111.12 ms, jitter = 111.12 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1007
# EPOCH = 431693.062031, wall = 255.79 ms, jitter = 255.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1008
# EPOCH = 431693.185920, wall = 123.89 ms, jitter = 123.89 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1009
# EPOCH = 431693.306295, wall = 120.37 ms, jitter = 120.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1010
# EPOCH = 431693.440200, wall = 133.90 ms, jitter = 133.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1011
# EPOCH = 431693.563979, wall = 123.78 ms, jitter = 123.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1012
# EPOCH = 431693.705852, wall = 141.87 ms, jitter = 141.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1013
# EPOCH = 431693.819883, wall = 114.03 ms, jitter = 114.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1014
# EPOCH = 431693.942213, wall = 122.33 ms, jitter = 122.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1015
# EPOCH = 431694.051122, wall = 108.91 ms, jitter = 108.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1016
# EPOCH = 431694.166385, wall = 115.26 ms, jitter = 115.26 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1017
# EPOCH = 431694.286186, wall = 119.80 ms, jitter = 119.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1018
# EPOCH = 431694.434126, wall = 147.94 ms, jitter = 147.94 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1019
# EPOCH = 431694.556808, wall = 122.68 ms, jitter = 122.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1020
# EPOCH = 431694.663393, wall = 106.58 ms, jitter = 106.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1021
# EPOCH = 431694.795176, wall = 131.78 ms, jitter = 131.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=1022
# EPOCH = 431694.935543, wall = 140.37 ms, jitter = 140.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1023
# EPOCH = 431695.050576, wall = 115.03 ms, jitter = 115.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=0
# EPOCH = 431695.165960, wall = 115.38 ms, jitter = 115.38 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1
# EPOCH = 431695.304956, wall = 139.00 ms, jitter = 139.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=2
# EPOCH = 431695.430730, wall = 125.77 ms, jitter = 125.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=3
# EPOCH = 431695.548075, wall = 117.35 ms, jitter = 117.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=4
# EPOCH = 431695.692924, wall = 144.85 ms, jitter = 144.85 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=5
# EPOCH = 431695.805918, wall = 112.99 ms, jitter = 112.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=6
# EPOCH = 431695.938495, wall = 132.58 ms, jitter = 132.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=7
# EPOCH = 431696.047759, wall = 109.26 ms, jitter = 109.26 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=8
# EPOCH = 431696.184322, wall = 136.56 ms, jitter = 136.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=9
# EPOCH = 431696.289587, wall = 105.27 ms, jitter = 105.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=10
# EPOCH = 431696.438819, wall = 149.23 ms, jitter = 149.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=11
# EPOCH = 431696.547207, wall = 108.39 ms, jitter = 108.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=12
# EPOCH = 431696.692176, wall = 144.97 ms, jitter = 144.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=13
# EPOCH = 431696.810927, wall = 118.75 ms, jitter = 118.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=14
# EPOCH = 431696.922949, wall = 112.02 ms, jitter = 112.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=15
# EPOCH = 431697.037949, wall = 115.00 ms, jitter = 115.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=16
# EPOCH = 431697.182771, wall = 144.82 ms, jitter = 144.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=17
# EPOCH = 431697.288210, wall = 105.44 ms, jitter = 105.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=18
# EPOCH = 431697.433709, wall = 145.50 ms, jitter = 145.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=19
# EPOCH = 431697.541412, wall = 107.70 ms, jitter = 107.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=20
# EPOCH = 431697.667719, wall = 126.31 ms, jitter = 126.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=21
# EPOCH = 431697.796213, wall = 128.49 ms, jitter = 128.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=22
# EPOCH = 431697.928224, wall = 132.01 ms, jitter = 132.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=23
# EPOCH = 431698.043736, wall = 115.51 ms, jitter = 115.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=24
# EPOCH = 431698.182015, wall = 138.28 ms, jitter = 138.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=25
# EPOCH = 431698.303488, wall = 121.47 ms, jitter = 121.47 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=26
# EPOCH = 431698.414372, wall = 110.88 ms, jitter = 110.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=27
# EPOCH = 431698.556953, wall = 142.58 ms, jitter = 142.58 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=28
# EPOCH = 431698.680078, wall = 123.13 ms, jitter = 123.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=29
# EPOCH = 431698.798598, wall = 118.52 ms, jitter = 118.52 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=30
# EPOCH = 431698.945616, wall = 147.02 ms, jitter = 147.02 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=31
# EPOCH = 431699.043460, wall =  97.84 ms, jitter =  97.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=32
# EPOCH = 431699.160950, wall = 117.49 ms, jitter = 117.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=33
# EPOCH = 431699.308883, wall = 147.93 ms, jitter = 147.93 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=34
# EPOCH = 431699.431787, wall = 122.90 ms, jitter = 122.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=35
# EPOCH = 431699.541236, wall = 109.45 ms, jitter = 109.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=36
# EPOCH = 431699.660581, wall = 119.34 ms, jitter = 119.34 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=37
# EPOCH = 431699.790623, wall = 130.04 ms, jitter = 130.04 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=38
# EPOCH = 431699.944283, wall = 153.66 ms, jitter = 153.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=39
# EPOCH = 431700.043025, wall =  98.74 ms, jitter =  98.74 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=40
# EPOCH = 431700.171609, wall = 128.58 ms, jitter = 128.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=41
# EPOCH = 431700.300274, wall = 128.66 ms, jitter = 128.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=42
# EPOCH = 431700.452384, wall = 152.11 ms, jitter = 152.11 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=43
# EPOCH = 431700.570383, wall = 118.00 ms, jitter = 118.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=44
# EPOCH = 431700.689356, wall = 118.97 ms, jitter = 118.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=45
# EPOCH = 431700.812524, wall = 123.17 ms, jitter = 123.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=46
# EPOCH = 431700.919694, wall = 107.17 ms, jitter = 107.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=47
# EPOCH = 431701.061651, wall = 141.96 ms, jitter = 141.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=48
# EPOCH = 431701.166768, wall = 105.12 ms, jitter = 105.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=49
# EPOCH = 431701.292392, wall = 125.62 ms, jitter = 125.62 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=50
# Graceful shutdown.
