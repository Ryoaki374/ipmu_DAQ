# %%
import time, threading, queue, sys, gc
from typing import Tuple

import numpy as np
import pyqtgraph as pg
from PyQt6 import QtCore
from collections import deque

import logging, logging.handlers

import h5py, pathlib
from datetime import datetime

# %% [markdown]
# | **速度目標 [rps]** | **1秒当たり [pulses / s]** | **1iterあたり [pulses]** | **カウント** | **再構成速度 (UP / DOWN) \[rps]** | **偏差 \[%]** |
# | ----------------- | -------------------------- | --------------------------- | ----------------------- | ------------------------------- | -------------------------- |
# | 0.1               | 204.8                      | 25.6                        | 26<br>25                | 0.102<br>0.09765625             | +1.56<br>−2.34             |
# | 0.2               | 409.6                      | 51.2                        | 52<br>51                | 0.203<br>0.19921875             | +1.56<br>−0.39             |
# | 0.3               | 614.4                      | 76.8                        | 77<br>76                | 0.301<br>0.296875               | +0.26<br>−1.04             |
# | 0.4               | 819.2                      | 102.4                       | 103<br>102              | 0.402<br>0.3984375              | +0.59<br>−0.39             |
# | 0.5               | 1 024.0                    | 128.0                       | 128<br>128              | 0.500<br>0.500                  | 0.00<br>0.00               |
# | 0.6               | 1 228.8                    | 153.6                       | 154<br>153              | 0.602<br>0.59765625             | +0.26<br>−0.39             |
# | 0.7               | 1 433.6                    | 179.2                       | 180<br>179              | 0.703<br>0.69921875             | +0.45<br>−0.11             |
# | 0.8               | 1 638.4                    | 204.8                       | 205<br>204              | 0.801<br>0.796875               | +0.10<br>−0.39             |
# | 0.9               | 1 843.2                    | 230.4                       | 231<br>230              | 0.902<br>0.8984375              | +0.26<br>−0.17             |
# | 1.0               | 2 048.0                    | 256.0                       | 256<br>256              | 1.000<br>1.000                  | 0.00<br>0.00               |

# %%
# Please change as you need
t_DC = 90 # [s]
pps = 100 # pulses at initialization
step = 5 # [pps]
rst = 1  # [s] reset time
target_freq = 1  # [rps]
RUN_SEC = 600  # auto‑stop after 10 min



# ------------------------------------------------------------  parameters
DEBUG = True  # set True for jitter log
SAMPLE_RATE = 100_000  # Hz
GEN_CHUNK_SEC = 0.1 # corresponds to PROC_INTERVAL up to 0.05
PROC_INTERVAL = 0.125          # process rate

CHUNK_SEC     = GEN_CHUNK_SEC
N_SAMPLES_GEN = int(SAMPLE_RATE * GEN_CHUNK_SEC) # 100_000 * 0.05 = 5000
SAMPLES_PROC = int(PROC_INTERVAL * SAMPLE_RATE) # 0.125s * 100kHz = 12500
QUEUE_DEPTH = 40  # raw AB backlog
QUAD_DEPTH = 40  # processed backlog (same)
DISPLAY_SEC = RUN_SEC+600
PLOT_SEC = 0.02  # *** fixed x-axis window width (s) ***
GUI_INTERVAL_MS = 50  # update interval (ms) e.g. 50ms = 20Hz

PULSE_HEIGHT = 5.0  # amplitude
INPUT_VELOCITY = 0.1  # rps

PULSE_WIDTH = 1 / (INPUT_VELOCITY * 512)  # period  (s)
PULSE_DUTY = 0.5  # duty
PULSE_PHASE_A = 0.0  # phase offset (s)
PULSE_PHASE_B = -PULSE_WIDTH / 4  # phase offset (s)

QUADPULSE_WIDTH = 0.00025  # width (s) assuming 4x given 1 rps
THRESHOLD_DEFAULT = 2.5  # logic threshold (V)

IDEAL_CPS = INPUT_VELOCITY   # counts/s (constant ideal)

# GUI buffer lengths (empirical)
HISTORY = int(SAMPLE_RATE * PLOT_SEC)
COUNT_HISTORY = int(RUN_SEC / GEN_CHUNK_SEC)
VELO_HISTORY = COUNT_HISTORY

# ------------------------------------------------------------  logging
LOG_CHUNK = 1024       # flush log queue every LOG_CHUNK messages




# ------------------------------------------------------------  queues & stop flag
buf_q = queue.Queue(maxsize=QUEUE_DEPTH)  # raw (t, A, B)
quad_q = queue.Queue(maxsize=QUAD_DEPTH)  # processed (t, A, B, quad)
stop_writer = threading.Event()

log_q = queue.Queue(maxsize=0)
queue_h = logging.handlers.QueueHandler(log_q)
logger = logging.getLogger("debug")
logger.setLevel(logging.INFO)
logger.addHandler(queue_h)

# %%
run_dir = pathlib.Path("../runs")
run_dir.mkdir(exist_ok=True)
timestamp = datetime.now().strftime("%y%m%d%H%M%S")
h5path = f"{run_dir}/{timestamp}.h5"

h5f = h5py.File(h5path, "w")
dset = h5f.create_dataset(
    "log", shape=(0, 3), maxshape=(None, 3),
    dtype=np.float32, chunks=(LOG_CHUNK, 3), compression="gzip"
)

print("dset shape  =", dset.shape)
print("dset maxshape =", dset.maxshape)
# Out:
# dset shape  = (0, 3)
# dset maxshape = (None, 3)

# %%
def gen_chunk_pulse(
    t: np.ndarray,
    *,
    height: float = PULSE_HEIGHT,
    width: float = PULSE_WIDTH,
    duty: float = PULSE_DUTY,
    phase: float = 0.0,
) -> np.ndarray:
    mod = (t + phase) % width
    return np.where(mod < duty * width, height, 0.0).astype(np.float32)


REL_AXIS_GEN = (
    np.arange(N_SAMPLES_GEN, dtype=np.float32) / SAMPLE_RATE
)  # 0 ... 0.2 s

# ------------------------------------------------------------  AB → direction → quad helpers


def gen_pulse_direction(
    dA: np.ndarray,
    dB: np.ndarray,
    *,
    threshold: float,
    prev_A: bool | None = None,
    prev_B: bool | None = None,
) -> tuple[np.ndarray, bool, bool]:
    """
    Detect direction for one block **with perfect edge coverage**.

    Parameters
    ----------
    dA, dB : ndarray[float32]
        Analog levels of phase-A / phase-B for the current block.
    threshold : float
        Logic threshold [V].
    prev_A, prev_B : bool | None
        Logical state of A/B *at the end of the PREVIOUS block*.
        • If None (first block), the function falls back to the
          “self-shift” method used before.

    Returns
    -------
    dir_log : ndarray[int8]
        +1 = CW edge, –1 = CCW edge, 0 = no edge.
    last_A, last_B : bool
        Logical state of A/B at the *end* of this block — feed these
        into the next call to avoid losing the boundary edge.
    """
    # --- current logic level ----------------------------------------
    A = dA > threshold
    B = dB > threshold

    # --- previous sample for XOR -----------------------------------
    if prev_A is None:  # first block → old behaviour
        A_prev = np.concatenate(([A[0]], A[:-1]))
        B_prev = np.concatenate(([B[0]], B[:-1]))
    else:               # use states carried over from last block
        A_prev = np.concatenate(([prev_A], A[:-1]))
        B_prev = np.concatenate(([prev_B], B[:-1]))

    dir_log = (B_prev ^ A).astype(int) - (A_prev ^ B).astype(int)

    return dir_log.astype(np.int8), bool(A[-1]), bool(B[-1])

def pulse_count(dir_log: np.ndarray) -> int:
    #return int(np.sum(dir_log))
    return np.sum(dir_log)


def gen_quad_pulse(
    t: np.ndarray, dir_log: np.ndarray, width: float, height: float, sampling_rate: int
) -> np.ndarray:
    samples = int(width * sampling_rate)
    if samples <= 0:
        return np.zeros_like(dir_log, dtype=np.float32)
    base = np.full(samples, height, dtype=np.float32)
    return np.convolve(dir_log, base, mode="full")[: len(t)]


# ------------------------------------------------------------  producer thread
def generator() -> None:
    """Generate AB rectangular-wave chunks at real-time cadence."""
    chunk_idx = 0
    next_t = time.perf_counter()
    while not stop_writer.is_set():
        base = chunk_idx * GEN_CHUNK_SEC
        t_axis = REL_AXIS_GEN + base
        pulse_A = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_A)
        pulse_B = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_B)
        try:
            buf_q.put_nowait((t_axis, pulse_A, pulse_B))
        except queue.Full:
            pass

        chunk_idx += 1
        next_t += GEN_CHUNK_SEC
        sleep = next_t - time.perf_counter()
        if sleep > 0:
            time.sleep(sleep)
        else:
            next_t = time.perf_counter()


# ------------------------------------------------------------  consumer thread
def log_listener():
    handler = logging.StreamHandler(sys.stdout)
    listener = logging.handlers.QueueListener(log_q, handler)
    listener.start()
    stop_writer.wait()
    listener.stop()

def command_freq(t_DC, pps, step, rst, target_freq, proc_interval):

    time = np.arange(0, t_DC+np.ceil((36000-pps)*target_freq/(step/rst))+60*60*2, proc_interval, dtype=np.float32)
    freq = np.zeros(int((t_DC+np.ceil((36000-pps)*target_freq/(step/rst))+60*60*2)*(1/proc_interval)), dtype=np.float32)

    n_DC = int(np.round(t_DC/proc_interval))  #DCの速度指令値=0rps
    freq[:n_DC] = 0.0

    n_rst = int(np.round(rst/proc_interval))  #加速中の速度指令値
    freq[n_DC: int(n_DC+n_rst*np.ceil((36000-pps)*target_freq/step))] = [pps/36000+target_freq/36000*step*(i+1) 
                                                                         for i in range(int(np.ceil((36000-pps)*target_freq/step))) 
                                                                         for j in freq[int(n_DC+i*n_rst): int(n_DC+(i+1)*n_rst)]]

    n_stable = int(np.round(60*60*2/proc_interval))  #Stableの速度指令値
    freq[int(n_DC+n_rst*np.ceil((36000-pps)*target_freq/step)):] = target_freq

    return time, freq

class IdealVelocityProvider:
    def __init__(self, t_DC, pps, step, rst, target_freq, proc_interval) -> None:
        #num_points: int = int(duration / dt) + 1
        #self.time_axis: np.ndarray = np.linspace(0.0, duration, num_points, dtype=np.float32)
        #self.velocity:  np.ndarray = np.full(num_points, IDEAL_CPS, dtype=np.float32)
        self.t_DC = t_DC
        self.pps = pps
        self.step = step
        self.rst = rst
        self.target_freq = target_freq
        self.proc_interval = proc_interval
        self.time_axis, self.velocity = command_freq(t_DC, pps, step, rst, target_freq, proc_interval)

    def slice(self, t_start: float, t_end: float) -> tuple[np.ndarray, np.ndarray]:
        """Return the time and velocity arrays that fall within [t_start, t_end]."""
        idx_start, idx_end = np.searchsorted(self.time_axis, [t_start, t_end])
        return self.time_axis[idx_start:idx_end], self.velocity[idx_start:idx_end]

ideal: IdealVelocityProvider | None = None  # initialised lazily in processor()


def processor() -> None:
    """
    deque ベース（旧方式）に戻したリアルタイム・コンシューマ。
    - buf_q から取り出した A/B チャンクを deque(Ring) に追加
    - PROC_INTERVAL ごとに SAMPLES_PROC 分を popleft
    - 理想速度 (IdealVelocityProvider) のスライスを同梱して quad_q へ送信
    ※ logger.info() のフォーマットは従来どおり維持
    dequeにしないとバグる
    """
    # ---------- one-time init ----------
    global ideal_provider
    if 'ideal_provider' not in globals() or ideal_provider is None:
        ideal_provider = IdealVelocityProvider(t_DC, pps, step, rst, target_freq, PROC_INTERVAL)

    # ---------- logging ----------
    buf = np.empty((LOG_CHUNK, 3), dtype=np.float32)  # 内部バッファ
    buf_len = 0
    print("buf shape =", buf.shape)

    # --- Python deque リングバッファ ---
    ring_t: deque[np.float32] = deque()
    ring_a: deque[np.float32] = deque()
    ring_b: deque[np.float32] = deque()
    last_A = last_B = None

    next_proc = time.perf_counter()
    cum_count = 0
    last_ts   = next_proc

    while not stop_writer.is_set():
        # ---------- 非ブロッキングで出来るだけ取り込む ----------
        try:
            while True:
                t, pA, pB = buf_q.get_nowait()
                ring_t.extend(t); ring_a.extend(pA); ring_b.extend(pB)
                buf_q.task_done()
        except queue.Empty:
            pass

        # ---------- 次の処理時刻まで待機 ----------
        now = time.perf_counter()
        if now < next_proc:
            time.sleep(next_proc - now)
            continue
        next_proc += PROC_INTERVAL

        # ---------- サンプル不足ならスキップ ----------
        if len(ring_t) < SAMPLES_PROC:
            continue

        # ---------- deque → NumPy へコピー ----------
        t_blk = np.array([ring_t.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        a_blk = np.array([ring_a.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        b_blk = np.array([ring_b.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)

        # ---------- 信号処理 ----------
        dir_log, last_A, last_B = gen_pulse_direction(
            a_blk, b_blk,
            threshold=THRESHOLD_DEFAULT,
            prev_A=last_A, prev_B=last_B
        )
        quad_sig  = gen_quad_pulse(t_blk, dir_log, QUADPULSE_WIDTH, PULSE_HEIGHT, SAMPLE_RATE)
        delta_cnt = pulse_count(dir_log)
        cum_count += delta_cnt
        velocity  = delta_cnt / PROC_INTERVAL / 2048

        # ---------- 理想速度スライス ----------
        t_ref, v_ref = ideal_provider.slice(t_blk[0], t_blk[-1])

        # ---------- ログ ----------
        if DEBUG:
            now = time.perf_counter()
            jitter = (now - last_ts) * 1e3
            logger.info(
                "EPOCH = %f, wall = %6.2f ms, jitter = %6.2f ms  delta c=%+d, v=%6.3f, len(dir_log)=%d, buf_len=%d",
                now, jitter, (now - last_ts) * 1e3,
                delta_cnt, velocity, len(dir_log), buf_len
            )
            last_ts = now

        # ---------- GUI へ送信 ----------
        try:
            quad_q.put_nowait(
                (t_blk, a_blk, b_blk, quad_sig,
                 t_blk[-1], cum_count, velocity,
                 t_ref, v_ref)
            )
        except queue.Full:
            pass

         # ---- append to buffer ----
        buf[buf_len] = (t_blk[-1], (v_ref[-1] if v_ref.size else 0.0), velocity)
        buf_len += 1
        if buf_len == buf.shape[0]:
            n = dset.shape[0]
            dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf
            buf_len = 0

     # ---- final flush ----
    if buf_len:
        n = dset.shape[0]
        dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf[:buf_len]
    h5f.close()


def start_gui() -> None:
    pg.setConfigOptions(useOpenGL=True, background="w", foreground="k")
    app = pg.mkQApp("Live plots")

    win = pg.GraphicsLayoutWidget(title="DEMO")

    layout = win.ci.layout                 # GraphicsLayout の中身
    layout.setColumnStretchFactor(0, 3)
    layout.setColumnStretchFactor(1, 5)
    #win_sig = pg.GraphicsLayoutWidget(show=True, title="Signal")
    #win_vel = pg.GraphicsLayoutWidget(show=True, title="Velocity")

    #win_sig.resize(800, 600)
    #win_vel.resize(800, 600)
    #win_sig.show()


    win.resize(800, 600)
    win.show()

    # [0, 0] A/B -------------------------------------------------------
    plt_ab = win.addPlot(row=0, col=0, title="RAW A / B")
    curve_A = plt_ab.plot(pen=pg.mkPen("#ff4b00", width=3))
    curve_B = plt_ab.plot(pen=pg.mkPen("#005aff", width=3))
    plt_ab.setLabel("left", "Amplitude [V]")
    plt_ab.setLabel("bottom", "Time [s]")
    plt_ab.setYRange(-0.5, PULSE_HEIGHT + 0.5)

    # [1,0] Quad waveform --------------------------------------------
    plt_q = win.addPlot(row=1, col=0, title="Quad pulse")
    curve_Q = plt_q.plot(pen=pg.mkPen("m", width=3))
    plt_q.setLabel("left", "Amplitude [V]")
    plt_q.setLabel("bottom", "Time [s]")
    plt_q.setYRange(-PULSE_HEIGHT - 0.5, PULSE_HEIGHT + 0.5)

    # [0,1] count (fixed x-axis) -------------------------------------
    plt_cnt = win.addPlot(row=0, col=1, title="Velovity - Command")
    curve_cnt = plt_cnt.plot(pen=pg.mkPen("#03af7a", width=3))
    #plt_cnt.setXRange(0, RUN_SEC, padding=0)
    #plt_cnt.enableAutoRange("x", True)
    plt_cnt.setLabel("left", "Diff")
    plt_cnt.setLabel("bottom", "Time [s]")

    # [1,1] velocity (fixed x-axis) ----------------------------------
    plt_vel = win.addPlot(row=1, col=1, title="Velocity")
    curve_vel     = plt_vel.plot(pen=pg.mkPen("#00a0e9", width=3))   # measured
    curve_vel_ref = plt_vel.plot(pen=pg.mkPen("#a05aff", width=3))   # ideal (new)
    #plt_vel.setXRange(0, RUN_SEC, padding=0)
    #plt_vel.enableAutoRange("x", True)
    plt_vel.setLabel("left", "Velocity [rps]")
    plt_vel.setLabel("bottom", "Time [s]")

    # buffers ---------------------------------------------------------
    xs = ya = yb = yq = np.empty(0, dtype=np.float32)
    xs_cnt = y_cnt = np.empty(0, dtype=np.float32)
    xs_vel = y_vel = np.empty(0, dtype=np.float32)
    xr = yr = np.empty(0, dtype=np.float32)       # ideal velocity buffers (new)

    def refresh():
        nonlocal xs, ya, yb, yq, xs_cnt, y_cnt, xs_vel, y_vel, xr, yr
        try:
            while True:
                # receive processed data (+ ideal velocity slice)
                t_ax, pA, pB, qsig, t_end, cum_cnt, vel, t_ref, v_ref = quad_q.get_nowait()

                xs = np.concatenate((xs, t_ax))[-HISTORY:]
                ya = np.concatenate((ya, pA))[-HISTORY:]
                yb = np.concatenate((yb, pB))[-HISTORY:]
                yq = np.concatenate((yq, qsig))[-HISTORY:]

                xs_cnt = np.append(xs_cnt, t_end)[-COUNT_HISTORY:]
                y_cnt  = np.append(y_cnt, vel-v_ref)[-COUNT_HISTORY:]

                xs_vel = np.append(xs_vel, t_end)[-VELO_HISTORY:]
                y_vel  = np.append(y_vel, vel)[-VELO_HISTORY:]

                xr = np.concatenate((xr, t_ref))[-VELO_HISTORY:]
                yr = np.concatenate((yr, v_ref))[-VELO_HISTORY:]

                quad_q.task_done()
        except queue.Empty:
            pass

        # scrolling window for waveforms only
        if xs.size:
            start = xs[-1] - PLOT_SEC
            plt_ab.setXRange(start, xs[-1], padding=0)
            plt_q.setXRange(start, xs[-1], padding=0)

        # --- auto-range for count/velocity ---
        if xs_cnt.size:
            plt_cnt.setXRange(xs_cnt[-1]-10, xs_cnt[-1], padding=0)

        if xs_vel.size:
            plt_vel.setXRange(xs_vel[-1]-10, xs_vel[-1], padding=0)

        # --- push data to curves ---
        curve_A.setData(xs, ya)
        curve_B.setData(xs, yb)
        curve_Q.setData(xs, yq)
        curve_cnt.setData(xs_cnt, y_cnt)
        curve_vel.setData(xs_vel, y_vel)
        curve_vel_ref.setData(xr, yr)

    timer = QtCore.QTimer()
    timer.timeout.connect(refresh)
    timer.start(GUI_INTERVAL_MS)

    # auto-stop after RUN_SEC
    QtCore.QTimer.singleShot(int(RUN_SEC * 1000), lambda: (stop_writer.set(), app.quit()))
    app.exec()

# %%
if __name__ == "__main__":
    threading.Thread(target=log_listener, daemon=True).start()  # start log listener

    gen_th  = threading.Thread(target=generator, daemon=True)
    proc_th = threading.Thread(target=processor, daemon=True)

    gen_th.start()
    proc_th.start()
    # con_th.start()

    start_gui()  # blocks until the user closes the window or timer expires

    # join threads and exit
    stop_writer.set()
    gen_th.join()
    proc_th.join()

    print("Graceful shutdown.")
# Out:
# buf shape = (1024, 3)
# EPOCH = 545883.113021, wall = 1040.71 ms, jitter = 1040.71 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=0
# EPOCH = 545883.190813, wall =  77.79 ms, jitter =  77.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1
# EPOCH = 545883.202623, wall =  11.81 ms, jitter =  11.81 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=2
# EPOCH = 545883.214378, wall =  11.76 ms, jitter =  11.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=3
# EPOCH = 545883.507140, wall = 292.76 ms, jitter = 292.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=4
# EPOCH = 545883.584192, wall =  77.05 ms, jitter =  77.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=5
# EPOCH = 545883.734189, wall = 150.00 ms, jitter = 150.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=6
# EPOCH = 545883.862888, wall = 128.70 ms, jitter = 128.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=7
# EPOCH = 545883.971795, wall = 108.91 ms, jitter = 108.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=8
# EPOCH = 545884.092402, wall = 120.61 ms, jitter = 120.61 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=9
# EPOCH = 545884.211496, wall = 119.09 ms, jitter = 119.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=10
# EPOCH = 545884.355174, wall = 143.68 ms, jitter = 143.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=11
# EPOCH = 545884.474793, wall = 119.62 ms, jitter = 119.62 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=12
# EPOCH = 545884.602142, wall = 127.35 ms, jitter = 127.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=13
# EPOCH = 545884.753304, wall = 151.16 ms, jitter = 151.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=14
# EPOCH = 545884.861009, wall = 107.71 ms, jitter = 107.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=15
# EPOCH = 545884.975000, wall = 113.99 ms, jitter = 113.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=16
# EPOCH = 545885.083459, wall = 108.46 ms, jitter = 108.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=17
# EPOCH = 545885.207030, wall = 123.57 ms, jitter = 123.57 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=18
# EPOCH = 545885.347556, wall = 140.53 ms, jitter = 140.53 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=19
# EPOCH = 545885.461587, wall = 114.03 ms, jitter = 114.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=20
# EPOCH = 545885.597419, wall = 135.83 ms, jitter = 135.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=21
# EPOCH = 545885.737373, wall = 139.95 ms, jitter = 139.95 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=22
# EPOCH = 545885.856793, wall = 119.42 ms, jitter = 119.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=23
# EPOCH = 545885.979218, wall = 122.42 ms, jitter = 122.42 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=24
# EPOCH = 545886.095774, wall = 116.56 ms, jitter = 116.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=25
# EPOCH = 545886.254501, wall = 158.73 ms, jitter = 158.73 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=26
# EPOCH = 545886.352351, wall =  97.85 ms, jitter =  97.85 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=27
# EPOCH = 545886.458470, wall = 106.12 ms, jitter = 106.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=28
# EPOCH = 545886.594760, wall = 136.29 ms, jitter = 136.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=29
# EPOCH = 545886.722436, wall = 127.68 ms, jitter = 127.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=30
# EPOCH = 545886.852809, wall = 130.37 ms, jitter = 130.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=31
# EPOCH = 545886.978631, wall = 125.82 ms, jitter = 125.82 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=32
# EPOCH = 545887.101121, wall = 122.49 ms, jitter = 122.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=33
# EPOCH = 545887.211620, wall = 110.50 ms, jitter = 110.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=34
# EPOCH = 545887.331870, wall = 120.25 ms, jitter = 120.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=35
# EPOCH = 545887.460061, wall = 128.19 ms, jitter = 128.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=36
# EPOCH = 545887.585336, wall = 125.27 ms, jitter = 125.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=37
# EPOCH = 545887.710303, wall = 124.97 ms, jitter = 124.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=38
# EPOCH = 545887.853226, wall = 142.92 ms, jitter = 142.92 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=39
# EPOCH = 545887.979770, wall = 126.54 ms, jitter = 126.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=40
# EPOCH = 545888.087361, wall = 107.59 ms, jitter = 107.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=41
# EPOCH = 545888.228348, wall = 140.99 ms, jitter = 140.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=42
# EPOCH = 545888.337133, wall = 108.79 ms, jitter = 108.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=43
# EPOCH = 545888.502638, wall = 165.50 ms, jitter = 165.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=44
# EPOCH = 545888.583877, wall =  81.24 ms, jitter =  81.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=45
# EPOCH = 545888.733054, wall = 149.18 ms, jitter = 149.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=46
# EPOCH = 545888.855928, wall = 122.87 ms, jitter = 122.87 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=47
# EPOCH = 545888.956581, wall = 100.65 ms, jitter = 100.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=48
# EPOCH = 545889.095960, wall = 139.38 ms, jitter = 139.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=49
# EPOCH = 545889.218078, wall = 122.12 ms, jitter = 122.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=50
# EPOCH = 545889.341279, wall = 123.20 ms, jitter = 123.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=51
# EPOCH = 545889.465000, wall = 123.72 ms, jitter = 123.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=52
# EPOCH = 545889.603339, wall = 138.34 ms, jitter = 138.34 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=53
# EPOCH = 545889.731398, wall = 128.06 ms, jitter = 128.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=54
# EPOCH = 545889.853116, wall = 121.72 ms, jitter = 121.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=55
# EPOCH = 545889.961775, wall = 108.66 ms, jitter = 108.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=56
# EPOCH = 545890.095839, wall = 134.06 ms, jitter = 134.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=57
# EPOCH = 545890.215322, wall = 119.48 ms, jitter = 119.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=58
# EPOCH = 545890.338012, wall = 122.69 ms, jitter = 122.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=59
# EPOCH = 545890.463765, wall = 125.75 ms, jitter = 125.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=60
# EPOCH = 545890.605285, wall = 141.52 ms, jitter = 141.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=61
# EPOCH = 545890.737286, wall = 132.00 ms, jitter = 132.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=62
# EPOCH = 545890.841998, wall = 104.71 ms, jitter = 104.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=63
# EPOCH = 545890.969000, wall = 127.00 ms, jitter = 127.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=64
# EPOCH = 545891.095189, wall = 126.19 ms, jitter = 126.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=65
# EPOCH = 545891.206602, wall = 111.41 ms, jitter = 111.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=66
# EPOCH = 545891.344668, wall = 138.07 ms, jitter = 138.07 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=67
# EPOCH = 545891.467301, wall = 122.63 ms, jitter = 122.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=68
# EPOCH = 545891.580352, wall = 113.05 ms, jitter = 113.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=69
# EPOCH = 545891.725183, wall = 144.83 ms, jitter = 144.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=70
# EPOCH = 545891.856916, wall = 131.73 ms, jitter = 131.73 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=71
# EPOCH = 545891.969079, wall = 112.16 ms, jitter = 112.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=72
# EPOCH = 545892.093994, wall = 124.92 ms, jitter = 124.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=73
# EPOCH = 545892.204866, wall = 110.87 ms, jitter = 110.87 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=74
# EPOCH = 545892.339848, wall = 134.98 ms, jitter = 134.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=75
# EPOCH = 545892.464987, wall = 125.14 ms, jitter = 125.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=76
# EPOCH = 545892.585083, wall = 120.10 ms, jitter = 120.10 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=77
# EPOCH = 545892.712759, wall = 127.68 ms, jitter = 127.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=78
# EPOCH = 545892.839013, wall = 126.25 ms, jitter = 126.25 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=79
# EPOCH = 545892.983775, wall = 144.76 ms, jitter = 144.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=80
# EPOCH = 545893.103499, wall = 119.72 ms, jitter = 119.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=81
# EPOCH = 545893.209320, wall = 105.82 ms, jitter = 105.82 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=82
# EPOCH = 545893.350576, wall = 141.26 ms, jitter = 141.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=83
# EPOCH = 545893.465568, wall = 114.99 ms, jitter = 114.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=84
# EPOCH = 545893.661021, wall = 195.45 ms, jitter = 195.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=85
# EPOCH = 545893.784888, wall = 123.87 ms, jitter = 123.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=86
# EPOCH = 545893.929300, wall = 144.41 ms, jitter = 144.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=87
# EPOCH = 545893.996580, wall =  67.28 ms, jitter =  67.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=88
# EPOCH = 545894.086249, wall =  89.67 ms, jitter =  89.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=89
# EPOCH = 545894.227001, wall = 140.75 ms, jitter = 140.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=90
# EPOCH = 545894.343023, wall = 116.02 ms, jitter = 116.02 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=91
# EPOCH = 545894.483618, wall = 140.59 ms, jitter = 140.59 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=92
# EPOCH = 545894.603037, wall = 119.42 ms, jitter = 119.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=93
# EPOCH = 545894.714445, wall = 111.41 ms, jitter = 111.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=94
# EPOCH = 545894.884315, wall = 169.87 ms, jitter = 169.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=95
# EPOCH = 545894.982015, wall =  97.70 ms, jitter =  97.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=96
# EPOCH = 545895.091950, wall = 109.94 ms, jitter = 109.94 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=97
# EPOCH = 545895.225262, wall = 133.31 ms, jitter = 133.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=98
# EPOCH = 545895.371919, wall = 146.66 ms, jitter = 146.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=99
# EPOCH = 545895.465048, wall =  93.13 ms, jitter =  93.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=100
# EPOCH = 545895.604500, wall = 139.45 ms, jitter = 139.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=101
# EPOCH = 545895.717749, wall = 113.25 ms, jitter = 113.25 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=102
# EPOCH = 545895.856335, wall = 138.59 ms, jitter = 138.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=103
# EPOCH = 545895.978873, wall = 122.54 ms, jitter = 122.54 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=104
# EPOCH = 545896.131876, wall = 153.00 ms, jitter = 153.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=105
# EPOCH = 545896.242948, wall = 111.07 ms, jitter = 111.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=106
# EPOCH = 545896.358780, wall = 115.83 ms, jitter = 115.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=107
# EPOCH = 545896.461314, wall = 102.53 ms, jitter = 102.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=108
# EPOCH = 545896.590934, wall = 129.62 ms, jitter = 129.62 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=109
# EPOCH = 545896.723514, wall = 132.58 ms, jitter = 132.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=110
# EPOCH = 545896.863067, wall = 139.55 ms, jitter = 139.55 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=111
# EPOCH = 545896.965081, wall = 102.01 ms, jitter = 102.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=112
# EPOCH = 545897.081000, wall = 115.92 ms, jitter = 115.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=113
# EPOCH = 545897.212175, wall = 131.18 ms, jitter = 131.18 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=114
# EPOCH = 545897.354575, wall = 142.40 ms, jitter = 142.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=115
# EPOCH = 545897.485612, wall = 131.04 ms, jitter = 131.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=116
# EPOCH = 545897.616047, wall = 130.43 ms, jitter = 130.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=117
# EPOCH = 545897.710562, wall =  94.52 ms, jitter =  94.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=118
# EPOCH = 545897.843723, wall = 133.16 ms, jitter = 133.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=119
# EPOCH = 545897.990284, wall = 146.56 ms, jitter = 146.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=120
# EPOCH = 545898.107570, wall = 117.29 ms, jitter = 117.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=121
# EPOCH = 545898.234265, wall = 126.69 ms, jitter = 126.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=122
# EPOCH = 545898.354174, wall = 119.91 ms, jitter = 119.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=123
# EPOCH = 545898.470696, wall = 116.52 ms, jitter = 116.52 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=124
# EPOCH = 545898.620399, wall = 149.70 ms, jitter = 149.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=125
# EPOCH = 545898.734384, wall = 113.99 ms, jitter = 113.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=126
# EPOCH = 545898.840917, wall = 106.53 ms, jitter = 106.53 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=127
# EPOCH = 545898.957676, wall = 116.76 ms, jitter = 116.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=128
# EPOCH = 545899.081137, wall = 123.46 ms, jitter = 123.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=129
# EPOCH = 545899.215527, wall = 134.39 ms, jitter = 134.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=130
# EPOCH = 545899.360642, wall = 145.11 ms, jitter = 145.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=131
# EPOCH = 545899.458962, wall =  98.32 ms, jitter =  98.32 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=132
# EPOCH = 545899.602750, wall = 143.79 ms, jitter = 143.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=133
# EPOCH = 545899.708245, wall = 105.49 ms, jitter = 105.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=134
# EPOCH = 545899.843088, wall = 134.84 ms, jitter = 134.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=135
# EPOCH = 545899.965974, wall = 122.89 ms, jitter = 122.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=136
# EPOCH = 545900.112833, wall = 146.86 ms, jitter = 146.86 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=137
# EPOCH = 545900.229785, wall = 116.95 ms, jitter = 116.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=138
# EPOCH = 545900.343336, wall = 113.55 ms, jitter = 113.55 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=139
# EPOCH = 545900.471592, wall = 128.26 ms, jitter = 128.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=140
# EPOCH = 545900.587557, wall = 115.96 ms, jitter = 115.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=141
# EPOCH = 545900.720443, wall = 132.89 ms, jitter = 132.89 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=142
# EPOCH = 545900.838019, wall = 117.58 ms, jitter = 117.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=143
# EPOCH = 545900.989827, wall = 151.81 ms, jitter = 151.81 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=144
# EPOCH = 545901.100755, wall = 110.93 ms, jitter = 110.93 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=145
# EPOCH = 545901.229388, wall = 128.63 ms, jitter = 128.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=146
# EPOCH = 545901.337521, wall = 108.13 ms, jitter = 108.13 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=147
# EPOCH = 545901.468091, wall = 130.57 ms, jitter = 130.57 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=148
# EPOCH = 545901.608283, wall = 140.19 ms, jitter = 140.19 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=149
# EPOCH = 545901.707518, wall =  99.24 ms, jitter =  99.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=150
# EPOCH = 545901.836144, wall = 128.63 ms, jitter = 128.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=151
# EPOCH = 545901.982150, wall = 146.01 ms, jitter = 146.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=152
# EPOCH = 545902.100404, wall = 118.25 ms, jitter = 118.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=153
# EPOCH = 545902.223416, wall = 123.01 ms, jitter = 123.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=154
# EPOCH = 545902.335852, wall = 112.44 ms, jitter = 112.44 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=155
# EPOCH = 545902.461226, wall = 125.37 ms, jitter = 125.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=156
# EPOCH = 545902.600521, wall = 139.30 ms, jitter = 139.30 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=157
# EPOCH = 545902.721521, wall = 121.00 ms, jitter = 121.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=158
# EPOCH = 545902.843212, wall = 121.69 ms, jitter = 121.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=159
# EPOCH = 545902.958702, wall = 115.49 ms, jitter = 115.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=160
# EPOCH = 545903.094286, wall = 135.58 ms, jitter = 135.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=161
# EPOCH = 545903.231274, wall = 136.99 ms, jitter = 136.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=162
# EPOCH = 545903.336946, wall = 105.67 ms, jitter = 105.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=163
# EPOCH = 545903.473844, wall = 136.90 ms, jitter = 136.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=164
# EPOCH = 545903.593856, wall = 120.01 ms, jitter = 120.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=165
# EPOCH = 545903.727560, wall = 133.70 ms, jitter = 133.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=166
# EPOCH = 545903.849126, wall = 121.57 ms, jitter = 121.57 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=167
# EPOCH = 545903.977920, wall = 128.79 ms, jitter = 128.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=168
# EPOCH = 545904.092753, wall = 114.83 ms, jitter = 114.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=169
# EPOCH = 545904.221846, wall = 129.09 ms, jitter = 129.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=170
# EPOCH = 545904.337083, wall = 115.24 ms, jitter = 115.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=171
# EPOCH = 545904.476042, wall = 138.96 ms, jitter = 138.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=172
# EPOCH = 545904.589848, wall = 113.81 ms, jitter = 113.81 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=173
# EPOCH = 545904.728400, wall = 138.55 ms, jitter = 138.55 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=174
# EPOCH = 545904.833698, wall = 105.30 ms, jitter = 105.30 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=175
# EPOCH = 545904.960674, wall = 126.98 ms, jitter = 126.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=176
# EPOCH = 545905.099777, wall = 139.10 ms, jitter = 139.10 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=177
# EPOCH = 545905.223058, wall = 123.28 ms, jitter = 123.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=178
# EPOCH = 545905.337618, wall = 114.56 ms, jitter = 114.56 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=179
# EPOCH = 545905.476068, wall = 138.45 ms, jitter = 138.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=180
# EPOCH = 545905.586587, wall = 110.52 ms, jitter = 110.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=181
# EPOCH = 545905.724442, wall = 137.85 ms, jitter = 137.85 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=182
# EPOCH = 545905.840943, wall = 116.50 ms, jitter = 116.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=183
# EPOCH = 545905.968222, wall = 127.28 ms, jitter = 127.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=184
# EPOCH = 545906.111020, wall = 142.80 ms, jitter = 142.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=185
# EPOCH = 545906.231613, wall = 120.59 ms, jitter = 120.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=186
# EPOCH = 545906.338305, wall = 106.69 ms, jitter = 106.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=187
# EPOCH = 545906.474795, wall = 136.49 ms, jitter = 136.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=188
# EPOCH = 545906.633616, wall = 158.82 ms, jitter = 158.82 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=189
# EPOCH = 545906.728155, wall =  94.54 ms, jitter =  94.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=190
# EPOCH = 545906.834264, wall = 106.11 ms, jitter = 106.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=191
# EPOCH = 545906.972944, wall = 138.68 ms, jitter = 138.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=192
# EPOCH = 545907.085814, wall = 112.87 ms, jitter = 112.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=193
# EPOCH = 545907.233368, wall = 147.55 ms, jitter = 147.55 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=194
# EPOCH = 545907.351924, wall = 118.56 ms, jitter = 118.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=195
# EPOCH = 545907.493672, wall = 141.75 ms, jitter = 141.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=196
# EPOCH = 545907.590717, wall =  97.04 ms, jitter =  97.04 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=197
# EPOCH = 545907.728565, wall = 137.85 ms, jitter = 137.85 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=198
# EPOCH = 545907.860909, wall = 132.34 ms, jitter = 132.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=199
# EPOCH = 545908.039512, wall = 178.60 ms, jitter = 178.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=200
# EPOCH = 545908.165372, wall = 125.86 ms, jitter = 125.86 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=201
# EPOCH = 545908.230605, wall =  65.23 ms, jitter =  65.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=202
# EPOCH = 545908.370003, wall = 139.40 ms, jitter = 139.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=203
# EPOCH = 545908.547081, wall = 177.08 ms, jitter = 177.08 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=204
# EPOCH = 545908.619169, wall =  72.09 ms, jitter =  72.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=205
# EPOCH = 545908.885385, wall = 266.22 ms, jitter = 266.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=206
# EPOCH = 545909.079821, wall = 194.44 ms, jitter = 194.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=207
# EPOCH = 545909.162967, wall =  83.15 ms, jitter =  83.15 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=208
# EPOCH = 545909.215399, wall =  52.43 ms, jitter =  52.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=209
# EPOCH = 545909.392042, wall = 176.64 ms, jitter = 176.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=210
# EPOCH = 545909.445175, wall =  53.13 ms, jitter =  53.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=211
# EPOCH = 545909.633275, wall = 188.10 ms, jitter = 188.10 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=212
# EPOCH = 545909.819232, wall = 185.96 ms, jitter = 185.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=213
# EPOCH = 545909.868653, wall =  49.42 ms, jitter =  49.42 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=214
# EPOCH = 545910.079286, wall = 210.63 ms, jitter = 210.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=215
# EPOCH = 545910.193678, wall = 114.39 ms, jitter = 114.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=216
# EPOCH = 545910.243525, wall =  49.85 ms, jitter =  49.85 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=217
# EPOCH = 545910.500089, wall = 256.56 ms, jitter = 256.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=218
# EPOCH = 545910.628798, wall = 128.71 ms, jitter = 128.71 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=219
# EPOCH = 545910.866462, wall = 237.66 ms, jitter = 237.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=220
# EPOCH = 545910.899107, wall =  32.65 ms, jitter =  32.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=221
# EPOCH = 545911.031937, wall = 132.83 ms, jitter = 132.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=222
# EPOCH = 545911.133772, wall = 101.83 ms, jitter = 101.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=223
# EPOCH = 545911.301931, wall = 168.16 ms, jitter = 168.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=224
# EPOCH = 545911.351362, wall =  49.43 ms, jitter =  49.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=225
# EPOCH = 545911.484186, wall = 132.82 ms, jitter = 132.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=226
# EPOCH = 545911.668492, wall = 184.31 ms, jitter = 184.31 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=227
# EPOCH = 545911.801378, wall = 132.89 ms, jitter = 132.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=228
# EPOCH = 545912.135890, wall = 334.51 ms, jitter = 334.51 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=229
# EPOCH = 545912.177903, wall =  42.01 ms, jitter =  42.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=230
# EPOCH = 545912.359506, wall = 181.60 ms, jitter = 181.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=231
# EPOCH = 545912.465523, wall = 106.02 ms, jitter = 106.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=232
# EPOCH = 545912.502287, wall =  36.76 ms, jitter =  36.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=233
# EPOCH = 545912.669492, wall = 167.20 ms, jitter = 167.20 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=234
# EPOCH = 545912.730290, wall =  60.80 ms, jitter =  60.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=235
# EPOCH = 545912.891325, wall = 161.03 ms, jitter = 161.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=236
# EPOCH = 545913.056791, wall = 165.47 ms, jitter = 165.47 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=237
# EPOCH = 545913.106017, wall =  49.23 ms, jitter =  49.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=238
# EPOCH = 545913.267520, wall = 161.50 ms, jitter = 161.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=239
# EPOCH = 545913.417568, wall = 150.05 ms, jitter = 150.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=240
# EPOCH = 545913.534870, wall = 117.30 ms, jitter = 117.30 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=241
# EPOCH = 545913.771765, wall = 236.89 ms, jitter = 236.89 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=242
# EPOCH = 545913.841293, wall =  69.53 ms, jitter =  69.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=243
# EPOCH = 545914.100267, wall = 258.97 ms, jitter = 258.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=244
# EPOCH = 545914.159991, wall =  59.72 ms, jitter =  59.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=245
# EPOCH = 545914.350585, wall = 190.59 ms, jitter = 190.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=246
# EPOCH = 545914.430879, wall =  80.29 ms, jitter =  80.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=247
# EPOCH = 545914.691077, wall = 260.20 ms, jitter = 260.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=248
# EPOCH = 545914.807563, wall = 116.49 ms, jitter = 116.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=249
# EPOCH = 545914.887696, wall =  80.13 ms, jitter =  80.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=250
# EPOCH = 545915.088350, wall = 200.65 ms, jitter = 200.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=251
# EPOCH = 545915.184133, wall =  95.78 ms, jitter =  95.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=252
# EPOCH = 545915.249352, wall =  65.22 ms, jitter =  65.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=253
# EPOCH = 545915.541415, wall = 292.06 ms, jitter = 292.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=254
# EPOCH = 545915.597451, wall =  56.04 ms, jitter =  56.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=255
# EPOCH = 545915.650107, wall =  52.66 ms, jitter =  52.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=256
# EPOCH = 545915.852009, wall = 201.90 ms, jitter = 201.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=257
# EPOCH = 545916.048210, wall = 196.20 ms, jitter = 196.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=258
# EPOCH = 545916.115544, wall =  67.33 ms, jitter =  67.33 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=259
# EPOCH = 545916.278342, wall = 162.80 ms, jitter = 162.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=260
# EPOCH = 545916.389951, wall = 111.61 ms, jitter = 111.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=261
# EPOCH = 545916.542034, wall = 152.08 ms, jitter = 152.08 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=262
# EPOCH = 545916.624078, wall =  82.04 ms, jitter =  82.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=263
# EPOCH = 545916.902839, wall = 278.76 ms, jitter = 278.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=264
# EPOCH = 545917.029364, wall = 126.53 ms, jitter = 126.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=265
# EPOCH = 545917.147497, wall = 118.13 ms, jitter = 118.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=266
# EPOCH = 545917.336974, wall = 189.48 ms, jitter = 189.48 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=267
# EPOCH = 545917.455920, wall = 118.95 ms, jitter = 118.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=268
# EPOCH = 545917.539154, wall =  83.23 ms, jitter =  83.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=269
# EPOCH = 545917.724050, wall = 184.90 ms, jitter = 184.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=270
# EPOCH = 545917.834833, wall = 110.78 ms, jitter = 110.78 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=271
# EPOCH = 545918.092270, wall = 257.44 ms, jitter = 257.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=272
# EPOCH = 545918.143326, wall =  51.06 ms, jitter =  51.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=273
# EPOCH = 545918.286373, wall = 143.05 ms, jitter = 143.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=274
# EPOCH = 545918.424995, wall = 138.62 ms, jitter = 138.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=275
# EPOCH = 545918.588597, wall = 163.60 ms, jitter = 163.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=276
# EPOCH = 545918.638209, wall =  49.61 ms, jitter =  49.61 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=277
# EPOCH = 545918.729286, wall =  91.08 ms, jitter =  91.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=278
# EPOCH = 545919.383442, wall = 654.16 ms, jitter = 654.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=279
# EPOCH = 545920.568154, wall = 1184.71 ms, jitter = 1184.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=280
# EPOCH = 545920.645834, wall =  77.68 ms, jitter =  77.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=281
# EPOCH = 545920.735405, wall =  89.57 ms, jitter =  89.57 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=282
# EPOCH = 545920.915448, wall = 180.04 ms, jitter = 180.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=283
# EPOCH = 545920.983407, wall =  67.96 ms, jitter =  67.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=284
# EPOCH = 545921.077869, wall =  94.46 ms, jitter =  94.46 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=285
# EPOCH = 545921.208819, wall = 130.95 ms, jitter = 130.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=286
# EPOCH = 545921.309100, wall = 100.28 ms, jitter = 100.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=287
# EPOCH = 545921.345041, wall =  35.94 ms, jitter =  35.94 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=288
# EPOCH = 545921.403873, wall =  58.83 ms, jitter =  58.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=289
# EPOCH = 545921.742277, wall = 338.40 ms, jitter = 338.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=290
# EPOCH = 545922.231595, wall = 489.32 ms, jitter = 489.32 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=291
# EPOCH = 545922.426880, wall = 195.29 ms, jitter = 195.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=292
# EPOCH = 545922.498914, wall =  72.03 ms, jitter =  72.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=293
# EPOCH = 545922.635404, wall = 136.49 ms, jitter = 136.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=294
# EPOCH = 545922.774466, wall = 139.06 ms, jitter = 139.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=295
# EPOCH = 545922.857745, wall =  83.28 ms, jitter =  83.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=296
# EPOCH = 545923.011481, wall = 153.74 ms, jitter = 153.74 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=297
# EPOCH = 545923.165567, wall = 154.09 ms, jitter = 154.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=298
# EPOCH = 545923.239543, wall =  73.98 ms, jitter =  73.98 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=299
# EPOCH = 545923.435648, wall = 196.11 ms, jitter = 196.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=300
# EPOCH = 545923.480288, wall =  44.64 ms, jitter =  44.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=301
# EPOCH = 545923.644980, wall = 164.69 ms, jitter = 164.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=302
# EPOCH = 545923.752578, wall = 107.60 ms, jitter = 107.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=303
# EPOCH = 545923.977134, wall = 224.56 ms, jitter = 224.56 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=304
# EPOCH = 545924.103737, wall = 126.60 ms, jitter = 126.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=305
# EPOCH = 545924.183183, wall =  79.45 ms, jitter =  79.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=306
# EPOCH = 545924.459082, wall = 275.90 ms, jitter = 275.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=307
# EPOCH = 545924.558015, wall =  98.93 ms, jitter =  98.93 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=308
# EPOCH = 545924.731424, wall = 173.41 ms, jitter = 173.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=309
# EPOCH = 545924.883104, wall = 151.68 ms, jitter = 151.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=310
# EPOCH = 545925.118393, wall = 235.29 ms, jitter = 235.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=311
# EPOCH = 545925.373680, wall = 255.29 ms, jitter = 255.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=312
# EPOCH = 545925.498290, wall = 124.61 ms, jitter = 124.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=313
# EPOCH = 545925.705783, wall = 207.49 ms, jitter = 207.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=314
# EPOCH = 545925.858928, wall = 153.15 ms, jitter = 153.15 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=315
# EPOCH = 545925.971741, wall = 112.81 ms, jitter = 112.81 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=316
# EPOCH = 545926.104956, wall = 133.22 ms, jitter = 133.22 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=317
# EPOCH = 545926.142128, wall =  37.17 ms, jitter =  37.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=318
# EPOCH = 545926.187130, wall =  45.00 ms, jitter =  45.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=319
# EPOCH = 545926.644310, wall = 457.18 ms, jitter = 457.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=320
# EPOCH = 545926.775579, wall = 131.27 ms, jitter = 131.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=321
# EPOCH = 545926.930557, wall = 154.98 ms, jitter = 154.98 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=322
# EPOCH = 545926.965543, wall =  34.99 ms, jitter =  34.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=323
# EPOCH = 545927.269725, wall = 304.18 ms, jitter = 304.18 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=324
# EPOCH = 545927.400728, wall = 131.00 ms, jitter = 131.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=325
# EPOCH = 545927.551453, wall = 150.73 ms, jitter = 150.73 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=326
# EPOCH = 545927.649686, wall =  98.23 ms, jitter =  98.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=327
# EPOCH = 545927.717664, wall =  67.98 ms, jitter =  67.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=328
# EPOCH = 545927.863658, wall = 145.99 ms, jitter = 145.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=329
# EPOCH = 545928.001879, wall = 138.22 ms, jitter = 138.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=330
# EPOCH = 545928.132443, wall = 130.56 ms, jitter = 130.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=331
# EPOCH = 545928.291408, wall = 158.96 ms, jitter = 158.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=332
# EPOCH = 545928.350742, wall =  59.33 ms, jitter =  59.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=333
# EPOCH = 545928.489091, wall = 138.35 ms, jitter = 138.35 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=334
# EPOCH = 545928.614943, wall = 125.85 ms, jitter = 125.85 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=335
# EPOCH = 545928.795939, wall = 181.00 ms, jitter = 181.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=336
# EPOCH = 545928.889266, wall =  93.33 ms, jitter =  93.33 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=337
# EPOCH = 545929.013407, wall = 124.14 ms, jitter = 124.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=338
# EPOCH = 545929.152180, wall = 138.77 ms, jitter = 138.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=339
# EPOCH = 545929.247505, wall =  95.33 ms, jitter =  95.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=340
# EPOCH = 545929.357333, wall = 109.83 ms, jitter = 109.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=341
# EPOCH = 545929.505161, wall = 147.83 ms, jitter = 147.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=342
# EPOCH = 545929.594289, wall =  89.13 ms, jitter =  89.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=343
# EPOCH = 545929.722352, wall = 128.06 ms, jitter = 128.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=344
# EPOCH = 545929.883612, wall = 161.26 ms, jitter = 161.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=345
# EPOCH = 545929.977914, wall =  94.30 ms, jitter =  94.30 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=346
# EPOCH = 545930.144066, wall = 166.15 ms, jitter = 166.15 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=347
# EPOCH = 545930.251112, wall = 107.05 ms, jitter = 107.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=348
# EPOCH = 545930.364605, wall = 113.49 ms, jitter = 113.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=349
# EPOCH = 545930.531322, wall = 166.72 ms, jitter = 166.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=350
# EPOCH = 545930.662856, wall = 131.53 ms, jitter = 131.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=351
# EPOCH = 545930.724251, wall =  61.39 ms, jitter =  61.39 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=352
# EPOCH = 545930.889233, wall = 164.98 ms, jitter = 164.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=353
# EPOCH = 545931.036162, wall = 146.93 ms, jitter = 146.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=354
# EPOCH = 545931.116960, wall =  80.80 ms, jitter =  80.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=355
# EPOCH = 545931.263061, wall = 146.10 ms, jitter = 146.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=356
# EPOCH = 545931.378950, wall = 115.89 ms, jitter = 115.89 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=357
# EPOCH = 545931.473127, wall =  94.18 ms, jitter =  94.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=358
# EPOCH = 545931.608512, wall = 135.39 ms, jitter = 135.39 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=359
# EPOCH = 545931.720709, wall = 112.20 ms, jitter = 112.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=360
# EPOCH = 545931.894887, wall = 174.18 ms, jitter = 174.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=361
# EPOCH = 545931.990644, wall =  95.76 ms, jitter =  95.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=362
# EPOCH = 545932.142767, wall = 152.12 ms, jitter = 152.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=363
# EPOCH = 545932.286549, wall = 143.78 ms, jitter = 143.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=364
# EPOCH = 545932.352438, wall =  65.89 ms, jitter =  65.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=365
# EPOCH = 545932.543951, wall = 191.51 ms, jitter = 191.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=366
# EPOCH = 545932.702913, wall = 158.96 ms, jitter = 158.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=367
# EPOCH = 545932.733452, wall =  30.54 ms, jitter =  30.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=368
# EPOCH = 545932.879943, wall = 146.49 ms, jitter = 146.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=369
# EPOCH = 545933.031275, wall = 151.33 ms, jitter = 151.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=370
# EPOCH = 545933.159485, wall = 128.21 ms, jitter = 128.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=371
# EPOCH = 545933.309109, wall = 149.62 ms, jitter = 149.62 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=372
# EPOCH = 545933.488142, wall = 179.03 ms, jitter = 179.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=373
# EPOCH = 545933.604835, wall = 116.69 ms, jitter = 116.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=374
# EPOCH = 545933.769866, wall = 165.03 ms, jitter = 165.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=375
# EPOCH = 545933.873765, wall = 103.90 ms, jitter = 103.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=376
# EPOCH = 545933.978424, wall = 104.66 ms, jitter = 104.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=377
# EPOCH = 545934.098193, wall = 119.77 ms, jitter = 119.77 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=378
# EPOCH = 545934.227184, wall = 128.99 ms, jitter = 128.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=379
# EPOCH = 545934.372492, wall = 145.31 ms, jitter = 145.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=380
# EPOCH = 545934.486972, wall = 114.48 ms, jitter = 114.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=381
# EPOCH = 545934.635020, wall = 148.05 ms, jitter = 148.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=382
# EPOCH = 545934.730466, wall =  95.45 ms, jitter =  95.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=383
# EPOCH = 545934.852193, wall = 121.73 ms, jitter = 121.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=384
# EPOCH = 545935.001406, wall = 149.21 ms, jitter = 149.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=385
# EPOCH = 545935.108735, wall = 107.33 ms, jitter = 107.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=386
# EPOCH = 545935.267120, wall = 158.38 ms, jitter = 158.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=387
# EPOCH = 545935.378258, wall = 111.14 ms, jitter = 111.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=388
# EPOCH = 545935.496389, wall = 118.13 ms, jitter = 118.13 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=389
# EPOCH = 545935.624897, wall = 128.51 ms, jitter = 128.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=390
# EPOCH = 545935.720618, wall =  95.72 ms, jitter =  95.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=391
# EPOCH = 545935.878513, wall = 157.89 ms, jitter = 157.89 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=392
# EPOCH = 545936.010703, wall = 132.19 ms, jitter = 132.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=393
# EPOCH = 545936.112829, wall = 102.13 ms, jitter = 102.13 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=394
# EPOCH = 545936.221635, wall = 108.81 ms, jitter = 108.81 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=395
# EPOCH = 545936.346257, wall = 124.62 ms, jitter = 124.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=396
# EPOCH = 545936.510589, wall = 164.33 ms, jitter = 164.33 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=397
# EPOCH = 545936.640171, wall = 129.58 ms, jitter = 129.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=398
# EPOCH = 545936.762454, wall = 122.28 ms, jitter = 122.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=399
# EPOCH = 545936.910277, wall = 147.82 ms, jitter = 147.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=400
# EPOCH = 545937.029146, wall = 118.87 ms, jitter = 118.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=401
# EPOCH = 545937.123618, wall =  94.47 ms, jitter =  94.47 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=402
# EPOCH = 545937.225897, wall = 102.28 ms, jitter = 102.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=403
# EPOCH = 545937.365115, wall = 139.22 ms, jitter = 139.22 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=404
# EPOCH = 545937.561904, wall = 196.79 ms, jitter = 196.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=405
# EPOCH = 545937.628218, wall =  66.31 ms, jitter =  66.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=406
# EPOCH = 545937.779500, wall = 151.28 ms, jitter = 151.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=407
# EPOCH = 545937.886034, wall = 106.53 ms, jitter = 106.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=408
# EPOCH = 545938.037362, wall = 151.33 ms, jitter = 151.33 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=409
# EPOCH = 545938.102608, wall =  65.25 ms, jitter =  65.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=410
# EPOCH = 545938.217111, wall = 114.50 ms, jitter = 114.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=411
# EPOCH = 545938.357990, wall = 140.88 ms, jitter = 140.88 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=412
# EPOCH = 545938.536699, wall = 178.71 ms, jitter = 178.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=413
# ...
# EPOCH = 546066.612487, wall = 129.50 ms, jitter = 129.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=414
# EPOCH = 546066.725437, wall = 112.95 ms, jitter = 112.95 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=415
# EPOCH = 546066.837746, wall = 112.31 ms, jitter = 112.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=416
# EPOCH = 546066.958669, wall = 120.92 ms, jitter = 120.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=417
# EPOCH = 546067.111433, wall = 152.76 ms, jitter = 152.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=418
# EPOCH = 546067.246501, wall = 135.07 ms, jitter = 135.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=419
# EPOCH = 546067.336819, wall =  90.32 ms, jitter =  90.32 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=420
# EPOCH = 546067.476852, wall = 140.03 ms, jitter = 140.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=421
# EPOCH = 546067.604537, wall = 127.69 ms, jitter = 127.69 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=422
# EPOCH = 546067.717593, wall = 113.06 ms, jitter = 113.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=423
# EPOCH = 546067.837008, wall = 119.41 ms, jitter = 119.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=424
# EPOCH = 546067.967278, wall = 130.27 ms, jitter = 130.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=425
# EPOCH = 546068.090128, wall = 122.85 ms, jitter = 122.85 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=426
# EPOCH = 546068.241728, wall = 151.60 ms, jitter = 151.60 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=427
# EPOCH = 546068.337154, wall =  95.43 ms, jitter =  95.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=428
# EPOCH = 546068.479300, wall = 142.15 ms, jitter = 142.15 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=429
# EPOCH = 546068.599870, wall = 120.57 ms, jitter = 120.57 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=430
# EPOCH = 546068.712893, wall = 113.02 ms, jitter = 113.02 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=431
# EPOCH = 546068.841858, wall = 128.96 ms, jitter = 128.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=432
# EPOCH = 546068.962909, wall = 121.05 ms, jitter = 121.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=433
# EPOCH = 546069.098193, wall = 135.28 ms, jitter = 135.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=434
# EPOCH = 546069.226531, wall = 128.34 ms, jitter = 128.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=435
# EPOCH = 546069.356008, wall = 129.48 ms, jitter = 129.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=436
# EPOCH = 546069.474192, wall = 118.18 ms, jitter = 118.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=437
# EPOCH = 546069.590237, wall = 116.04 ms, jitter = 116.04 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=438
# EPOCH = 546069.706429, wall = 116.19 ms, jitter = 116.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=439
# EPOCH = 546069.835211, wall = 128.78 ms, jitter = 128.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=440
# EPOCH = 546069.979819, wall = 144.61 ms, jitter = 144.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=441
# EPOCH = 546070.110628, wall = 130.81 ms, jitter = 130.81 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=442
# EPOCH = 546070.396902, wall = 286.27 ms, jitter = 286.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=443
# EPOCH = 546070.421316, wall =  24.41 ms, jitter =  24.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=444
# EPOCH = 546070.524309, wall = 102.99 ms, jitter = 102.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=445
# EPOCH = 546070.635966, wall = 111.66 ms, jitter = 111.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=446
# EPOCH = 546070.723426, wall =  87.46 ms, jitter =  87.46 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=447
# EPOCH = 546070.857732, wall = 134.31 ms, jitter = 134.31 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=448
# EPOCH = 546070.992235, wall = 134.50 ms, jitter = 134.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=449
# EPOCH = 546071.090600, wall =  98.36 ms, jitter =  98.36 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=450
# EPOCH = 546071.213034, wall = 122.43 ms, jitter = 122.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=451
# EPOCH = 546071.352995, wall = 139.96 ms, jitter = 139.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=452
# EPOCH = 546071.485473, wall = 132.48 ms, jitter = 132.48 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=453
# EPOCH = 546071.588895, wall = 103.42 ms, jitter = 103.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=454
# EPOCH = 546071.743647, wall = 154.75 ms, jitter = 154.75 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=455
# EPOCH = 546071.859364, wall = 115.72 ms, jitter = 115.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=456
# EPOCH = 546072.007048, wall = 147.68 ms, jitter = 147.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=457
# EPOCH = 546072.111743, wall = 104.70 ms, jitter = 104.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=458
# EPOCH = 546072.224810, wall = 113.07 ms, jitter = 113.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=459
# EPOCH = 546072.541732, wall = 316.92 ms, jitter = 316.92 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=460
# EPOCH = 546072.613444, wall =  71.71 ms, jitter =  71.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=461
# EPOCH = 546072.749084, wall = 135.64 ms, jitter = 135.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=462
# EPOCH = 546072.886047, wall = 136.96 ms, jitter = 136.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=463
# EPOCH = 546073.035871, wall = 149.82 ms, jitter = 149.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=464
# EPOCH = 546073.096504, wall =  60.63 ms, jitter =  60.63 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=465
# EPOCH = 546073.229038, wall = 132.53 ms, jitter = 132.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=466
# EPOCH = 546073.356673, wall = 127.63 ms, jitter = 127.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=467
# EPOCH = 546073.518174, wall = 161.50 ms, jitter = 161.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=468
# EPOCH = 546073.601735, wall =  83.56 ms, jitter =  83.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=469
# EPOCH = 546073.737636, wall = 135.90 ms, jitter = 135.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=470
# EPOCH = 546073.871003, wall = 133.37 ms, jitter = 133.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=471
# EPOCH = 546073.958685, wall =  87.68 ms, jitter =  87.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=472
# EPOCH = 546074.084386, wall = 125.70 ms, jitter = 125.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=473
# EPOCH = 546074.208182, wall = 123.80 ms, jitter = 123.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=474
# EPOCH = 546074.332596, wall = 124.41 ms, jitter = 124.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=475
# EPOCH = 546074.497773, wall = 165.18 ms, jitter = 165.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=476
# EPOCH = 546074.592092, wall =  94.32 ms, jitter =  94.32 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=477
# EPOCH = 546074.743331, wall = 151.24 ms, jitter = 151.24 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=478
# EPOCH = 546074.833692, wall =  90.36 ms, jitter =  90.36 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=479
# EPOCH = 546074.961836, wall = 128.14 ms, jitter = 128.14 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=480
# EPOCH = 546075.085412, wall = 123.58 ms, jitter = 123.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=481
# EPOCH = 546075.217579, wall = 132.17 ms, jitter = 132.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=482
# EPOCH = 546075.362243, wall = 144.66 ms, jitter = 144.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=483
# EPOCH = 546075.465611, wall = 103.37 ms, jitter = 103.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=484
# EPOCH = 546075.614978, wall = 149.37 ms, jitter = 149.37 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=485
# EPOCH = 546075.734256, wall = 119.28 ms, jitter = 119.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=486
# EPOCH = 546075.867621, wall = 133.37 ms, jitter = 133.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=487
# EPOCH = 546075.989033, wall = 121.41 ms, jitter = 121.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=488
# EPOCH = 546076.140159, wall = 151.13 ms, jitter = 151.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=489
# EPOCH = 546076.223559, wall =  83.40 ms, jitter =  83.40 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=490
# EPOCH = 546076.344424, wall = 120.86 ms, jitter = 120.86 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=491
# EPOCH = 546076.465878, wall = 121.45 ms, jitter = 121.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=492
# EPOCH = 546076.584174, wall = 118.30 ms, jitter = 118.30 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=493
# EPOCH = 546076.746603, wall = 162.43 ms, jitter = 162.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=494
# EPOCH = 546076.831843, wall =  85.24 ms, jitter =  85.24 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=495
# EPOCH = 546076.976793, wall = 144.95 ms, jitter = 144.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=496
# EPOCH = 546077.114337, wall = 137.54 ms, jitter = 137.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=497
# EPOCH = 546077.236705, wall = 122.37 ms, jitter = 122.37 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=498
# EPOCH = 546077.402943, wall = 166.24 ms, jitter = 166.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=499
# EPOCH = 546077.524408, wall = 121.46 ms, jitter = 121.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=500
# EPOCH = 546077.648837, wall = 124.43 ms, jitter = 124.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=501
# EPOCH = 546077.759068, wall = 110.23 ms, jitter = 110.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=502
# EPOCH = 546077.863004, wall = 103.94 ms, jitter = 103.94 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=503
# EPOCH = 546077.965568, wall = 102.56 ms, jitter = 102.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=504
# EPOCH = 546078.131236, wall = 165.67 ms, jitter = 165.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=505
# EPOCH = 546078.225972, wall =  94.74 ms, jitter =  94.74 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=506
# EPOCH = 546078.392807, wall = 166.84 ms, jitter = 166.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=507
# EPOCH = 546078.506458, wall = 113.65 ms, jitter = 113.65 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=508
# EPOCH = 546078.638010, wall = 131.55 ms, jitter = 131.55 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=509
# EPOCH = 546078.743999, wall = 105.99 ms, jitter = 105.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=510
# EPOCH = 546078.872400, wall = 128.40 ms, jitter = 128.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=511
# EPOCH = 546078.972271, wall =  99.87 ms, jitter =  99.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=512
# EPOCH = 546079.127042, wall = 154.77 ms, jitter = 154.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=513
# EPOCH = 546079.263045, wall = 136.00 ms, jitter = 136.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=514
# EPOCH = 546079.430269, wall = 167.22 ms, jitter = 167.22 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=515
# EPOCH = 546079.489489, wall =  59.22 ms, jitter =  59.22 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=516
# EPOCH = 546079.602780, wall = 113.29 ms, jitter = 113.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=517
# EPOCH = 546079.718501, wall = 115.72 ms, jitter = 115.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=518
# EPOCH = 546079.843224, wall = 124.72 ms, jitter = 124.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=519
# EPOCH = 546079.976123, wall = 132.90 ms, jitter = 132.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=520
# EPOCH = 546080.123527, wall = 147.40 ms, jitter = 147.40 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=521
# EPOCH = 546080.261555, wall = 138.03 ms, jitter = 138.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=522
# EPOCH = 546080.423927, wall = 162.37 ms, jitter = 162.37 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=523
# EPOCH = 546080.503634, wall =  79.71 ms, jitter =  79.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=524
# EPOCH = 546080.627563, wall = 123.93 ms, jitter = 123.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=525
# EPOCH = 546080.802171, wall = 174.61 ms, jitter = 174.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=526
# EPOCH = 546080.895088, wall =  92.92 ms, jitter =  92.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=527
# EPOCH = 546081.038818, wall = 143.73 ms, jitter = 143.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=528
# EPOCH = 546081.118481, wall =  79.66 ms, jitter =  79.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=529
# EPOCH = 546081.259206, wall = 140.73 ms, jitter = 140.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=530
# EPOCH = 546081.375931, wall = 116.72 ms, jitter = 116.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=531
# EPOCH = 546081.463604, wall =  87.67 ms, jitter =  87.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=532
# EPOCH = 546081.634653, wall = 171.05 ms, jitter = 171.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=533
# EPOCH = 546081.721447, wall =  86.79 ms, jitter =  86.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=534
# EPOCH = 546081.851770, wall = 130.32 ms, jitter = 130.32 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=535
# EPOCH = 546081.992182, wall = 140.41 ms, jitter = 140.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=536
# EPOCH = 546082.101159, wall = 108.98 ms, jitter = 108.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=537
# EPOCH = 546082.243121, wall = 141.96 ms, jitter = 141.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=538
# EPOCH = 546082.348813, wall = 105.69 ms, jitter = 105.69 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=539
# EPOCH = 546082.504838, wall = 156.03 ms, jitter = 156.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=540
# EPOCH = 546082.587561, wall =  82.72 ms, jitter =  82.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=541
# EPOCH = 546082.733261, wall = 145.70 ms, jitter = 145.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=542
# EPOCH = 546082.852088, wall = 118.83 ms, jitter = 118.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=543
# EPOCH = 546083.024051, wall = 171.96 ms, jitter = 171.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=544
# EPOCH = 546083.129274, wall = 105.22 ms, jitter = 105.22 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=545
# EPOCH = 546083.279411, wall = 150.14 ms, jitter = 150.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=546
# EPOCH = 546083.364329, wall =  84.92 ms, jitter =  84.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=547
# EPOCH = 546083.476796, wall = 112.47 ms, jitter = 112.47 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=548
# EPOCH = 546083.583338, wall = 106.54 ms, jitter = 106.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=549
# EPOCH = 546083.732600, wall = 149.26 ms, jitter = 149.26 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=550
# Graceful shutdown.
