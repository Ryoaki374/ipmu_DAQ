# %%
import time, threading, queue, sys, gc
from typing import Tuple

import numpy as np
import pyqtgraph as pg
from PyQt6 import QtCore
from collections import deque

import logging, logging.handlers

import h5py, pathlib
from datetime import datetime

# %% [markdown]
# | **速度目標 [rps]** | **1秒当たり [pulses / s]** | **1iterあたり [pulses]** | **カウント** | **再構成速度 (UP / DOWN) \[rps]** | **偏差 \[%]** |
# | ----------------- | -------------------------- | --------------------------- | ----------------------- | ------------------------------- | -------------------------- |
# | 0.1               | 204.8                      | 25.6                        | 26<br>25                | 0.102<br>0.09765625             | +1.56<br>−2.34             |
# | 0.2               | 409.6                      | 51.2                        | 52<br>51                | 0.203<br>0.19921875             | +1.56<br>−0.39             |
# | 0.3               | 614.4                      | 76.8                        | 77<br>76                | 0.301<br>0.296875               | +0.26<br>−1.04             |
# | 0.4               | 819.2                      | 102.4                       | 103<br>102              | 0.402<br>0.3984375              | +0.59<br>−0.39             |
# | 0.5               | 1 024.0                    | 128.0                       | 128<br>128              | 0.500<br>0.500                  | 0.00<br>0.00               |
# | 0.6               | 1 228.8                    | 153.6                       | 154<br>153              | 0.602<br>0.59765625             | +0.26<br>−0.39             |
# | 0.7               | 1 433.6                    | 179.2                       | 180<br>179              | 0.703<br>0.69921875             | +0.45<br>−0.11             |
# | 0.8               | 1 638.4                    | 204.8                       | 205<br>204              | 0.801<br>0.796875               | +0.10<br>−0.39             |
# | 0.9               | 1 843.2                    | 230.4                       | 231<br>230              | 0.902<br>0.8984375              | +0.26<br>−0.17             |
# | 1.0               | 2 048.0                    | 256.0                       | 256<br>256              | 1.000<br>1.000                  | 0.00<br>0.00               |

# %%
# Please change as you need
t_DC = 90 # [s]
pps = 100 # pulses at initialization
step = 5 # [pps]
rst = 1  # [s] reset time
target_freq = 1  # [rps]
RUN_SEC = 600  # auto‑stop after 10 min



# ------------------------------------------------------------  parameters
DEBUG = True  # set True for jitter log
SAMPLE_RATE = 100_000  # Hz
GEN_CHUNK_SEC = 0.1 # corresponds to PROC_INTERVAL up to 0.05
PROC_INTERVAL = 0.125          # process rate

CHUNK_SEC     = GEN_CHUNK_SEC
N_SAMPLES_GEN = int(SAMPLE_RATE * GEN_CHUNK_SEC) # 100_000 * 0.05 = 5000
SAMPLES_PROC = int(PROC_INTERVAL * SAMPLE_RATE) # 0.125s * 100kHz = 12500
QUEUE_DEPTH = 40  # raw AB backlog
QUAD_DEPTH = 40  # processed backlog (same)
DISPLAY_SEC = RUN_SEC+600
PLOT_SEC = 0.02  # *** fixed x-axis window width (s) ***
GUI_INTERVAL_MS = 50  # update interval (ms) e.g. 50ms = 20Hz

PULSE_HEIGHT = 5.0  # amplitude
INPUT_VELOCITY = 0.1  # rps

PULSE_WIDTH = 1 / (INPUT_VELOCITY * 512)  # period  (s)
PULSE_DUTY = 0.5  # duty
PULSE_PHASE_A = 0.0  # phase offset (s)
PULSE_PHASE_B = -PULSE_WIDTH / 4  # phase offset (s)

QUADPULSE_WIDTH = 0.00025  # width (s) assuming 4x given 1 rps
THRESHOLD_DEFAULT = 2.5  # logic threshold (V)

IDEAL_CPS = INPUT_VELOCITY   # counts/s (constant ideal)

# GUI buffer lengths (empirical)
HISTORY = int(SAMPLE_RATE * PLOT_SEC)
COUNT_HISTORY = int(RUN_SEC / GEN_CHUNK_SEC)
VELO_HISTORY = COUNT_HISTORY

# ------------------------------------------------------------  logging
LOG_CHUNK = 1024       # flush log queue every LOG_CHUNK messages




# ------------------------------------------------------------  queues & stop flag
buf_q = queue.Queue(maxsize=QUEUE_DEPTH)  # raw (t, A, B)
quad_q = queue.Queue(maxsize=QUAD_DEPTH)  # processed (t, A, B, quad)
stop_writer = threading.Event()

log_q = queue.Queue(maxsize=0)
queue_h = logging.handlers.QueueHandler(log_q)
logger = logging.getLogger("debug")
logger.setLevel(logging.INFO)
logger.addHandler(queue_h)

# %%
run_dir = pathlib.Path("../runs")
run_dir.mkdir(exist_ok=True)
timestamp = datetime.now().strftime("%y%m%d%H%M%S")
h5path = f"{run_dir}/{timestamp}.h5"

h5f = h5py.File(h5path, "w")
dset = h5f.create_dataset(
    "log", shape=(0, 3), maxshape=(None, 3),
    dtype=np.float32, chunks=(LOG_CHUNK, 3), compression="gzip"
)

print("dset shape  =", dset.shape)
print("dset maxshape =", dset.maxshape)
# Out:
# dset shape  = (0, 3)
# dset maxshape = (None, 3)

# %%
def gen_chunk_pulse(
    t: np.ndarray,
    *,
    height: float = PULSE_HEIGHT,
    width: float = PULSE_WIDTH,
    duty: float = PULSE_DUTY,
    phase: float = 0.0,
) -> np.ndarray:
    mod = (t + phase) % width
    return np.where(mod < duty * width, height, 0.0).astype(np.float32)


REL_AXIS_GEN = (
    np.arange(N_SAMPLES_GEN, dtype=np.float32) / SAMPLE_RATE
)  # 0 ... 0.2 s

# ------------------------------------------------------------  AB → direction → quad helpers


def gen_pulse_direction(
    dA: np.ndarray,
    dB: np.ndarray,
    *,
    threshold: float,
    prev_A: bool | None = None,
    prev_B: bool | None = None,
) -> tuple[np.ndarray, bool, bool]:
    """
    Detect direction for one block **with perfect edge coverage**.

    Parameters
    ----------
    dA, dB : ndarray[float32]
        Analog levels of phase-A / phase-B for the current block.
    threshold : float
        Logic threshold [V].
    prev_A, prev_B : bool | None
        Logical state of A/B *at the end of the PREVIOUS block*.
        • If None (first block), the function falls back to the
          “self-shift” method used before.

    Returns
    -------
    dir_log : ndarray[int8]
        +1 = CW edge, –1 = CCW edge, 0 = no edge.
    last_A, last_B : bool
        Logical state of A/B at the *end* of this block — feed these
        into the next call to avoid losing the boundary edge.
    """
    # --- current logic level ----------------------------------------
    A = dA > threshold
    B = dB > threshold

    # --- previous sample for XOR -----------------------------------
    if prev_A is None:  # first block → old behaviour
        A_prev = np.concatenate(([A[0]], A[:-1]))
        B_prev = np.concatenate(([B[0]], B[:-1]))
    else:               # use states carried over from last block
        A_prev = np.concatenate(([prev_A], A[:-1]))
        B_prev = np.concatenate(([prev_B], B[:-1]))

    dir_log = (B_prev ^ A).astype(int) - (A_prev ^ B).astype(int)

    return dir_log.astype(np.int8), bool(A[-1]), bool(B[-1])

def pulse_count(dir_log: np.ndarray) -> int:
    #return int(np.sum(dir_log))
    return np.sum(dir_log)


def gen_quad_pulse(
    t: np.ndarray, dir_log: np.ndarray, width: float, height: float, sampling_rate: int
) -> np.ndarray:
    samples = int(width * sampling_rate)
    if samples <= 0:
        return np.zeros_like(dir_log, dtype=np.float32)
    base = np.full(samples, height, dtype=np.float32)
    return np.convolve(dir_log, base, mode="full")[: len(t)]


# ------------------------------------------------------------  producer thread
def generator() -> None:
    """Generate AB rectangular-wave chunks at real-time cadence."""
    chunk_idx = 0
    next_t = time.perf_counter()
    while not stop_writer.is_set():
        base = chunk_idx * GEN_CHUNK_SEC
        t_axis = REL_AXIS_GEN + base
        pulse_A = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_A)
        pulse_B = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_B)
        try:
            buf_q.put_nowait((t_axis, pulse_A, pulse_B))
        except queue.Full:
            pass

        chunk_idx += 1
        next_t += GEN_CHUNK_SEC
        sleep = next_t - time.perf_counter()
        if sleep > 0:
            time.sleep(sleep)
        else:
            next_t = time.perf_counter()


# ------------------------------------------------------------  consumer thread
def log_listener():
    handler = logging.StreamHandler(sys.stdout)
    listener = logging.handlers.QueueListener(log_q, handler)
    listener.start()
    stop_writer.wait()
    listener.stop()

def command_freq(t_DC, pps, step, rst, target_freq, proc_interval):

    time = np.arange(0, t_DC+np.ceil((36000-pps)*target_freq/(step/rst))+60*60*2, proc_interval, dtype=np.float32)
    freq = np.zeros(int((t_DC+np.ceil((36000-pps)*target_freq/(step/rst))+60*60*2)*(1/proc_interval)), dtype=np.float32)

    n_DC = int(np.round(t_DC/proc_interval))  #DCの速度指令値=0rps
    freq[:n_DC] = 0.0

    n_rst = int(np.round(rst/proc_interval))  #加速中の速度指令値
    freq[n_DC: int(n_DC+n_rst*np.ceil((36000-pps)*target_freq/step))] = [pps/36000+target_freq/36000*step*(i+1) 
                                                                         for i in range(int(np.ceil((36000-pps)*target_freq/step))) 
                                                                         for j in freq[int(n_DC+i*n_rst): int(n_DC+(i+1)*n_rst)]]

    n_stable = int(np.round(60*60*2/proc_interval))  #Stableの速度指令値
    freq[int(n_DC+n_rst*np.ceil((36000-pps)*target_freq/step)):] = target_freq

    return time, freq

class IdealVelocityProvider:
    def __init__(self, t_DC, pps, step, rst, target_freq, proc_interval) -> None:
        #num_points: int = int(duration / dt) + 1
        #self.time_axis: np.ndarray = np.linspace(0.0, duration, num_points, dtype=np.float32)
        #self.velocity:  np.ndarray = np.full(num_points, IDEAL_CPS, dtype=np.float32)
        self.t_DC = t_DC
        self.pps = pps
        self.step = step
        self.rst = rst
        self.target_freq = target_freq
        self.proc_interval = proc_interval
        self.time_axis, self.velocity = command_freq(t_DC, pps, step, rst, target_freq, proc_interval)

    def slice(self, t_start: float, t_end: float) -> tuple[np.ndarray, np.ndarray]:
        """Return the time and velocity arrays that fall within [t_start, t_end]."""
        idx_start, idx_end = np.searchsorted(self.time_axis, [t_start, t_end])
        return self.time_axis[idx_start:idx_end], self.velocity[idx_start:idx_end]

ideal: IdealVelocityProvider | None = None  # initialised lazily in processor()


def processor() -> None:
    """
    deque ベース（旧方式）に戻したリアルタイム・コンシューマ。
    - buf_q から取り出した A/B チャンクを deque(Ring) に追加
    - PROC_INTERVAL ごとに SAMPLES_PROC 分を popleft
    - 理想速度 (IdealVelocityProvider) のスライスを同梱して quad_q へ送信
    ※ logger.info() のフォーマットは従来どおり維持
    dequeにしないとバグる
    """
    # ---------- one-time init ----------
    global ideal_provider
    if 'ideal_provider' not in globals() or ideal_provider is None:
        ideal_provider = IdealVelocityProvider(t_DC, pps, step, rst, target_freq, PROC_INTERVAL)

    # ---------- logging ----------
    buf = np.empty((LOG_CHUNK, 3), dtype=np.float32)  # 内部バッファ
    buf_len = 0
    print("buf shape =", buf.shape)

    # --- Python deque リングバッファ ---
    ring_t: deque[np.float32] = deque()
    ring_a: deque[np.float32] = deque()
    ring_b: deque[np.float32] = deque()
    last_A = last_B = None

    next_proc = time.perf_counter()
    cum_count = 0
    last_ts   = next_proc

    while not stop_writer.is_set():
        # ---------- 非ブロッキングで出来るだけ取り込む ----------
        try:
            while True:
                t, pA, pB = buf_q.get_nowait()
                ring_t.extend(t); ring_a.extend(pA); ring_b.extend(pB)
                buf_q.task_done()
        except queue.Empty:
            pass

        # ---------- 次の処理時刻まで待機 ----------
        now = time.perf_counter()
        if now < next_proc:
            time.sleep(next_proc - now)
            continue
        next_proc += PROC_INTERVAL

        # ---------- サンプル不足ならスキップ ----------
        if len(ring_t) < SAMPLES_PROC:
            continue

        # ---------- deque → NumPy へコピー ----------
        t_blk = np.array([ring_t.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        a_blk = np.array([ring_a.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        b_blk = np.array([ring_b.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)

        # ---------- 信号処理 ----------
        dir_log, last_A, last_B = gen_pulse_direction(
            a_blk, b_blk,
            threshold=THRESHOLD_DEFAULT,
            prev_A=last_A, prev_B=last_B
        )
        quad_sig  = gen_quad_pulse(t_blk, dir_log, QUADPULSE_WIDTH, PULSE_HEIGHT, SAMPLE_RATE)
        delta_cnt = pulse_count(dir_log)
        cum_count += delta_cnt
        velocity  = delta_cnt / PROC_INTERVAL / 2048

        # ---------- 理想速度スライス ----------
        t_ref, v_ref = ideal_provider.slice(t_blk[0], t_blk[-1])

        # ---------- ログ ----------
        if DEBUG:
            now = time.perf_counter()
            jitter = (now - last_ts) * 1e3
            logger.info(
                "EPOCH = %f, wall = %6.2f ms, jitter = %6.2f ms  delta c=%+d, v=%6.3f, len(dir_log)=%d, buf_len=%d",
                now, jitter, (now - last_ts) * 1e3,
                delta_cnt, velocity, len(dir_log), buf_len
            )
            last_ts = now

        # ---------- GUI へ送信 ----------
        try:
            quad_q.put_nowait(
                (t_blk, a_blk, b_blk, quad_sig,
                 t_blk[-1], cum_count, velocity,
                 t_ref, v_ref)
            )
        except queue.Full:
            pass

         # ---- append to buffer ----
        buf[buf_len] = (t_blk[-1], (v_ref[-1] if v_ref.size else 0.0), velocity)
        buf_len += 1
        if buf_len == buf.shape[0]:
            n = dset.shape[0]
            dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf
            buf_len = 0

     # ---- final flush ----
    if buf_len:
        n = dset.shape[0]
        dset.resize(n+buf_len, axis=0); dset[-buf_len:] = buf[:buf_len]
    h5f.close()


def start_gui() -> None:
    pg.setConfigOptions(useOpenGL=True, background="w", foreground="k")
    app = pg.mkQApp("Live plots")

    win = pg.GraphicsLayoutWidget(title="DEMO")

    layout = win.ci.layout                 # GraphicsLayout の中身
    layout.setColumnStretchFactor(0, 3)
    layout.setColumnStretchFactor(1, 5)
    #win_sig = pg.GraphicsLayoutWidget(show=True, title="Signal")
    #win_vel = pg.GraphicsLayoutWidget(show=True, title="Velocity")

    #win_sig.resize(800, 600)
    #win_vel.resize(800, 600)
    #win_sig.show()


    win.resize(800, 600)
    win.show()

    # [0, 0] A/B -------------------------------------------------------
    plt_ab = win.addPlot(row=0, col=0, title="RAW A / B")
    curve_A = plt_ab.plot(pen=pg.mkPen("#ff4b00", width=3))
    curve_B = plt_ab.plot(pen=pg.mkPen("#005aff", width=3))
    plt_ab.setLabel("left", "Amplitude [V]")
    plt_ab.setLabel("bottom", "Time [s]")
    plt_ab.setYRange(-0.5, PULSE_HEIGHT + 0.5)

    # [1,0] Quad waveform --------------------------------------------
    plt_q = win.addPlot(row=1, col=0, title="Quad pulse")
    curve_Q = plt_q.plot(pen=pg.mkPen("m", width=3))
    plt_q.setLabel("left", "Amplitude [V]")
    plt_q.setLabel("bottom", "Time [s]")
    plt_q.setYRange(-PULSE_HEIGHT - 0.5, PULSE_HEIGHT + 0.5)

    # [0,1] count (fixed x-axis) -------------------------------------
    plt_cnt = win.addPlot(row=0, col=1, title="Velovity - Command")
    curve_cnt = plt_cnt.plot(pen=pg.mkPen("#03af7a", width=3))
    #plt_cnt.setXRange(0, RUN_SEC, padding=0)
    #plt_cnt.enableAutoRange("x", True)
    plt_cnt.setLabel("left", "Diff")
    plt_cnt.setLabel("bottom", "Time [s]")

    # [1,1] velocity (fixed x-axis) ----------------------------------
    plt_vel = win.addPlot(row=1, col=1, title="Velocity")
    curve_vel     = plt_vel.plot(pen=pg.mkPen("#00a0e9", width=3))   # measured
    curve_vel_ref = plt_vel.plot(pen=pg.mkPen("#a05aff", width=3))   # ideal (new)
    #plt_vel.setXRange(0, RUN_SEC, padding=0)
    #plt_vel.enableAutoRange("x", True)
    plt_vel.setLabel("left", "Velocity [rps]")
    plt_vel.setLabel("bottom", "Time [s]")

    # buffers ---------------------------------------------------------
    xs = ya = yb = yq = np.empty(0, dtype=np.float32)
    xs_cnt = y_cnt = np.empty(0, dtype=np.float32)
    xs_vel = y_vel = np.empty(0, dtype=np.float32)
    xr = yr = np.empty(0, dtype=np.float32)       # ideal velocity buffers (new)

    def refresh():
        nonlocal xs, ya, yb, yq, xs_cnt, y_cnt, xs_vel, y_vel, xr, yr
        try:
            while True:
                # receive processed data (+ ideal velocity slice)
                t_ax, pA, pB, qsig, t_end, cum_cnt, vel, t_ref, v_ref = quad_q.get_nowait()

                xs = np.concatenate((xs, t_ax))[-HISTORY:]
                ya = np.concatenate((ya, pA))[-HISTORY:]
                yb = np.concatenate((yb, pB))[-HISTORY:]
                yq = np.concatenate((yq, qsig))[-HISTORY:]

                xs_cnt = np.append(xs_cnt, t_end)[-COUNT_HISTORY:]
                y_cnt  = np.append(y_cnt, vel-v_ref)[-COUNT_HISTORY:]

                xs_vel = np.append(xs_vel, t_end)[-VELO_HISTORY:]
                y_vel  = np.append(y_vel, vel)[-VELO_HISTORY:]

                xr = np.concatenate((xr, t_ref))[-VELO_HISTORY:]
                yr = np.concatenate((yr, v_ref))[-VELO_HISTORY:]

                quad_q.task_done()
        except queue.Empty:
            pass

        # scrolling window for waveforms only
        if xs.size:
            start = xs[-1] - PLOT_SEC
            plt_ab.setXRange(start, xs[-1], padding=0)
            plt_q.setXRange(start, xs[-1], padding=0)

        # --- auto-range for count/velocity ---
        if xs_cnt.size:
            plt_cnt.setXRange(xs_cnt[-1]-10, xs_cnt[-1], padding=0)

        if xs_vel.size:
            plt_vel.setXRange(xs_vel[-1]-10, xs_vel[-1], padding=0)

        # --- push data to curves ---
        curve_A.setData(xs, ya)
        curve_B.setData(xs, yb)
        curve_Q.setData(xs, yq)
        curve_cnt.setData(xs_cnt, y_cnt)
        curve_vel.setData(xs_vel, y_vel)
        curve_vel_ref.setData(xr, yr)

    timer = QtCore.QTimer()
    timer.timeout.connect(refresh)
    timer.start(GUI_INTERVAL_MS)

    # auto-stop after RUN_SEC
    QtCore.QTimer.singleShot(int(RUN_SEC * 1000), lambda: (stop_writer.set(), app.quit()))
    app.exec()

# %%
if __name__ == "__main__":
    threading.Thread(target=log_listener, daemon=True).start()  # start log listener

    gen_th  = threading.Thread(target=generator, daemon=True)
    proc_th = threading.Thread(target=processor, daemon=True)

    gen_th.start()
    proc_th.start()
    # con_th.start()

    start_gui()  # blocks until the user closes the window or timer expires

    # join threads and exit
    stop_writer.set()
    gen_th.join()
    proc_th.join()

    print("Graceful shutdown.")
# Out:
# buf shape = (1024, 3)
# EPOCH = 691597.488825, wall = 429.16 ms, jitter = 429.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=0
# EPOCH = 691597.530789, wall =  41.96 ms, jitter =  41.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=1
# EPOCH = 691598.772762, wall = 1241.97 ms, jitter = 1241.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=2
# EPOCH = 691599.386563, wall = 613.80 ms, jitter = 613.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=3
# EPOCH = 691599.461596, wall =  75.03 ms, jitter =  75.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=4
# EPOCH = 691599.572445, wall = 110.85 ms, jitter = 110.85 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=5
# EPOCH = 691599.757471, wall = 185.03 ms, jitter = 185.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=6
# EPOCH = 691599.839006, wall =  81.54 ms, jitter =  81.54 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=7
# EPOCH = 691599.947274, wall = 108.27 ms, jitter = 108.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=8
# EPOCH = 691600.089307, wall = 142.03 ms, jitter = 142.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=9
# EPOCH = 691600.225479, wall = 136.17 ms, jitter = 136.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=10
# EPOCH = 691600.361682, wall = 136.20 ms, jitter = 136.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=11
# EPOCH = 691600.475949, wall = 114.27 ms, jitter = 114.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=12
# EPOCH = 691600.577006, wall = 101.06 ms, jitter = 101.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=13
# EPOCH = 691600.706648, wall = 129.64 ms, jitter = 129.64 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=14
# EPOCH = 691600.847310, wall = 140.66 ms, jitter = 140.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=15
# EPOCH = 691600.976934, wall = 129.62 ms, jitter = 129.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=16
# EPOCH = 691601.087012, wall = 110.08 ms, jitter = 110.08 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=17
# EPOCH = 691601.199339, wall = 112.33 ms, jitter = 112.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=18
# EPOCH = 691601.350939, wall = 151.60 ms, jitter = 151.60 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=19
# EPOCH = 691601.473072, wall = 122.13 ms, jitter = 122.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=20
# EPOCH = 691601.594864, wall = 121.79 ms, jitter = 121.79 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=21
# EPOCH = 691601.721839, wall = 126.98 ms, jitter = 126.98 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=22
# EPOCH = 691601.832706, wall = 110.87 ms, jitter = 110.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=23
# EPOCH = 691601.946826, wall = 114.12 ms, jitter = 114.12 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=24
# EPOCH = 691602.105877, wall = 159.05 ms, jitter = 159.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=25
# EPOCH = 691602.263821, wall = 157.94 ms, jitter = 157.94 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=26
# EPOCH = 691602.370432, wall = 106.61 ms, jitter = 106.61 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=27
# EPOCH = 691602.451702, wall =  81.27 ms, jitter =  81.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=28
# EPOCH = 691602.600856, wall = 149.15 ms, jitter = 149.15 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=29
# EPOCH = 691602.702803, wall = 101.95 ms, jitter = 101.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=30
# EPOCH = 691602.852302, wall = 149.50 ms, jitter = 149.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=31
# EPOCH = 691602.964604, wall = 112.30 ms, jitter = 112.30 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=32
# EPOCH = 691603.073083, wall = 108.48 ms, jitter = 108.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=33
# EPOCH = 691603.217416, wall = 144.33 ms, jitter = 144.33 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=34
# EPOCH = 691603.330574, wall = 113.16 ms, jitter = 113.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=35
# EPOCH = 691603.460762, wall = 130.19 ms, jitter = 130.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=36
# EPOCH = 691603.569489, wall = 108.73 ms, jitter = 108.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=37
# EPOCH = 691603.722574, wall = 153.08 ms, jitter = 153.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=38
# EPOCH = 691603.836272, wall = 113.70 ms, jitter = 113.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=39
# EPOCH = 691603.958688, wall = 122.42 ms, jitter = 122.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=40
# EPOCH = 691604.112581, wall = 153.89 ms, jitter = 153.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=41
# EPOCH = 691604.223077, wall = 110.50 ms, jitter = 110.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=42
# EPOCH = 691604.327584, wall = 104.51 ms, jitter = 104.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=43
# EPOCH = 691604.473065, wall = 145.48 ms, jitter = 145.48 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=44
# EPOCH = 691604.583560, wall = 110.50 ms, jitter = 110.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=45
# EPOCH = 691604.714525, wall = 130.97 ms, jitter = 130.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=46
# EPOCH = 691604.817788, wall = 103.26 ms, jitter = 103.26 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=47
# EPOCH = 691604.967077, wall = 149.29 ms, jitter = 149.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=48
# EPOCH = 691605.070744, wall = 103.67 ms, jitter = 103.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=49
# EPOCH = 691605.239992, wall = 169.25 ms, jitter = 169.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=50
# EPOCH = 691605.329802, wall =  89.81 ms, jitter =  89.81 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=51
# EPOCH = 691605.465890, wall = 136.09 ms, jitter = 136.09 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=52
# EPOCH = 691605.593278, wall = 127.39 ms, jitter = 127.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=53
# EPOCH = 691605.694466, wall = 101.19 ms, jitter = 101.19 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=54
# EPOCH = 691605.824742, wall = 130.28 ms, jitter = 130.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=55
# EPOCH = 691605.949595, wall = 124.85 ms, jitter = 124.85 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=56
# EPOCH = 691606.087376, wall = 137.78 ms, jitter = 137.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=57
# EPOCH = 691606.207465, wall = 120.09 ms, jitter = 120.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=58
# EPOCH = 691606.332549, wall = 125.08 ms, jitter = 125.08 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=59
# EPOCH = 691606.448277, wall = 115.73 ms, jitter = 115.73 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=60
# EPOCH = 691606.591954, wall = 143.68 ms, jitter = 143.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=61
# EPOCH = 691606.700530, wall = 108.58 ms, jitter = 108.58 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=62
# EPOCH = 691606.841529, wall = 141.00 ms, jitter = 141.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=63
# EPOCH = 691606.954285, wall = 112.76 ms, jitter = 112.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=64
# EPOCH = 691607.078838, wall = 124.55 ms, jitter = 124.55 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=65
# EPOCH = 691607.210868, wall = 132.03 ms, jitter = 132.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=66
# EPOCH = 691607.340099, wall = 129.23 ms, jitter = 129.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=67
# EPOCH = 691607.476205, wall = 136.11 ms, jitter = 136.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=68
# EPOCH = 691607.595251, wall = 119.05 ms, jitter = 119.05 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=69
# EPOCH = 691607.697776, wall = 102.53 ms, jitter = 102.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=70
# EPOCH = 691607.829841, wall = 132.06 ms, jitter = 132.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=71
# EPOCH = 691607.959534, wall = 129.69 ms, jitter = 129.69 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=72
# EPOCH = 691608.093246, wall = 133.71 ms, jitter = 133.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=73
# EPOCH = 691608.216066, wall = 122.82 ms, jitter = 122.82 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=74
# EPOCH = 691608.322377, wall = 106.31 ms, jitter = 106.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=75
# EPOCH = 691608.456337, wall = 133.96 ms, jitter = 133.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=76
# EPOCH = 691608.574794, wall = 118.46 ms, jitter = 118.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=77
# EPOCH = 691608.717475, wall = 142.68 ms, jitter = 142.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=78
# EPOCH = 691608.856767, wall = 139.29 ms, jitter = 139.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=79
# EPOCH = 691608.961846, wall = 105.08 ms, jitter = 105.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=80
# EPOCH = 691609.073358, wall = 111.51 ms, jitter = 111.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=81
# EPOCH = 691609.207856, wall = 134.50 ms, jitter = 134.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=82
# EPOCH = 691609.338007, wall = 130.15 ms, jitter = 130.15 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=83
# EPOCH = 691609.467187, wall = 129.18 ms, jitter = 129.18 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=84
# EPOCH = 691609.604111, wall = 136.92 ms, jitter = 136.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=85
# EPOCH = 691609.719755, wall = 115.64 ms, jitter = 115.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=86
# EPOCH = 691609.843465, wall = 123.71 ms, jitter = 123.71 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=87
# EPOCH = 691609.972578, wall = 129.11 ms, jitter = 129.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=88
# EPOCH = 691610.095483, wall = 122.90 ms, jitter = 122.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=89
# EPOCH = 691610.202491, wall = 107.01 ms, jitter = 107.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=90
# EPOCH = 691610.330573, wall = 128.08 ms, jitter = 128.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=91
# EPOCH = 691610.445500, wall = 114.93 ms, jitter = 114.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=92
# EPOCH = 691610.588451, wall = 142.95 ms, jitter = 142.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=93
# EPOCH = 691610.697011, wall = 108.56 ms, jitter = 108.56 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=94
# EPOCH = 691610.841640, wall = 144.63 ms, jitter = 144.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=95
# EPOCH = 691610.983914, wall = 142.27 ms, jitter = 142.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=96
# EPOCH = 691611.144848, wall = 160.93 ms, jitter = 160.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=97
# EPOCH = 691611.209997, wall =  65.15 ms, jitter =  65.15 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=98
# EPOCH = 691611.344378, wall = 134.38 ms, jitter = 134.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=99
# EPOCH = 691611.476870, wall = 132.49 ms, jitter = 132.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=100
# EPOCH = 691611.604062, wall = 127.19 ms, jitter = 127.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=101
# EPOCH = 691611.704645, wall = 100.58 ms, jitter = 100.58 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=102
# EPOCH = 691611.821959, wall = 117.31 ms, jitter = 117.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=103
# EPOCH = 691611.953226, wall = 131.27 ms, jitter = 131.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=104
# EPOCH = 691612.080434, wall = 127.21 ms, jitter = 127.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=105
# EPOCH = 691612.215550, wall = 135.12 ms, jitter = 135.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=106
# EPOCH = 691612.320573, wall = 105.02 ms, jitter = 105.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=107
# EPOCH = 691612.462020, wall = 141.45 ms, jitter = 141.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=108
# EPOCH = 691612.586604, wall = 124.58 ms, jitter = 124.58 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=109
# EPOCH = 691612.708536, wall = 121.93 ms, jitter = 121.93 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=110
# EPOCH = 691612.838246, wall = 129.71 ms, jitter = 129.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=111
# EPOCH = 691612.944098, wall = 105.85 ms, jitter = 105.85 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=112
# EPOCH = 691613.073946, wall = 129.85 ms, jitter = 129.85 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=113
# EPOCH = 691613.198478, wall = 124.53 ms, jitter = 124.53 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=114
# EPOCH = 691613.349464, wall = 150.99 ms, jitter = 150.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=115
# EPOCH = 691613.458499, wall = 109.03 ms, jitter = 109.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=116
# EPOCH = 691613.571559, wall = 113.06 ms, jitter = 113.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=117
# EPOCH = 691613.697654, wall = 126.10 ms, jitter = 126.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=118
# EPOCH = 691613.836794, wall = 139.14 ms, jitter = 139.14 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=119
# EPOCH = 691613.946178, wall = 109.38 ms, jitter = 109.38 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=120
# EPOCH = 691614.135913, wall = 189.74 ms, jitter = 189.74 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=121
# EPOCH = 691614.207495, wall =  71.58 ms, jitter =  71.58 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=122
# EPOCH = 691614.340826, wall = 133.33 ms, jitter = 133.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=123
# EPOCH = 691614.461814, wall = 120.99 ms, jitter = 120.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=124
# EPOCH = 691614.616148, wall = 154.33 ms, jitter = 154.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=125
# EPOCH = 691614.744566, wall = 128.42 ms, jitter = 128.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=126
# EPOCH = 691614.859926, wall = 115.36 ms, jitter = 115.36 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=127
# EPOCH = 691614.961893, wall = 101.97 ms, jitter = 101.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=128
# EPOCH = 691615.079670, wall = 117.78 ms, jitter = 117.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=129
# EPOCH = 691615.227631, wall = 147.96 ms, jitter = 147.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=130
# EPOCH = 691615.366568, wall = 138.94 ms, jitter = 138.94 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=131
# EPOCH = 691615.477209, wall = 110.64 ms, jitter = 110.64 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=132
# EPOCH = 691615.631269, wall = 154.06 ms, jitter = 154.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=133
# EPOCH = 691615.716006, wall =  84.74 ms, jitter =  84.74 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=134
# EPOCH = 691615.843972, wall = 127.97 ms, jitter = 127.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=135
# EPOCH = 691615.946785, wall = 102.81 ms, jitter = 102.81 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=136
# EPOCH = 691616.087127, wall = 140.34 ms, jitter = 140.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=137
# EPOCH = 691616.225793, wall = 138.67 ms, jitter = 138.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=138
# EPOCH = 691616.369083, wall = 143.29 ms, jitter = 143.29 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=139
# EPOCH = 691616.457918, wall =  88.83 ms, jitter =  88.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=140
# EPOCH = 691616.587512, wall = 129.59 ms, jitter = 129.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=141
# EPOCH = 691616.768316, wall = 180.80 ms, jitter = 180.80 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=142
# EPOCH = 691616.885405, wall = 117.09 ms, jitter = 117.09 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=143
# EPOCH = 691616.982401, wall =  97.00 ms, jitter =  97.00 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=144
# EPOCH = 691617.101655, wall = 119.25 ms, jitter = 119.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=145
# EPOCH = 691617.230329, wall = 128.67 ms, jitter = 128.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=146
# EPOCH = 691617.336429, wall = 106.10 ms, jitter = 106.10 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=147
# EPOCH = 691617.445790, wall = 109.36 ms, jitter = 109.36 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=148
# EPOCH = 691617.575803, wall = 130.01 ms, jitter = 130.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=149
# EPOCH = 691617.698944, wall = 123.14 ms, jitter = 123.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=150
# EPOCH = 691617.822055, wall = 123.11 ms, jitter = 123.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=151
# EPOCH = 691617.953972, wall = 131.92 ms, jitter = 131.92 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=152
# EPOCH = 691618.070481, wall = 116.51 ms, jitter = 116.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=153
# EPOCH = 691618.222496, wall = 152.01 ms, jitter = 152.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=154
# EPOCH = 691618.343422, wall = 120.93 ms, jitter = 120.93 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=155
# EPOCH = 691618.487487, wall = 144.07 ms, jitter = 144.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=156
# EPOCH = 691618.619358, wall = 131.87 ms, jitter = 131.87 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=157
# EPOCH = 691618.702505, wall =  83.15 ms, jitter =  83.15 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=158
# EPOCH = 691618.843345, wall = 140.84 ms, jitter = 140.84 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=159
# EPOCH = 691618.972602, wall = 129.26 ms, jitter = 129.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=160
# EPOCH = 691619.129803, wall = 157.20 ms, jitter = 157.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=161
# EPOCH = 691619.206214, wall =  76.41 ms, jitter =  76.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=162
# EPOCH = 691619.331102, wall = 124.89 ms, jitter = 124.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=163
# EPOCH = 691619.446546, wall = 115.44 ms, jitter = 115.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=164
# EPOCH = 691619.598034, wall = 151.49 ms, jitter = 151.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=165
# EPOCH = 691619.784905, wall = 186.87 ms, jitter = 186.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=166
# EPOCH = 691619.835932, wall =  51.03 ms, jitter =  51.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=167
# EPOCH = 691619.958361, wall = 122.43 ms, jitter = 122.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=168
# EPOCH = 691620.096904, wall = 138.54 ms, jitter = 138.54 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=169
# EPOCH = 691620.208040, wall = 111.14 ms, jitter = 111.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=170
# EPOCH = 691620.346143, wall = 138.10 ms, jitter = 138.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=171
# EPOCH = 691620.479340, wall = 133.20 ms, jitter = 133.20 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=172
# EPOCH = 691620.599922, wall = 120.58 ms, jitter = 120.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=173
# EPOCH = 691620.755097, wall = 155.18 ms, jitter = 155.18 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=174
# EPOCH = 691620.901325, wall = 146.23 ms, jitter = 146.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=175
# EPOCH = 691621.051573, wall = 150.25 ms, jitter = 150.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=176
# EPOCH = 691621.084238, wall =  32.67 ms, jitter =  32.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=177
# EPOCH = 691621.237493, wall = 153.26 ms, jitter = 153.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=178
# EPOCH = 691621.431297, wall = 193.80 ms, jitter = 193.80 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=179
# EPOCH = 691621.459370, wall =  28.07 ms, jitter =  28.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=180
# EPOCH = 691621.588928, wall = 129.56 ms, jitter = 129.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=181
# EPOCH = 691621.730838, wall = 141.91 ms, jitter = 141.91 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=182
# EPOCH = 691621.867354, wall = 136.52 ms, jitter = 136.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=183
# EPOCH = 691622.006603, wall = 139.25 ms, jitter = 139.25 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=184
# EPOCH = 691622.126262, wall = 119.66 ms, jitter = 119.66 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=185
# EPOCH = 691622.255944, wall = 129.68 ms, jitter = 129.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=186
# EPOCH = 691622.340839, wall =  84.90 ms, jitter =  84.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=187
# EPOCH = 691622.491407, wall = 150.57 ms, jitter = 150.57 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=188
# EPOCH = 691622.596384, wall = 104.98 ms, jitter = 104.98 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=189
# EPOCH = 691622.731904, wall = 135.52 ms, jitter = 135.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=190
# EPOCH = 691622.903003, wall = 171.10 ms, jitter = 171.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=191
# EPOCH = 691623.008630, wall = 105.63 ms, jitter = 105.63 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=192
# EPOCH = 691623.081270, wall =  72.64 ms, jitter =  72.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=193
# EPOCH = 691623.201794, wall = 120.52 ms, jitter = 120.52 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=194
# EPOCH = 691623.404791, wall = 203.00 ms, jitter = 203.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=195
# EPOCH = 691623.495471, wall =  90.68 ms, jitter =  90.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=196
# EPOCH = 691623.633714, wall = 138.24 ms, jitter = 138.24 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=197
# EPOCH = 691623.702460, wall =  68.75 ms, jitter =  68.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=198
# EPOCH = 691623.849257, wall = 146.80 ms, jitter = 146.80 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=199
# EPOCH = 691624.002466, wall = 153.21 ms, jitter = 153.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=200
# EPOCH = 691624.122800, wall = 120.33 ms, jitter = 120.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=201
# EPOCH = 691624.261115, wall = 138.31 ms, jitter = 138.31 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=202
# EPOCH = 691624.401074, wall = 139.96 ms, jitter = 139.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=203
# EPOCH = 691624.493812, wall =  92.74 ms, jitter =  92.74 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=204
# EPOCH = 691624.588134, wall =  94.32 ms, jitter =  94.32 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=205
# EPOCH = 691624.728392, wall = 140.26 ms, jitter = 140.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=206
# EPOCH = 691624.830170, wall = 101.78 ms, jitter = 101.78 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=207
# EPOCH = 691625.151692, wall = 321.52 ms, jitter = 321.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=208
# EPOCH = 691625.243052, wall =  91.36 ms, jitter =  91.36 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=209
# EPOCH = 691625.412647, wall = 169.59 ms, jitter = 169.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=210
# EPOCH = 691625.541442, wall = 128.80 ms, jitter = 128.80 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=211
# EPOCH = 691625.627089, wall =  85.65 ms, jitter =  85.65 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=212
# EPOCH = 691625.780810, wall = 153.72 ms, jitter = 153.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=213
# EPOCH = 691625.882199, wall = 101.39 ms, jitter = 101.39 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=214
# EPOCH = 691625.999952, wall = 117.75 ms, jitter = 117.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=215
# EPOCH = 691626.120135, wall = 120.18 ms, jitter = 120.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=216
# EPOCH = 691626.228148, wall = 108.01 ms, jitter = 108.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=217
# EPOCH = 691626.354657, wall = 126.51 ms, jitter = 126.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=218
# EPOCH = 691626.476552, wall = 121.89 ms, jitter = 121.89 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=219
# EPOCH = 691626.587146, wall = 110.59 ms, jitter = 110.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=220
# EPOCH = 691626.755018, wall = 167.87 ms, jitter = 167.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=221
# EPOCH = 691626.855009, wall =  99.99 ms, jitter =  99.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=222
# EPOCH = 691626.977774, wall = 122.76 ms, jitter = 122.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=223
# EPOCH = 691627.109562, wall = 131.79 ms, jitter = 131.79 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=224
# EPOCH = 691627.216082, wall = 106.52 ms, jitter = 106.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=225
# EPOCH = 691627.383697, wall = 167.62 ms, jitter = 167.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=226
# EPOCH = 691627.520942, wall = 137.24 ms, jitter = 137.24 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=227
# EPOCH = 691627.616944, wall =  96.00 ms, jitter =  96.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=228
# EPOCH = 691627.711791, wall =  94.85 ms, jitter =  94.85 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=229
# EPOCH = 691627.829320, wall = 117.53 ms, jitter = 117.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=230
# EPOCH = 691628.020507, wall = 191.19 ms, jitter = 191.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=231
# EPOCH = 691628.109031, wall =  88.52 ms, jitter =  88.52 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=232
# EPOCH = 691628.299340, wall = 190.31 ms, jitter = 190.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=233
# EPOCH = 691628.357045, wall =  57.70 ms, jitter =  57.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=234
# EPOCH = 691628.482921, wall = 125.88 ms, jitter = 125.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=235
# EPOCH = 691628.630091, wall = 147.17 ms, jitter = 147.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=236
# EPOCH = 691628.805865, wall = 175.77 ms, jitter = 175.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=237
# EPOCH = 691628.935378, wall = 129.51 ms, jitter = 129.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=238
# EPOCH = 691628.976612, wall =  41.23 ms, jitter =  41.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=239
# EPOCH = 691629.144330, wall = 167.72 ms, jitter = 167.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=240
# EPOCH = 691629.212843, wall =  68.51 ms, jitter =  68.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=241
# EPOCH = 691629.342985, wall = 130.14 ms, jitter = 130.14 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=242
# EPOCH = 691629.488295, wall = 145.31 ms, jitter = 145.31 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=243
# EPOCH = 691629.576030, wall =  87.73 ms, jitter =  87.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=244
# EPOCH = 691629.736107, wall = 160.08 ms, jitter = 160.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=245
# EPOCH = 691629.834493, wall =  98.39 ms, jitter =  98.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=246
# EPOCH = 691629.968222, wall = 133.73 ms, jitter = 133.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=247
# EPOCH = 691630.119717, wall = 151.50 ms, jitter = 151.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=248
# EPOCH = 691630.233159, wall = 113.44 ms, jitter = 113.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=249
# EPOCH = 691630.340268, wall = 107.11 ms, jitter = 107.11 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=250
# EPOCH = 691630.491435, wall = 151.17 ms, jitter = 151.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=251
# EPOCH = 691630.615188, wall = 123.75 ms, jitter = 123.75 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=252
# EPOCH = 691630.703609, wall =  88.42 ms, jitter =  88.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=253
# EPOCH = 691630.897126, wall = 193.52 ms, jitter = 193.52 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=254
# EPOCH = 691630.988999, wall =  91.87 ms, jitter =  91.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=255
# EPOCH = 691631.106327, wall = 117.33 ms, jitter = 117.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=256
# EPOCH = 691631.250935, wall = 144.61 ms, jitter = 144.61 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=257
# EPOCH = 691631.384524, wall = 133.59 ms, jitter = 133.59 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=258
# EPOCH = 691631.509665, wall = 125.14 ms, jitter = 125.14 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=259
# EPOCH = 691631.607160, wall =  97.49 ms, jitter =  97.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=260
# EPOCH = 691631.723707, wall = 116.55 ms, jitter = 116.55 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=261
# EPOCH = 691631.862846, wall = 139.14 ms, jitter = 139.14 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=262
# EPOCH = 691631.998664, wall = 135.82 ms, jitter = 135.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=263
# EPOCH = 691632.083621, wall =  84.96 ms, jitter =  84.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=264
# EPOCH = 691632.240975, wall = 157.35 ms, jitter = 157.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=265
# EPOCH = 691632.347220, wall = 106.24 ms, jitter = 106.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=266
# EPOCH = 691632.466687, wall = 119.47 ms, jitter = 119.47 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=267
# EPOCH = 691632.581110, wall = 114.42 ms, jitter = 114.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=268
# EPOCH = 691632.755715, wall = 174.60 ms, jitter = 174.60 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=269
# EPOCH = 691632.914355, wall = 158.64 ms, jitter = 158.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=270
# EPOCH = 691632.964995, wall =  50.64 ms, jitter =  50.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=271
# EPOCH = 691633.075871, wall = 110.88 ms, jitter = 110.88 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=272
# EPOCH = 691633.207201, wall = 131.33 ms, jitter = 131.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=273
# EPOCH = 691633.349874, wall = 142.67 ms, jitter = 142.67 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=274
# EPOCH = 691633.457285, wall = 107.41 ms, jitter = 107.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=275
# EPOCH = 691633.623966, wall = 166.68 ms, jitter = 166.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=276
# EPOCH = 691633.735840, wall = 111.87 ms, jitter = 111.87 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=277
# EPOCH = 691633.835749, wall =  99.91 ms, jitter =  99.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=278
# EPOCH = 691633.994970, wall = 159.22 ms, jitter = 159.22 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=279
# EPOCH = 691634.110681, wall = 115.71 ms, jitter = 115.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=280
# EPOCH = 691634.225846, wall = 115.16 ms, jitter = 115.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=281
# EPOCH = 691634.360545, wall = 134.70 ms, jitter = 134.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=282
# EPOCH = 691634.513513, wall = 152.97 ms, jitter = 152.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=283
# EPOCH = 691634.625374, wall = 111.86 ms, jitter = 111.86 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=284
# EPOCH = 691634.721219, wall =  95.84 ms, jitter =  95.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=285
# EPOCH = 691634.857865, wall = 136.65 ms, jitter = 136.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=286
# EPOCH = 691634.972587, wall = 114.72 ms, jitter = 114.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=287
# EPOCH = 691635.074167, wall = 101.58 ms, jitter = 101.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=288
# EPOCH = 691635.224540, wall = 150.37 ms, jitter = 150.37 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=289
# EPOCH = 691635.376486, wall = 151.95 ms, jitter = 151.95 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=290
# EPOCH = 691635.496632, wall = 120.15 ms, jitter = 120.15 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=291
# EPOCH = 691635.670981, wall = 174.35 ms, jitter = 174.35 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=292
# EPOCH = 691635.709838, wall =  38.86 ms, jitter =  38.86 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=293
# EPOCH = 691635.869994, wall = 160.16 ms, jitter = 160.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=294
# EPOCH = 691635.973037, wall = 103.04 ms, jitter = 103.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=295
# EPOCH = 691636.088216, wall = 115.18 ms, jitter = 115.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=296
# EPOCH = 691636.201049, wall = 112.83 ms, jitter = 112.83 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=297
# EPOCH = 691636.368791, wall = 167.74 ms, jitter = 167.74 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=298
# EPOCH = 691636.459850, wall =  91.06 ms, jitter =  91.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=299
# EPOCH = 691636.588534, wall = 128.68 ms, jitter = 128.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=300
# EPOCH = 691636.719889, wall = 131.35 ms, jitter = 131.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=301
# EPOCH = 691636.848689, wall = 128.80 ms, jitter = 128.80 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=302
# EPOCH = 691636.980562, wall = 131.87 ms, jitter = 131.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=303
# EPOCH = 691637.120386, wall = 139.82 ms, jitter = 139.82 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=304
# EPOCH = 691637.222022, wall = 101.64 ms, jitter = 101.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=305
# EPOCH = 691637.423288, wall = 201.27 ms, jitter = 201.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=306
# EPOCH = 691637.475516, wall =  52.23 ms, jitter =  52.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=307
# EPOCH = 691637.585768, wall = 110.25 ms, jitter = 110.25 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=308
# EPOCH = 691637.713997, wall = 128.23 ms, jitter = 128.23 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=309
# EPOCH = 691637.854203, wall = 140.21 ms, jitter = 140.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=310
# EPOCH = 691637.990501, wall = 136.30 ms, jitter = 136.30 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=311
# EPOCH = 691638.140518, wall = 150.02 ms, jitter = 150.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=312
# EPOCH = 691638.254082, wall = 113.56 ms, jitter = 113.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=313
# EPOCH = 691638.358160, wall = 104.08 ms, jitter = 104.08 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=314
# EPOCH = 691638.481718, wall = 123.56 ms, jitter = 123.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=315
# EPOCH = 691638.586714, wall = 105.00 ms, jitter = 105.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=316
# EPOCH = 691638.759984, wall = 173.27 ms, jitter = 173.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=317
# EPOCH = 691638.907185, wall = 147.20 ms, jitter = 147.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=318
# EPOCH = 691638.962010, wall =  54.82 ms, jitter =  54.82 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=319
# EPOCH = 691639.089382, wall = 127.37 ms, jitter = 127.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=320
# EPOCH = 691639.203512, wall = 114.13 ms, jitter = 114.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=321
# EPOCH = 691639.416550, wall = 213.04 ms, jitter = 213.04 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=322
# EPOCH = 691639.480960, wall =  64.41 ms, jitter =  64.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=323
# EPOCH = 691639.602126, wall = 121.17 ms, jitter = 121.17 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=324
# EPOCH = 691639.729294, wall = 127.17 ms, jitter = 127.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=325
# EPOCH = 691639.837309, wall = 108.01 ms, jitter = 108.01 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=326
# EPOCH = 691639.974036, wall = 136.73 ms, jitter = 136.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=327
# EPOCH = 691640.091556, wall = 117.52 ms, jitter = 117.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=328
# EPOCH = 691640.215733, wall = 124.18 ms, jitter = 124.18 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=329
# EPOCH = 691640.324654, wall = 108.92 ms, jitter = 108.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=330
# EPOCH = 691640.453518, wall = 128.86 ms, jitter = 128.86 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=331
# EPOCH = 691640.591387, wall = 137.87 ms, jitter = 137.87 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=332
# EPOCH = 691640.703063, wall = 111.68 ms, jitter = 111.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=333
# EPOCH = 691640.870208, wall = 167.15 ms, jitter = 167.15 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=334
# EPOCH = 691640.989668, wall = 119.46 ms, jitter = 119.46 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=335
# EPOCH = 691641.129933, wall = 140.27 ms, jitter = 140.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=336
# EPOCH = 691641.232319, wall = 102.39 ms, jitter = 102.39 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=337
# EPOCH = 691641.338439, wall = 106.12 ms, jitter = 106.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=338
# EPOCH = 691641.464094, wall = 125.65 ms, jitter = 125.65 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=339
# EPOCH = 691641.580356, wall = 116.26 ms, jitter = 116.26 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=340
# EPOCH = 691641.732787, wall = 152.43 ms, jitter = 152.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=341
# EPOCH = 691641.841842, wall = 109.06 ms, jitter = 109.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=342
# EPOCH = 691641.980344, wall = 138.50 ms, jitter = 138.50 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=343
# EPOCH = 691642.109948, wall = 129.60 ms, jitter = 129.60 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=344
# EPOCH = 691642.224998, wall = 115.05 ms, jitter = 115.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=345
# EPOCH = 691642.349604, wall = 124.61 ms, jitter = 124.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=346
# EPOCH = 691642.461710, wall = 112.11 ms, jitter = 112.11 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=347
# EPOCH = 691642.577679, wall = 115.97 ms, jitter = 115.97 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=348
# EPOCH = 691642.738545, wall = 160.87 ms, jitter = 160.87 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=349
# EPOCH = 691642.853383, wall = 114.84 ms, jitter = 114.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=350
# EPOCH = 691642.960520, wall = 107.14 ms, jitter = 107.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=351
# EPOCH = 691643.120908, wall = 160.39 ms, jitter = 160.39 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=352
# EPOCH = 691643.232341, wall = 111.43 ms, jitter = 111.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=353
# EPOCH = 691643.360279, wall = 127.94 ms, jitter = 127.94 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=354
# EPOCH = 691643.476648, wall = 116.37 ms, jitter = 116.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=355
# EPOCH = 691643.617297, wall = 140.65 ms, jitter = 140.65 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=356
# EPOCH = 691643.736061, wall = 118.76 ms, jitter = 118.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=357
# EPOCH = 691643.832760, wall =  96.70 ms, jitter =  96.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=358
# EPOCH = 691643.958294, wall = 125.53 ms, jitter = 125.53 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=359
# EPOCH = 691644.144917, wall = 186.62 ms, jitter = 186.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=360
# EPOCH = 691644.248441, wall = 103.52 ms, jitter = 103.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=361
# EPOCH = 691644.347368, wall =  98.93 ms, jitter =  98.93 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=362
# EPOCH = 691644.466390, wall = 119.02 ms, jitter = 119.02 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=363
# EPOCH = 691644.593827, wall = 127.44 ms, jitter = 127.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=364
# EPOCH = 691644.697538, wall = 103.71 ms, jitter = 103.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=365
# EPOCH = 691644.870744, wall = 173.21 ms, jitter = 173.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=366
# EPOCH = 691645.044645, wall = 173.90 ms, jitter = 173.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=367
# EPOCH = 691645.077676, wall =  33.03 ms, jitter =  33.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=368
# EPOCH = 691645.212930, wall = 135.25 ms, jitter = 135.25 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=369
# EPOCH = 691645.329847, wall = 116.92 ms, jitter = 116.92 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=370
# EPOCH = 691645.455930, wall = 126.08 ms, jitter = 126.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=371
# EPOCH = 691645.578052, wall = 122.12 ms, jitter = 122.12 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=372
# EPOCH = 691645.730614, wall = 152.56 ms, jitter = 152.56 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=373
# EPOCH = 691645.847635, wall = 117.02 ms, jitter = 117.02 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=374
# EPOCH = 691645.997622, wall = 149.99 ms, jitter = 149.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=375
# EPOCH = 691646.134956, wall = 137.33 ms, jitter = 137.33 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=376
# EPOCH = 691646.228722, wall =  93.77 ms, jitter =  93.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=377
# EPOCH = 691646.363866, wall = 135.14 ms, jitter = 135.14 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=378
# EPOCH = 691646.502294, wall = 138.43 ms, jitter = 138.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=379
# EPOCH = 691646.669573, wall = 167.28 ms, jitter = 167.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=380
# EPOCH = 691646.711397, wall =  41.82 ms, jitter =  41.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=381
# EPOCH = 691646.837740, wall = 126.34 ms, jitter = 126.34 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=382
# EPOCH = 691647.000456, wall = 162.72 ms, jitter = 162.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=383
# EPOCH = 691647.122184, wall = 121.73 ms, jitter = 121.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=384
# EPOCH = 691647.213659, wall =  91.48 ms, jitter =  91.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=385
# EPOCH = 691647.356493, wall = 142.83 ms, jitter = 142.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=386
# EPOCH = 691647.517917, wall = 161.42 ms, jitter = 161.42 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=387
# EPOCH = 691647.576674, wall =  58.76 ms, jitter =  58.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=388
# EPOCH = 691647.752750, wall = 176.08 ms, jitter = 176.08 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=389
# EPOCH = 691647.879933, wall = 127.18 ms, jitter = 127.18 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=390
# EPOCH = 691648.021301, wall = 141.37 ms, jitter = 141.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=391
# EPOCH = 691648.129977, wall = 108.68 ms, jitter = 108.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=392
# EPOCH = 691648.291405, wall = 161.43 ms, jitter = 161.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=393
# EPOCH = 691648.393865, wall = 102.46 ms, jitter = 102.46 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=394
# EPOCH = 691648.486440, wall =  92.57 ms, jitter =  92.57 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=395
# EPOCH = 691648.605482, wall = 119.04 ms, jitter = 119.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=396
# EPOCH = 691648.774543, wall = 169.06 ms, jitter = 169.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=397
# EPOCH = 691648.865235, wall =  90.69 ms, jitter =  90.69 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=398
# EPOCH = 691649.016195, wall = 150.96 ms, jitter = 150.96 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=399
# EPOCH = 691649.147726, wall = 131.53 ms, jitter = 131.53 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=400
# EPOCH = 691649.261957, wall = 114.23 ms, jitter = 114.23 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=401
# EPOCH = 691649.369474, wall = 107.52 ms, jitter = 107.52 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=402
# EPOCH = 691649.493994, wall = 124.52 ms, jitter = 124.52 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=403
# EPOCH = 691649.594486, wall = 100.49 ms, jitter = 100.49 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=404
# EPOCH = 691649.712858, wall = 118.37 ms, jitter = 118.37 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=405
# EPOCH = 691649.895572, wall = 182.71 ms, jitter = 182.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=406
# EPOCH = 691650.045023, wall = 149.45 ms, jitter = 149.45 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=407
# EPOCH = 691650.077512, wall =  32.49 ms, jitter =  32.49 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=408
# EPOCH = 691650.207846, wall = 130.33 ms, jitter = 130.33 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=409
# EPOCH = 691650.330629, wall = 122.78 ms, jitter = 122.78 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=410
# EPOCH = 691650.466053, wall = 135.42 ms, jitter = 135.42 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=411
# EPOCH = 691650.627254, wall = 161.20 ms, jitter = 161.20 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=412
# EPOCH = 691650.709443, wall =  82.19 ms, jitter =  82.19 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=413
# ...
# EPOCH = 691706.072060, wall = 116.82 ms, jitter = 116.82 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=855
# EPOCH = 691706.200508, wall = 128.45 ms, jitter = 128.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=856
# EPOCH = 691706.325938, wall = 125.43 ms, jitter = 125.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=857
# EPOCH = 691706.462390, wall = 136.45 ms, jitter = 136.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=858
# EPOCH = 691706.590113, wall = 127.72 ms, jitter = 127.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=859
# EPOCH = 691706.714569, wall = 124.46 ms, jitter = 124.46 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=860
# EPOCH = 691706.845293, wall = 130.72 ms, jitter = 130.72 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=861
# EPOCH = 691706.950723, wall = 105.43 ms, jitter = 105.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=862
# EPOCH = 691707.069163, wall = 118.44 ms, jitter = 118.44 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=863
# EPOCH = 691707.193872, wall = 124.71 ms, jitter = 124.71 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=864
# EPOCH = 691707.339161, wall = 145.29 ms, jitter = 145.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=865
# EPOCH = 691707.460483, wall = 121.32 ms, jitter = 121.32 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=866
# EPOCH = 691707.571247, wall = 110.76 ms, jitter = 110.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=867
# EPOCH = 691707.767231, wall = 195.98 ms, jitter = 195.98 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=868
# EPOCH = 691707.855890, wall =  88.66 ms, jitter =  88.66 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=869
# EPOCH = 691707.960773, wall = 104.88 ms, jitter = 104.88 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=870
# EPOCH = 691708.103828, wall = 143.05 ms, jitter = 143.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=871
# EPOCH = 691708.210898, wall = 107.07 ms, jitter = 107.07 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=872
# EPOCH = 691708.339508, wall = 128.61 ms, jitter = 128.61 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=873
# EPOCH = 691708.463715, wall = 124.21 ms, jitter = 124.21 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=874
# EPOCH = 691708.583914, wall = 120.20 ms, jitter = 120.20 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=875
# EPOCH = 691708.734206, wall = 150.29 ms, jitter = 150.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=876
# EPOCH = 691708.830786, wall =  96.58 ms, jitter =  96.58 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=877
# EPOCH = 691708.958420, wall = 127.63 ms, jitter = 127.63 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=878
# EPOCH = 691709.103325, wall = 144.90 ms, jitter = 144.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=879
# EPOCH = 691709.209225, wall = 105.90 ms, jitter = 105.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=880
# EPOCH = 691709.343127, wall = 133.90 ms, jitter = 133.90 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=881
# EPOCH = 691709.476861, wall = 133.73 ms, jitter = 133.73 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=882
# EPOCH = 691709.620944, wall = 144.08 ms, jitter = 144.08 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=883
# EPOCH = 691709.694109, wall =  73.16 ms, jitter =  73.16 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=884
# EPOCH = 691709.872786, wall = 178.68 ms, jitter = 178.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=885
# EPOCH = 691710.003222, wall = 130.44 ms, jitter = 130.44 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=886
# EPOCH = 691710.095730, wall =  92.51 ms, jitter =  92.51 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=887
# EPOCH = 691710.201995, wall = 106.27 ms, jitter = 106.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=888
# EPOCH = 691710.347030, wall = 145.03 ms, jitter = 145.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=889
# EPOCH = 691710.445086, wall =  98.06 ms, jitter =  98.06 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=890
# EPOCH = 691710.599153, wall = 154.07 ms, jitter = 154.07 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=891
# EPOCH = 691710.695266, wall =  96.11 ms, jitter =  96.11 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=892
# EPOCH = 691710.831697, wall = 136.43 ms, jitter = 136.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=893
# EPOCH = 691710.976690, wall = 144.99 ms, jitter = 144.99 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=894
# EPOCH = 691711.106975, wall = 130.28 ms, jitter = 130.28 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=895
# EPOCH = 691711.215246, wall = 108.27 ms, jitter = 108.27 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=896
# EPOCH = 691711.326968, wall = 111.72 ms, jitter = 111.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=897
# EPOCH = 691711.464211, wall = 137.24 ms, jitter = 137.24 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=898
# EPOCH = 691711.582176, wall = 117.97 ms, jitter = 117.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=899
# EPOCH = 691711.709134, wall = 126.96 ms, jitter = 126.96 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=900
# EPOCH = 691711.825802, wall = 116.67 ms, jitter = 116.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=901
# EPOCH = 691711.951524, wall = 125.72 ms, jitter = 125.72 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=902
# EPOCH = 691712.073976, wall = 122.45 ms, jitter = 122.45 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=903
# EPOCH = 691712.235241, wall = 161.27 ms, jitter = 161.27 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=904
# EPOCH = 691712.321403, wall =  86.16 ms, jitter =  86.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=905
# EPOCH = 691712.464276, wall = 142.87 ms, jitter = 142.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=906
# EPOCH = 691712.584956, wall = 120.68 ms, jitter = 120.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=907
# EPOCH = 691712.719242, wall = 134.29 ms, jitter = 134.29 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=908
# EPOCH = 691712.836852, wall = 117.61 ms, jitter = 117.61 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=909
# EPOCH = 691712.972285, wall = 135.43 ms, jitter = 135.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=910
# EPOCH = 691713.086278, wall = 113.99 ms, jitter = 113.99 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=911
# EPOCH = 691713.230288, wall = 144.01 ms, jitter = 144.01 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=912
# EPOCH = 691713.331114, wall = 100.83 ms, jitter = 100.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=913
# EPOCH = 691713.477012, wall = 145.90 ms, jitter = 145.90 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=914
# EPOCH = 691713.601440, wall = 124.43 ms, jitter = 124.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=915
# EPOCH = 691713.712984, wall = 111.54 ms, jitter = 111.54 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=916
# EPOCH = 691713.823481, wall = 110.50 ms, jitter = 110.50 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=917
# EPOCH = 691713.952158, wall = 128.68 ms, jitter = 128.68 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=918
# EPOCH = 691714.085437, wall = 133.28 ms, jitter = 133.28 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=919
# EPOCH = 691714.196145, wall = 110.71 ms, jitter = 110.71 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=920
# EPOCH = 691714.377903, wall = 181.76 ms, jitter = 181.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=921
# EPOCH = 691714.455960, wall =  78.06 ms, jitter =  78.06 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=922
# EPOCH = 691714.593994, wall = 138.03 ms, jitter = 138.03 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=923
# EPOCH = 691714.753696, wall = 159.70 ms, jitter = 159.70 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=924
# EPOCH = 691714.837046, wall =  83.35 ms, jitter =  83.35 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=925
# EPOCH = 691714.969453, wall = 132.41 ms, jitter = 132.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=926
# EPOCH = 691715.083419, wall = 113.97 ms, jitter = 113.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=927
# EPOCH = 691715.213166, wall = 129.75 ms, jitter = 129.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=928
# EPOCH = 691715.321700, wall = 108.53 ms, jitter = 108.53 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=929
# EPOCH = 691715.450834, wall = 129.13 ms, jitter = 129.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=930
# EPOCH = 691715.591261, wall = 140.43 ms, jitter = 140.43 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=931
# EPOCH = 691715.739229, wall = 147.97 ms, jitter = 147.97 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=932
# EPOCH = 691715.875616, wall = 136.39 ms, jitter = 136.39 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=933
# EPOCH = 691715.974224, wall =  98.61 ms, jitter =  98.61 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=934
# EPOCH = 691716.107859, wall = 133.64 ms, jitter = 133.64 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=935
# EPOCH = 691716.215911, wall = 108.05 ms, jitter = 108.05 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=936
# EPOCH = 691716.344833, wall = 128.92 ms, jitter = 128.92 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=937
# EPOCH = 691716.464215, wall = 119.38 ms, jitter = 119.38 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=938
# EPOCH = 691716.582282, wall = 118.07 ms, jitter = 118.07 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=939
# EPOCH = 691716.697405, wall = 115.12 ms, jitter = 115.12 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=940
# EPOCH = 691716.888911, wall = 191.51 ms, jitter = 191.51 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=941
# EPOCH = 691716.984654, wall =  95.74 ms, jitter =  95.74 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=942
# EPOCH = 691717.071788, wall =  87.13 ms, jitter =  87.13 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=943
# EPOCH = 691717.202208, wall = 130.42 ms, jitter = 130.42 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=944
# EPOCH = 691717.339310, wall = 137.10 ms, jitter = 137.10 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=945
# EPOCH = 691717.462479, wall = 123.17 ms, jitter = 123.17 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=946
# EPOCH = 691717.571645, wall = 109.17 ms, jitter = 109.17 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=947
# EPOCH = 691717.737574, wall = 165.93 ms, jitter = 165.93 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=948
# EPOCH = 691717.845976, wall = 108.40 ms, jitter = 108.40 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=949
# EPOCH = 691717.958677, wall = 112.70 ms, jitter = 112.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=950
# EPOCH = 691718.073296, wall = 114.62 ms, jitter = 114.62 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=951
# EPOCH = 691718.242733, wall = 169.44 ms, jitter = 169.44 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=952
# EPOCH = 691718.325172, wall =  82.44 ms, jitter =  82.44 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=953
# EPOCH = 691718.461806, wall = 136.63 ms, jitter = 136.63 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=954
# EPOCH = 691718.614556, wall = 152.75 ms, jitter = 152.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=955
# EPOCH = 691718.701223, wall =  86.67 ms, jitter =  86.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=956
# EPOCH = 691718.838475, wall = 137.25 ms, jitter = 137.25 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=957
# EPOCH = 691718.952057, wall = 113.58 ms, jitter = 113.58 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=958
# EPOCH = 691719.072592, wall = 120.53 ms, jitter = 120.53 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=959
# EPOCH = 691719.222257, wall = 149.67 ms, jitter = 149.67 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=960
# EPOCH = 691719.323147, wall = 100.89 ms, jitter = 100.89 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=961
# EPOCH = 691719.443902, wall = 120.76 ms, jitter = 120.76 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=962
# EPOCH = 691719.569281, wall = 125.38 ms, jitter = 125.38 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=963
# EPOCH = 691719.726690, wall = 157.41 ms, jitter = 157.41 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=964
# EPOCH = 691719.831556, wall = 104.87 ms, jitter = 104.87 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=965
# EPOCH = 691719.955398, wall = 123.84 ms, jitter = 123.84 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=966
# EPOCH = 691720.071945, wall = 116.55 ms, jitter = 116.55 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=967
# EPOCH = 691720.238280, wall = 166.34 ms, jitter = 166.34 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=968
# EPOCH = 691720.335959, wall =  97.68 ms, jitter =  97.68 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=969
# EPOCH = 691720.458172, wall = 122.21 ms, jitter = 122.21 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=970
# EPOCH = 691720.582209, wall = 124.04 ms, jitter = 124.04 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=971
# EPOCH = 691720.736692, wall = 154.48 ms, jitter = 154.48 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=972
# EPOCH = 691720.857457, wall = 120.77 ms, jitter = 120.77 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=973
# EPOCH = 691720.979224, wall = 121.77 ms, jitter = 121.77 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=974
# EPOCH = 691721.094980, wall = 115.76 ms, jitter = 115.76 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=975
# EPOCH = 691721.229727, wall = 134.75 ms, jitter = 134.75 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=976
# EPOCH = 691721.339753, wall = 110.03 ms, jitter = 110.03 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=977
# EPOCH = 691721.470755, wall = 131.00 ms, jitter = 131.00 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=978
# EPOCH = 691721.587101, wall = 116.35 ms, jitter = 116.35 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=979
# EPOCH = 691721.758262, wall = 171.16 ms, jitter = 171.16 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=980
# EPOCH = 691721.884676, wall = 126.41 ms, jitter = 126.41 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=981
# EPOCH = 691721.988056, wall = 103.38 ms, jitter = 103.38 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=982
# EPOCH = 691722.070882, wall =  82.83 ms, jitter =  82.83 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=983
# EPOCH = 691722.226003, wall = 155.12 ms, jitter = 155.12 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=984
# EPOCH = 691722.366347, wall = 140.34 ms, jitter = 140.34 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=985
# EPOCH = 691722.500826, wall = 134.48 ms, jitter = 134.48 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=986
# EPOCH = 691722.589769, wall =  88.94 ms, jitter =  88.94 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=987
# EPOCH = 691722.695680, wall = 105.91 ms, jitter = 105.91 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=988
# EPOCH = 691722.860110, wall = 164.43 ms, jitter = 164.43 ms  delta c=+25, v= 0.098, len(dir_log)=12500, buf_len=989
# EPOCH = 691722.952470, wall =  92.36 ms, jitter =  92.36 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=990
# EPOCH = 691723.076174, wall = 123.70 ms, jitter = 123.70 ms  delta c=+26, v= 0.102, len(dir_log)=12500, buf_len=991
# Graceful shutdown.
