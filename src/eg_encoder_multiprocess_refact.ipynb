# %%
import time, threading, queue, sys, gc
from typing import Tuple

import numpy as np
import pyqtgraph as pg
from PyQt6 import QtCore
from collections import deque

import logging, logging.handlers

# %% [markdown]
# | **速度目標 [rps]** | **1秒当たり [pulses / s]** | **1iterあたり [pulses]** | **カウント** | **再構成速度 (UP / DOWN) \[rps]** | **偏差 \[%]** |
# | ----------------- | -------------------------- | --------------------------- | ----------------------- | ------------------------------- | -------------------------- |
# | 0.1               | 204.8                      | 25.6                        | 26<br>25                | 0.102<br>0.09765625             | +1.56<br>−2.34             |
# | 0.2               | 409.6                      | 51.2                        | 52<br>51                | 0.203<br>0.19921875             | +1.56<br>−0.39             |
# | 0.3               | 614.4                      | 76.8                        | 77<br>76                | 0.301<br>0.296875               | +0.26<br>−1.04             |
# | 0.4               | 819.2                      | 102.4                       | 103<br>102              | 0.402<br>0.3984375              | +0.59<br>−0.39             |
# | 0.5               | 1 024.0                    | 128.0                       | 128<br>128              | 0.500<br>0.500                  | 0.00<br>0.00               |
# | 0.6               | 1 228.8                    | 153.6                       | 154<br>153              | 0.602<br>0.59765625             | +0.26<br>−0.39             |
# | 0.7               | 1 433.6                    | 179.2                       | 180<br>179              | 0.703<br>0.69921875             | +0.45<br>−0.11             |
# | 0.8               | 1 638.4                    | 204.8                       | 205<br>204              | 0.801<br>0.796875               | +0.10<br>−0.39             |
# | 0.9               | 1 843.2                    | 230.4                       | 231<br>230              | 0.902<br>0.8984375              | +0.26<br>−0.17             |
# | 1.0               | 2 048.0                    | 256.0                       | 256<br>256              | 1.000<br>1.000                  | 0.00<br>0.00               |

# %%
# ------------------------------------------------------------  parameters
DEBUG = True  # set True for jitter log
SAMPLE_RATE = 100_000  # Hz
GEN_CHUNK_SEC = 0.1 # corresponds to PROC_INTERVAL up to 0.05
PROC_INTERVAL = 0.125          # process rate

CHUNK_SEC     = GEN_CHUNK_SEC
N_SAMPLES_GEN = int(SAMPLE_RATE * GEN_CHUNK_SEC) # 100_000 * 0.05 = 5000
SAMPLES_PROC = int(PROC_INTERVAL * SAMPLE_RATE) # 0.125s * 100kHz = 12500
QUEUE_DEPTH = 40  # raw AB backlog
QUAD_DEPTH = 40  # processed backlog (same)
RUN_SEC = 600  # auto‑stop after 10 s
DISPLAY_SEC = RUN_SEC+600
PLOT_SEC = 0.02  # *** fixed x-axis window width (s) ***
GUI_INTERVAL_MS = 50  # update interval (ms) e.g. 50ms = 20Hz

PULSE_HEIGHT = 5.0  # amplitude
INPUT_VELOCITY = 0.1  # rps

PULSE_WIDTH = 1 / (INPUT_VELOCITY * 512)  # period  (s)
PULSE_DUTY = 0.5  # duty
PULSE_PHASE_A = 0.0  # phase offset (s)
PULSE_PHASE_B = -PULSE_WIDTH / 4  # phase offset (s)

QUADPULSE_WIDTH = 0.00025  # width (s) assuming 4x given 1 rps
THRESHOLD_DEFAULT = 2.5  # logic threshold (V)

IDEAL_CPS = INPUT_VELOCITY   # counts/s (constant ideal)

# GUI buffer lengths (empirical)
HISTORY = int(SAMPLE_RATE * PLOT_SEC)
COUNT_HISTORY = int(RUN_SEC / GEN_CHUNK_SEC)
VELO_HISTORY = COUNT_HISTORY


# ------------------------------------------------------------  queues & stop flag
buf_q = queue.Queue(maxsize=QUEUE_DEPTH)  # raw (t, A, B)
quad_q = queue.Queue(maxsize=QUAD_DEPTH)  # processed (t, A, B, quad)
stop_writer = threading.Event()

log_q = queue.Queue(maxsize=0)
queue_h = logging.handlers.QueueHandler(log_q)
logger = logging.getLogger("debug")
logger.setLevel(logging.INFO)
logger.addHandler(queue_h)

# %%
def gen_chunk_pulse(
    t: np.ndarray,
    *,
    height: float = PULSE_HEIGHT,
    width: float = PULSE_WIDTH,
    duty: float = PULSE_DUTY,
    phase: float = 0.0,
) -> np.ndarray:
    mod = (t + phase) % width
    return np.where(mod < duty * width, height, 0.0).astype(np.float32)


REL_AXIS_GEN = (
    np.arange(N_SAMPLES_GEN, dtype=np.float32) / SAMPLE_RATE
)  # 0 ... 0.2 s

# ------------------------------------------------------------  AB → direction → quad helpers


def gen_pulse_direction(
    dA: np.ndarray,
    dB: np.ndarray,
    *,
    threshold: float,
    prev_A: bool | None = None,
    prev_B: bool | None = None,
) -> tuple[np.ndarray, bool, bool]:
    """
    Detect direction for one block **with perfect edge coverage**.

    Parameters
    ----------
    dA, dB : ndarray[float32]
        Analog levels of phase-A / phase-B for the current block.
    threshold : float
        Logic threshold [V].
    prev_A, prev_B : bool | None
        Logical state of A/B *at the end of the PREVIOUS block*.
        • If None (first block), the function falls back to the
          “self-shift” method used before.

    Returns
    -------
    dir_log : ndarray[int8]
        +1 = CW edge, –1 = CCW edge, 0 = no edge.
    last_A, last_B : bool
        Logical state of A/B at the *end* of this block — feed these
        into the next call to avoid losing the boundary edge.
    """
    # --- current logic level ----------------------------------------
    A = dA > threshold
    B = dB > threshold

    # --- previous sample for XOR -----------------------------------
    if prev_A is None:  # first block → old behaviour
        A_prev = np.concatenate(([A[0]], A[:-1]))
        B_prev = np.concatenate(([B[0]], B[:-1]))
    else:               # use states carried over from last block
        A_prev = np.concatenate(([prev_A], A[:-1]))
        B_prev = np.concatenate(([prev_B], B[:-1]))

    dir_log = (B_prev ^ A).astype(int) - (A_prev ^ B).astype(int)

    return dir_log.astype(np.int8), bool(A[-1]), bool(B[-1])

def pulse_count(dir_log: np.ndarray) -> int:
    #return int(np.sum(dir_log))
    return np.sum(dir_log)


def gen_quad_pulse(
    t: np.ndarray, dir_log: np.ndarray, width: float, height: float, sampling_rate: int
) -> np.ndarray:
    samples = int(width * sampling_rate)
    if samples <= 0:
        return np.zeros_like(dir_log, dtype=np.float32)
    base = np.full(samples, height, dtype=np.float32)
    return np.convolve(dir_log, base, mode="full")[: len(t)]


# ------------------------------------------------------------  producer thread
def generator() -> None:
    """Generate AB rectangular-wave chunks at real-time cadence."""
    chunk_idx = 0
    next_t = time.perf_counter()
    while not stop_writer.is_set():
        base = chunk_idx * GEN_CHUNK_SEC
        t_axis = REL_AXIS_GEN + base
        pulse_A = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_A)
        pulse_B = gen_chunk_pulse(t_axis, phase=PULSE_PHASE_B)
        try:
            buf_q.put_nowait((t_axis, pulse_A, pulse_B))
        except queue.Full:
            pass

        chunk_idx += 1
        next_t += GEN_CHUNK_SEC
        sleep = next_t - time.perf_counter()
        if sleep > 0:
            time.sleep(sleep)
        else:
            next_t = time.perf_counter()


# ------------------------------------------------------------  consumer thread
def log_listener():
    handler = logging.StreamHandler(sys.stdout)
    listener = logging.handlers.QueueListener(log_q, handler)
    listener.start()
    stop_writer.wait()
    listener.stop()

def command_freq(t_DC, step, rst, target_freq, proc_interval):

    time = np.arange(0, t_DC+36000*target_freq/(step/rst)+60*60*2, proc_interval, dtype=np.float32)
    freq = np.zeros(int((t_DC+36000*target_freq/(step/rst)+60*60*2)*(1/proc_interval)), dtype=np.float32)

    # Refactoring suggestions
    # 1. Use numpy's vectorized operations instead of loops for better performance.
    # eg. precomupte the indices and use numpy's advanced indexing
    # n_dc       = int(np.round(t_dc / sample_dt))
    # freq[:n_dc] = 0.0

    for i in range(int(t_DC*(1/proc_interval))): #DCの速度指令値=0rps
        freq[i] = 0.0

    for i in range(int(36000*target_freq/step)): #加速中の速度指令値
        for j in range(int(rst*(1/proc_interval))):
            freq[int((t_DC+i*rst)*(1/proc_interval)+j)] = target_freq/36000*step*(i+1)

    for i in range(int(60*60*2*(1/proc_interval))): #Stableの速度指令値
        freq[int((t_DC+36000*target_freq/(step/rst))*(1/proc_interval))+i] = target_freq

    return time, freq

class IdealVelocityProvider:
    def __init__(self, duration: float, dt: float) -> None:
        #num_points: int = int(duration / dt) + 1
        #self.time_axis: np.ndarray = np.linspace(0.0, duration, num_points, dtype=np.float32)
        #self.velocity:  np.ndarray = np.full(num_points, IDEAL_CPS, dtype=np.float32)
        self.time_axis, self.velocity = command_freq(90, 5, 1, 1, proc_interval=PROC_INTERVAL)

    def slice(self, t_start: float, t_end: float) -> tuple[np.ndarray, np.ndarray]:
        """Return the time and velocity arrays that fall within [t_start, t_end]."""
        idx_start, idx_end = np.searchsorted(self.time_axis, [t_start, t_end])
        return self.time_axis[idx_start:idx_end], self.velocity[idx_start:idx_end]

ideal: IdealVelocityProvider | None = None  # initialised lazily in processor()


def processor() -> None:
    """
    deque ベース（旧方式）に戻したリアルタイム・コンシューマ。
    - buf_q から取り出した A/B チャンクを deque(Ring) に追加
    - PROC_INTERVAL ごとに SAMPLES_PROC 分を popleft
    - 理想速度 (IdealVelocityProvider) のスライスを同梱して quad_q へ送信
    ※ logger.info() のフォーマットは従来どおり維持
    dequeにしないとバグる
    """
    # ---------- one-time init ----------
    global ideal_provider
    if 'ideal_provider' not in globals() or ideal_provider is None:
        ideal_provider = IdealVelocityProvider(RUN_SEC, PROC_INTERVAL)

    # --- Python deque リングバッファ ---
    ring_t: deque[np.float32] = deque()
    ring_a: deque[np.float32] = deque()
    ring_b: deque[np.float32] = deque()
    last_A = last_B = None

    next_proc = time.perf_counter()
    cum_count = 0
    last_ts   = next_proc

    while not stop_writer.is_set():
        # ---------- 非ブロッキングで出来るだけ取り込む ----------
        try:
            while True:
                t, pA, pB = buf_q.get_nowait()
                ring_t.extend(t); ring_a.extend(pA); ring_b.extend(pB)
                buf_q.task_done()
        except queue.Empty:
            pass

        # ---------- 次の処理時刻まで待機 ----------
        now = time.perf_counter()
        if now < next_proc:
            time.sleep(next_proc - now)
            continue
        next_proc += PROC_INTERVAL

        # ---------- サンプル不足ならスキップ ----------
        if len(ring_t) < SAMPLES_PROC:
            continue

        # ---------- deque → NumPy へコピー ----------
        t_blk = np.array([ring_t.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        a_blk = np.array([ring_a.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)
        b_blk = np.array([ring_b.popleft() for _ in range(SAMPLES_PROC)], dtype=np.float32)

        # ---------- 信号処理 ----------
        dir_log, last_A, last_B = gen_pulse_direction(
            a_blk, b_blk,
            threshold=THRESHOLD_DEFAULT,
            prev_A=last_A, prev_B=last_B
        )
        quad_sig  = gen_quad_pulse(t_blk, dir_log, QUADPULSE_WIDTH, PULSE_HEIGHT, SAMPLE_RATE)
        delta_cnt = pulse_count(dir_log)
        cum_count += delta_cnt
        velocity  = delta_cnt / PROC_INTERVAL / 2048

        # ---------- 理想速度スライス ----------
        t_ref, v_ref = ideal_provider.slice(t_blk[0], t_blk[-1])

        # ---------- ログ ----------
        if DEBUG:
            now = time.perf_counter()
            jitter = (now - last_ts) * 1e3
            logger.info(
                "EPOCH = %f, wall = %6.2f ms, jitter = %6.2f ms  delta c=%+d  delta raw c=%d  v=%6.3f, len(dir_log)=%d",
                now, jitter, (now - last_ts) * 1e3,
                delta_cnt, np.sum(dir_log), velocity, len(dir_log),
            )
            last_ts = now

        # ---------- GUI へ送信 ----------
        try:
            quad_q.put_nowait(
                (t_blk, a_blk, b_blk, quad_sig,
                 t_blk[-1], cum_count, velocity,
                 t_ref, v_ref)
            )
        except queue.Full:
            pass


def start_gui() -> None:
    pg.setConfigOptions(useOpenGL=True, background="w", foreground="k")
    app = pg.mkQApp("Live plots")

    win = pg.GraphicsLayoutWidget(title="DEMO")

    layout = win.ci.layout                 # GraphicsLayout の中身
    layout.setColumnStretchFactor(0, 3)
    layout.setColumnStretchFactor(1, 5)
    #win_sig = pg.GraphicsLayoutWidget(show=True, title="Signal")
    #win_vel = pg.GraphicsLayoutWidget(show=True, title="Velocity")

    #win_sig.resize(800, 600)
    #win_vel.resize(800, 600)
    #win_sig.show()


    win.resize(800, 600)
    win.show()

    # [0, 0] A/B -------------------------------------------------------
    plt_ab = win.addPlot(row=0, col=0, title="RAW A / B")
    curve_A = plt_ab.plot(pen=pg.mkPen("#ff4b00", width=3))
    curve_B = plt_ab.plot(pen=pg.mkPen("#005aff", width=3))
    plt_ab.setLabel("left", "Amplitude [V]")
    plt_ab.setLabel("bottom", "Time [s]")
    plt_ab.setYRange(-0.5, PULSE_HEIGHT + 0.5)

    # [1,0] Quad waveform --------------------------------------------
    plt_q = win.addPlot(row=1, col=0, title="Quad pulse")
    curve_Q = plt_q.plot(pen=pg.mkPen("m", width=3))
    plt_q.setLabel("left", "Amplitude [V]")
    plt_q.setLabel("bottom", "Time [s]")
    plt_q.setYRange(-PULSE_HEIGHT - 0.5, PULSE_HEIGHT + 0.5)

    # [0,1] count (fixed x-axis) -------------------------------------
    plt_cnt = win.addPlot(row=0, col=1, title="Velovity - Command")
    curve_cnt = plt_cnt.plot(pen=pg.mkPen("#03af7a", width=3))
    #plt_cnt.setXRange(0, RUN_SEC, padding=0)
    #plt_cnt.enableAutoRange("x", True)
    plt_cnt.setLabel("left", "Diff")
    plt_cnt.setLabel("bottom", "Time [s]")

    # [1,1] velocity (fixed x-axis) ----------------------------------
    plt_vel = win.addPlot(row=1, col=1, title="Velocity")
    curve_vel     = plt_vel.plot(pen=pg.mkPen("#00a0e9", width=3))   # measured
    curve_vel_ref = plt_vel.plot(pen=pg.mkPen("#a05aff", width=3))   # ideal (new)
    #plt_vel.setXRange(0, RUN_SEC, padding=0)
    #plt_vel.enableAutoRange("x", True)
    plt_vel.setLabel("left", "Velocity [rps]")
    plt_vel.setLabel("bottom", "Time [s]")

    # buffers ---------------------------------------------------------
    xs = ya = yb = yq = np.empty(0, dtype=np.float32)
    xs_cnt = y_cnt = np.empty(0, dtype=np.float32)
    xs_vel = y_vel = np.empty(0, dtype=np.float32)
    xr = yr = np.empty(0, dtype=np.float32)       # ideal velocity buffers (new)

    def refresh():
        nonlocal xs, ya, yb, yq, xs_cnt, y_cnt, xs_vel, y_vel, xr, yr
        try:
            while True:
                # receive processed data (+ ideal velocity slice)
                t_ax, pA, pB, qsig, t_end, cum_cnt, vel, t_ref, v_ref = quad_q.get_nowait()

                xs = np.concatenate((xs, t_ax))[-HISTORY:]
                ya = np.concatenate((ya, pA))[-HISTORY:]
                yb = np.concatenate((yb, pB))[-HISTORY:]
                yq = np.concatenate((yq, qsig))[-HISTORY:]

                xs_cnt = np.append(xs_cnt, t_end)[-COUNT_HISTORY:]
                y_cnt  = np.append(y_cnt, vel-v_ref)[-COUNT_HISTORY:]

                xs_vel = np.append(xs_vel, t_end)[-VELO_HISTORY:]
                y_vel  = np.append(y_vel, vel)[-VELO_HISTORY:]

                xr = np.concatenate((xr, t_ref))[-VELO_HISTORY:]
                yr = np.concatenate((yr, v_ref))[-VELO_HISTORY:]

                quad_q.task_done()
        except queue.Empty:
            pass

        # scrolling window for waveforms only
        if xs.size:
            start = xs[-1] - PLOT_SEC
            plt_ab.setXRange(start, xs[-1], padding=0)
            plt_q.setXRange(start, xs[-1], padding=0)

        # --- auto-range for count/velocity ---
        if xs_cnt.size:
            plt_cnt.setXRange(xs_cnt[-1]-10, xs_cnt[-1], padding=0)

        if xs_vel.size:
            plt_vel.setXRange(xs_vel[-1]-10, xs_vel[-1], padding=0)

        # --- push data to curves ---
        curve_A.setData(xs, ya)
        curve_B.setData(xs, yb)
        curve_Q.setData(xs, yq)
        curve_cnt.setData(xs_cnt, y_cnt)
        curve_vel.setData(xs_vel, y_vel)
        curve_vel_ref.setData(xr, yr)

    timer = QtCore.QTimer()
    timer.timeout.connect(refresh)
    timer.start(GUI_INTERVAL_MS)

    # auto-stop after RUN_SEC
    QtCore.QTimer.singleShot(int(RUN_SEC * 1000), lambda: (stop_writer.set(), app.quit()))
    app.exec()

# %%
if __name__ == "__main__":
    threading.Thread(target=log_listener, daemon=True).start()  # start log listener

    gen_th  = threading.Thread(target=generator, daemon=True)
    proc_th = threading.Thread(target=processor, daemon=True)

    gen_th.start()
    proc_th.start()
    # con_th.start()

    start_gui()  # blocks until the user closes the window or timer expires

    # join threads and exit
    stop_writer.set()
    gen_th.join()
    proc_th.join()

    print("Graceful shutdown.")
# Out:
# EPOCH = 25190.502979, wall = 261.76 ms, jitter = 261.76 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25190.634524, wall = 131.55 ms, jitter = 131.55 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25190.756142, wall = 121.62 ms, jitter = 121.62 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25190.896567, wall = 140.43 ms, jitter = 140.43 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25191.009378, wall = 112.81 ms, jitter = 112.81 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25191.130144, wall = 120.77 ms, jitter = 120.77 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25191.256336, wall = 126.19 ms, jitter = 126.19 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25191.383666, wall = 127.33 ms, jitter = 127.33 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25191.517452, wall = 133.79 ms, jitter = 133.79 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25191.626921, wall = 109.47 ms, jitter = 109.47 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25191.780656, wall = 153.74 ms, jitter = 153.74 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25191.874389, wall =  93.73 ms, jitter =  93.73 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25192.010205, wall = 135.82 ms, jitter = 135.82 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25192.123899, wall = 113.69 ms, jitter = 113.69 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25192.261150, wall = 137.25 ms, jitter = 137.25 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25192.384242, wall = 123.09 ms, jitter = 123.09 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25192.519035, wall = 134.79 ms, jitter = 134.79 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25192.638086, wall = 119.05 ms, jitter = 119.05 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25192.752603, wall = 114.52 ms, jitter = 114.52 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25192.894921, wall = 142.32 ms, jitter = 142.32 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25193.007722, wall = 112.80 ms, jitter = 112.80 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25193.151423, wall = 143.70 ms, jitter = 143.70 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25193.253483, wall = 102.06 ms, jitter = 102.06 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25193.391397, wall = 137.91 ms, jitter = 137.91 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25193.517836, wall = 126.44 ms, jitter = 126.44 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25193.637747, wall = 119.91 ms, jitter = 119.91 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25193.755146, wall = 117.40 ms, jitter = 117.40 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25193.874343, wall = 119.20 ms, jitter = 119.20 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25194.006251, wall = 131.91 ms, jitter = 131.91 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25194.130378, wall = 124.13 ms, jitter = 124.13 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25194.269601, wall = 139.22 ms, jitter = 139.22 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25194.380441, wall = 110.84 ms, jitter = 110.84 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25194.507963, wall = 127.52 ms, jitter = 127.52 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25194.628057, wall = 120.09 ms, jitter = 120.09 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25194.756691, wall = 128.63 ms, jitter = 128.63 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25194.878339, wall = 121.65 ms, jitter = 121.65 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25195.010091, wall = 131.75 ms, jitter = 131.75 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25195.127249, wall = 117.16 ms, jitter = 117.16 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25195.268905, wall = 141.66 ms, jitter = 141.66 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25195.398212, wall = 129.31 ms, jitter = 129.31 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25195.502950, wall = 104.74 ms, jitter = 104.74 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25195.647709, wall = 144.76 ms, jitter = 144.76 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25195.749642, wall = 101.93 ms, jitter = 101.93 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25195.879499, wall = 129.86 ms, jitter = 129.86 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25196.027632, wall = 148.13 ms, jitter = 148.13 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25196.146984, wall = 119.35 ms, jitter = 119.35 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25196.265631, wall = 118.65 ms, jitter = 118.65 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25196.376038, wall = 110.41 ms, jitter = 110.41 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25196.520918, wall = 144.88 ms, jitter = 144.88 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25196.669686, wall = 148.77 ms, jitter = 148.77 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25196.776125, wall = 106.44 ms, jitter = 106.44 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25196.893293, wall = 117.17 ms, jitter = 117.17 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25197.022028, wall = 128.73 ms, jitter = 128.73 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25197.137987, wall = 115.96 ms, jitter = 115.96 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25197.261153, wall = 123.17 ms, jitter = 123.17 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25197.386974, wall = 125.82 ms, jitter = 125.82 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25197.515129, wall = 128.16 ms, jitter = 128.16 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25197.647115, wall = 131.99 ms, jitter = 131.99 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25197.749282, wall = 102.17 ms, jitter = 102.17 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25197.895024, wall = 145.74 ms, jitter = 145.74 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25198.022621, wall = 127.60 ms, jitter = 127.60 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25198.147393, wall = 124.77 ms, jitter = 124.77 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25198.279537, wall = 132.14 ms, jitter = 132.14 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25198.394893, wall = 115.36 ms, jitter = 115.36 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25198.518844, wall = 123.95 ms, jitter = 123.95 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25198.647951, wall = 129.11 ms, jitter = 129.11 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25198.750237, wall = 102.29 ms, jitter = 102.29 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25198.873340, wall = 123.10 ms, jitter = 123.10 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25199.039588, wall = 166.25 ms, jitter = 166.25 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25199.157228, wall = 117.64 ms, jitter = 117.64 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25199.257798, wall = 100.57 ms, jitter = 100.57 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25199.414037, wall = 156.24 ms, jitter = 156.24 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25199.502031, wall =  87.99 ms, jitter =  87.99 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25199.650714, wall = 148.68 ms, jitter = 148.68 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25199.748984, wall =  98.27 ms, jitter =  98.27 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25199.878896, wall = 129.91 ms, jitter = 129.91 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25200.026585, wall = 147.69 ms, jitter = 147.69 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25200.135788, wall = 109.20 ms, jitter = 109.20 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25200.261663, wall = 125.87 ms, jitter = 125.87 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25200.403315, wall = 141.65 ms, jitter = 141.65 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25200.521187, wall = 117.87 ms, jitter = 117.87 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25200.632586, wall = 111.40 ms, jitter = 111.40 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25200.757139, wall = 124.55 ms, jitter = 124.55 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25200.889541, wall = 132.40 ms, jitter = 132.40 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25201.023873, wall = 134.33 ms, jitter = 134.33 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25201.148211, wall = 124.34 ms, jitter = 124.34 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25201.264908, wall = 116.70 ms, jitter = 116.70 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25201.394718, wall = 129.81 ms, jitter = 129.81 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25201.505143, wall = 110.42 ms, jitter = 110.42 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25201.647414, wall = 142.27 ms, jitter = 142.27 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25201.750171, wall = 102.76 ms, jitter = 102.76 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25201.883770, wall = 133.60 ms, jitter = 133.60 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25202.022115, wall = 138.34 ms, jitter = 138.34 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25202.155139, wall = 133.02 ms, jitter = 133.02 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25202.266445, wall = 111.31 ms, jitter = 111.31 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25202.383890, wall = 117.44 ms, jitter = 117.44 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25202.503973, wall = 120.08 ms, jitter = 120.08 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25202.636322, wall = 132.35 ms, jitter = 132.35 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25202.790877, wall = 154.56 ms, jitter = 154.56 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25202.876950, wall =  86.07 ms, jitter =  86.07 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25203.036066, wall = 159.12 ms, jitter = 159.12 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25203.130647, wall =  94.58 ms, jitter =  94.58 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25203.260814, wall = 130.17 ms, jitter = 130.17 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25203.398387, wall = 137.57 ms, jitter = 137.57 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25203.498502, wall = 100.11 ms, jitter = 100.11 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25203.641034, wall = 142.53 ms, jitter = 142.53 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25203.767836, wall = 126.80 ms, jitter = 126.80 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25203.886397, wall = 118.56 ms, jitter = 118.56 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25204.003185, wall = 116.79 ms, jitter = 116.79 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25204.137361, wall = 134.18 ms, jitter = 134.18 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25204.268326, wall = 130.97 ms, jitter = 130.97 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25204.406218, wall = 137.89 ms, jitter = 137.89 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25204.515458, wall = 109.24 ms, jitter = 109.24 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25204.641974, wall = 126.52 ms, jitter = 126.52 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25204.767605, wall = 125.63 ms, jitter = 125.63 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25204.881709, wall = 114.10 ms, jitter = 114.10 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25205.034377, wall = 152.67 ms, jitter = 152.67 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25205.130269, wall =  95.89 ms, jitter =  95.89 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25205.263740, wall = 133.47 ms, jitter = 133.47 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25205.388350, wall = 124.61 ms, jitter = 124.61 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25205.519563, wall = 131.21 ms, jitter = 131.21 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25205.626928, wall = 107.37 ms, jitter = 107.37 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25205.764849, wall = 137.92 ms, jitter = 137.92 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25205.897580, wall = 132.73 ms, jitter = 132.73 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25206.012323, wall = 114.74 ms, jitter = 114.74 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25206.141912, wall = 129.59 ms, jitter = 129.59 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25206.271465, wall = 129.55 ms, jitter = 129.55 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25206.380338, wall = 108.87 ms, jitter = 108.87 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25206.506842, wall = 126.50 ms, jitter = 126.50 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25206.642423, wall = 135.58 ms, jitter = 135.58 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25206.800768, wall = 158.34 ms, jitter = 158.34 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25206.884201, wall =  83.43 ms, jitter =  83.43 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25207.012594, wall = 128.39 ms, jitter = 128.39 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25207.155349, wall = 142.76 ms, jitter = 142.76 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25207.250997, wall =  95.65 ms, jitter =  95.65 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25207.384579, wall = 133.58 ms, jitter = 133.58 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25207.508975, wall = 124.40 ms, jitter = 124.40 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25207.632388, wall = 123.41 ms, jitter = 123.41 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25207.756061, wall = 123.67 ms, jitter = 123.67 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25207.889042, wall = 132.98 ms, jitter = 132.98 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25208.033453, wall = 144.41 ms, jitter = 144.41 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25208.138919, wall = 105.47 ms, jitter = 105.47 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25208.273426, wall = 134.51 ms, jitter = 134.51 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25208.376774, wall = 103.35 ms, jitter = 103.35 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25208.510777, wall = 134.00 ms, jitter = 134.00 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25208.635375, wall = 124.60 ms, jitter = 124.60 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25208.755109, wall = 119.73 ms, jitter = 119.73 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25208.890071, wall = 134.96 ms, jitter = 134.96 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25209.018363, wall = 128.29 ms, jitter = 128.29 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25209.141406, wall = 123.04 ms, jitter = 123.04 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25209.277206, wall = 135.80 ms, jitter = 135.80 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25209.401264, wall = 124.06 ms, jitter = 124.06 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25209.635092, wall = 233.83 ms, jitter = 233.83 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25209.762425, wall = 127.33 ms, jitter = 127.33 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25209.896755, wall = 134.33 ms, jitter = 134.33 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25209.998276, wall = 101.52 ms, jitter = 101.52 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25210.124802, wall = 126.53 ms, jitter = 126.53 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25210.248326, wall = 123.52 ms, jitter = 123.52 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25210.379961, wall = 131.64 ms, jitter = 131.64 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25210.503565, wall = 123.60 ms, jitter = 123.60 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25210.640191, wall = 136.63 ms, jitter = 136.63 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25210.774394, wall = 134.20 ms, jitter = 134.20 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25210.875653, wall = 101.26 ms, jitter = 101.26 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25211.022400, wall = 146.75 ms, jitter = 146.75 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25211.148900, wall = 126.50 ms, jitter = 126.50 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25211.258625, wall = 109.73 ms, jitter = 109.73 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25211.380541, wall = 121.92 ms, jitter = 121.92 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25211.502602, wall = 122.06 ms, jitter = 122.06 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25211.624875, wall = 122.27 ms, jitter = 122.27 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25211.776370, wall = 151.49 ms, jitter = 151.49 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25211.904828, wall = 128.46 ms, jitter = 128.46 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25212.001272, wall =  96.44 ms, jitter =  96.44 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25212.135470, wall = 134.20 ms, jitter = 134.20 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25212.266620, wall = 131.15 ms, jitter = 131.15 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25212.377299, wall = 110.68 ms, jitter = 110.68 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25212.504992, wall = 127.69 ms, jitter = 127.69 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25212.638316, wall = 133.32 ms, jitter = 133.32 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25212.773812, wall = 135.50 ms, jitter = 135.50 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25212.877339, wall = 103.53 ms, jitter = 103.53 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25213.003287, wall = 125.95 ms, jitter = 125.95 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25213.146980, wall = 143.69 ms, jitter = 143.69 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25213.256790, wall = 109.81 ms, jitter = 109.81 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25213.395753, wall = 138.96 ms, jitter = 138.96 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25213.514417, wall = 118.66 ms, jitter = 118.66 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25213.642190, wall = 127.77 ms, jitter = 127.77 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25213.756918, wall = 114.73 ms, jitter = 114.73 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25213.929180, wall = 172.26 ms, jitter = 172.26 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25214.028998, wall =  99.82 ms, jitter =  99.82 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25214.138127, wall = 109.13 ms, jitter = 109.13 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25214.258348, wall = 120.22 ms, jitter = 120.22 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25214.387901, wall = 129.55 ms, jitter = 129.55 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25214.501399, wall = 113.50 ms, jitter = 113.50 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# EPOCH = 25214.632168, wall = 130.77 ms, jitter = 130.77 ms  delta c=+25  delta raw c=25  v= 0.098, len(dir_log)=12500
# EPOCH = 25214.750932, wall = 118.76 ms, jitter = 118.76 ms  delta c=+26  delta raw c=26  v= 0.102, len(dir_log)=12500
# Graceful shutdown.
